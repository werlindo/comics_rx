# %% [markdown]
# # Scraping Comic Book Covers
#
# **Goal**: Scrape comic covers so can use them as visual touchstones for users in the app.

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import requests
import random
import time
import os

# Selenium
from selenium.webdriver import Firefox
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.firefox.options import Options
options = Options()
options.headless = True

# Data storage
from sqlalchemy import create_engine # SQL helper
import psycopg2 as psql #PostgreSQL DBs

# Custom
import lib.data_fcns as dfc
import lib.keys as keys  # Custom keys lib
import lib.comic_scraper as cs

# %% [markdown]
# ### Initialize Browser

# %%
driver_exe_path = os.path.join(os.getcwd(), 'drivers'
                               ,'geckodriver-windows.exe')

# %%
driver_exe_path
# Out:
# 'D:\\dropbox\\flatiron\\capstone\\comics_rx\\drivers\\geckodriver-windows.exe'

# %%
browser = Firefox(options=options, executable_path=driver_exe_path)
url = "http://www.comicbookdb.com/"
browser.get(url)

# %% [markdown]
# ### Make list of Titles!
#
# Get list of titles to scrape covers.

# %%
# Define path to secret
secret_path_aws = os.path.join(os.environ['HOME'], '.secret', 
                           'aws_ps_flatiron.json')
secret_path_aws
# Out:
# 'C:\\Users\\werlindo\\.secret\\aws_ps_flatiron.json'

# %%
aws_keys = keys.get_keys(secret_path_aws)
user = aws_keys['user']
ps = aws_keys['password']
host = aws_keys['host']
db = aws_keys['db_name']

aws_ps_engine = ('postgresql://' + user + ':' + ps + '@' + host + '/' + db)

# Setup PSQL connection
conn = psql.connect(
    database=db,
    user=user,
    password=ps,
    host=host,
    port='5432'
)

# %%
# Instantiate cursor
cur = conn.cursor()

# %%
#  Count records.
query = """
    SELECT * from comic_trans;
"""

# %%
# Execute the query
cur.execute(query)

# %%
# Check results
temp_df = pd.DataFrame(cur.fetchall())
temp_df.columns = [col.name for col in cur.description]

# %%
temp_df.head(3)
# Out:
#    index                       publisher    item_id             title_and_num  \
# 0      2  Amaze Ink Slave Labor Graphics  DCD151935           Filler Bunny #2
# 1      3  Amaze Ink Slave Labor Graphics  DCD341726              Gargoyles #6
# 2      4  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
#
#    qty_sold           date_sold account_num                  comic_title
# 0         1 2011-08-14 18:01:03       00174           Filler Bunny (SLG)
# 1         1 2012-06-22 14:11:37       00593              Gargoyles (SLG)
# 2         1 2010-07-21 14:03:07       00226  Royal Historian of Oz (SLG)

# %%
temp_df['title'] = ( temp_df['title_and_num'].apply(dfc.cut_issue_num) )

# %%
temp_df.head()
# Out:
#    index                       publisher    item_id             title_and_num  \
# 0      2  Amaze Ink Slave Labor Graphics  DCD151935           Filler Bunny #2
# 1      3  Amaze Ink Slave Labor Graphics  DCD341726              Gargoyles #6
# 2      4  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
# 3      5  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
# 4      6  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
#
#    qty_sold           date_sold account_num                  comic_title  \
# 0         1 2011-08-14 18:01:03       00174           Filler Bunny (SLG)
# 1         1 2012-06-22 14:11:37       00593              Gargoyles (SLG)
# 2         1 2010-07-21 14:03:07       00226  Royal Historian of Oz (SLG)
# 3         1 2010-07-14 19:49:40       00399  Royal Historian of Oz (SLG)
# 4         1 2010-07-19 10:39:04       00237  Royal Historian of Oz (SLG)
#
#                    title
# 0           Filler Bunny
# 1              Gargoyles
# 2  Royal Historian of Oz
# 3  Royal Historian of Oz
# 4  Royal Historian of Oz

# %%
temp_df['title'] = (temp_df['title'].apply(lambda x : x.replace('&' ,'and'))
                    .apply(lambda x : x.replace('?' ,''))
                    .apply(lambda x : x.replace('/' ,' '))
                   )

# %%
titles = list(temp_df['title'].unique())

# %%
sample_titles = titles[:300]

# %%
sample_titles
# Out:
# ['Filler Bunny',
#  'Gargoyles',
#  'Royal Historian of Oz',
#  'Warlord of Io and Other Storie',
#  'Afterlife With Archie',
#  'Afterlife With Archie Magazin',
#  'Archie',
#  'Boys',
#  'Archie and Friends Double Diges',
#  'Archie and Friends Double Doubl',
#  'Archie 1941',
#  'Archie and Me Comics Digest',
#  'Archie and Me Jumbo Comics Di',
#  'Archie Collectors E',
#  'Archie Comics Annual Digest',
#  'Archie Comics Double Digest',
#  'Archie Double Digest',
#  'Archie Jumbo Comics Digest',
#  'Archie Meets Batman 66',
#  'Archie Meets Ramones One Sho',
#  'Archie Vs Sharknado One Shot',
#  'Archies',
#  'Archies Halloween Spectacula',
#  'Archies One Shot Cvr A Jaime',
#  'Archies Superteens Vs Crusade',
#  'B and V Friends Double Digest',
#  'B and V Friends Halloween Annua',
#  'B and V Friends Jumbo Comics Di',
#  'Betty and Veronica',
#  'Betty and Veronica Comics Annua',
#  'Betty and Veronica Comics Diges',
#  'Betty and Veronica Comics Doubl',
#  'Betty and Veronica Friends Fore',
#  'Betty and Veronica Holiday Annu',
#  'Betty and Veronica Jumbo Comic',
#  'Betty and Veronica Friends Fo',
#  'Betty and Veronica Vixens',
#  'Big Moose One Shot Cvr A Reg',
#  'Black Hood',
#  'Black Hood Season 2',
#  'Blossoms 666',
#  'Chilling Adv of Sabrina',
#  'Fox #1 2nd Ptg (Pp',
#  'Fox',
#  'Fox (Dark Circle)',
#  'Hangman',
#  'Josie and the Pussycats',
#  'Jughead',
#  'Jughead and Archie Comics Doubl',
#  'Jughead Hunger Vs Vampironic',
#  'Jughead the Hunger',
#  'Jughead the Hunger One Shot C',
#  'Jughead Time Police',
#  'Jugheads Double Digest',
#  'Kevin Keller',
#  'Life With Archie',
#  'Life With Archie Comic',
#  'Little Archie One Shot Cvr A',
#  'Marvel Comics Digest',
#  'Mega Man',
#  'Mega Man Worlds Unite Battle',
#  'Monster Sized Chilling Advent',
#  'Reggie and Me',
#  'Riverdale',
#  'Riverdale (Ongoing)',
#  'Riverdale Digest',
#  'Riverdale Season 3',
#  'Sabrina',
#  'Sabrina Teenage Witch',
#  'Shield (Dark Circle)',
#  'Mercury Heat',
#  'Sonic Boom',
#  'Sonic Mega Drive Next Level O',
#  'Sonic Mega Drive One Shot (C',
#  'Sonic Super Digest',
#  'Sonic Super Special Magazine',
#  'Sonic the Hedgehog',
#  'Sonic Universe',
#  'Sonic Worlds Unite Battles',
#  'Tales From Riverdale Digest',
#  'Vampironica',
#  'World of Archie Comics Doubl',
#  'World of Archie Double Diges',
#  'World of Archie Jumbo Comics',
#  'All New Fathom',
#  'All New Soulfire',
#  'Aspen Splash 2010 Swimsuit Sp',
#  'Bubblegun VOL 2',
#  'Charismagic',
#  'Charismagic Death Princess',
#  'Dead Mans Run',
#  'Executive Assistant Iris',
#  'Executive Assistant Iris VOL',
#  'Fathom',
#  'Fathom Annual',
#  'Fathom Blue Descent',
#  'Fathom Elite Saga',
#  'Fathom Kiani VOL 3',
#  'Fathom Kiani VOL 4',
#  'Fathom VOL 4',
#  'Haunted City',
#  'Jirni VOL 2',
#  'Lady Mechanika',
#  'Lady Mechanika Collected Edit',
#  'Lola Xoxo',
#  'No World',
#  'Soulfire',
#  'Soulfire Annual',
#  'Soulfire Despair',
#  'Soulfire Hope',
#  'Soulfire New World Order',
#  'Soulfire VOL 3',
#  'Soulfire VOL 4',
#  'Soulfire VOL Two',
#  'Soulfire Volume Two',
#  'Trish Out of Water',
#  'Absolution Happy Kitty Specia',
#  'Absolution Rubicon',
#  'Alan Moore Neonomicon Hornboo',
#  'Anna Mercury 2',
#  'Belladonna',
#  'Caliban',
#  'Caligula',
#  'Caligula Heart of Rome',
#  'Captain Swing',
#  'Chronicles of Wormwood Last B',
#  'Chronicles of Wormwood Lb',
#  'Chronicles of Wormwood Lb Pre',
#  'Cinema Purgatorio',
#  'Cinema Purgatorio Dlx HC',
#  'Code Pru',
#  'Crossed',
#  'Crossed Annual 2013',
#  'Crossed Annual 2014 (Mr',
#  'Crossed Badlands',
#  'Crossed Badlands Patient Zer',
#  'Crossed Dead Or Alive',
#  'Crossed Family Values',
#  'Crossed Plus 100',
#  'Crossed Plus 100 Mimic',
#  'Crossed Psycho',
#  'Crossed Psychopath',
#  'Crossed Special 2013 (Mr',
#  'Crossed Special 2013 Torture',
#  'Crossed Special 2014 (Mr',
#  'Crossed Wish You Were Here As',
#  'Dan the Unharmable',
#  'Dark Gods',
#  'Dicks',
#  'Dicks Color Ed',
#  'Do Anything VOL 0',
#  'Doktor Sleepless',
#  'Extinction Parade',
#  'Extinction Parade War',
#  'Fashion Beast',
#  'Ferals',
#  'Fevre Dream',
#  'George Rr Martin In the Hous',
#  'George Rr Martin Skin Trade',
#  'God Is Dead',
#  'God Is Dead Book of Acts Alph',
#  'God Is Dead Book of Acts Omeg',
#  'Gravel',
#  'Gravel Combat Magician',
#  'Hero Worship',
#  'Neonomicon',
#  'Night O T Living Dead',
#  'Night O T Living Dead 2011 An',
#  'Night O T Living Dead Afterma',
#  'Night O T Living Dead Death V',
#  'Night O T Living Dead Holida',
#  'Night of the Living Dead',
#  'Providence',
#  'Providence Ltd HC Act 01 (Mr',
#  'Rover Red Charlie',
#  'Sdcc 2014 Extinction Parade W',
#  'Stitched',
#  'Streets of Glory',
#  'Supergod',
#  'Uber',
#  'Uber Invasion',
#  'Uber Special',
#  'War Stories',
#  'Wolfskin Hundredth Dream',
#  'Bart Simpson',
#  'Bart Simpson Comics',
#  'Bart Simpsons Pal Milhouse',
#  'Bart Simpsons Treehouse of Ho',
#  'Bartman`s Spectaculary Super',
#  'Chief Wiggums Felonious Funni',
#  'Comic Book Guy the Comic Boo',
#  'Duffman Adventures',
#  'Futurama Annual',
#  'Futurama Comics',
#  'Grampa Simpsons Choose Your O',
#  'Jimbo Jones',
#  'Kang and Kodos',
#  'Krusty the Clown (One Shot',
#  'Lil Homer',
#  'Malevolent Mr Burns',
#  'Mcbain',
#  'Mighty Moe Szyslak',
#  'Simpsons Comics',
#  'Professor Frink Fantastic Sci',
#  'Ralph Wiggum Comics',
#  'Sergio Aragones Funnies',
#  'Simpsons Illustrated',
#  'Simpsons Summer Shindig',
#  'Simpsons Super Spectacular',
#  'Simpsons Treehouse of Horror',
#  'Simpsons Winter Wingding',
#  'Spongebob Comics',
#  'Spongebob Comics Annual Gian',
#  'Wonderful World of Lisa Simps',
#  '3 Guns',
#  'Abbott',
#  'Abigail and the Snowman',
#  'Adv Time Banana Guard Academ',
#  'Adventure Time',
#  'Adventure Time 2013 Spoooktac',
#  'Adventure Time 2014 Annual',
#  'Adventure Time 2014 Special',
#  'Angel',
#  'Adventure Time 2015 Spoooktac',
#  'Adventure Time 2016 Spoooktac',
#  'Adventure Time 2017 Spoooktac',
#  'Adventure Time Annual',
#  'Adventure Time Beginning of E',
#  'Adventure Time Candy Capers',
#  'Adventure Time Comics',
#  'Adventure Time Fionna and Cake',
#  'Adventure Time Flip Side',
#  'Adventure Time Ice King',
#  'Adventure Time Marceline Gon',
#  'Adventure Time Marceline Scre',
#  'Adventure Time Marcy and Simon',
#  'Adventure Time Regular Show',
#  'Adventure Time Season 11',
#  'Adventure Time Summer Specia',
#  'Aliens Vs Parker',
#  'Amazing World of Gumball',
#  'Amazing World of Gumball 201',
#  'Amazing World of Gumball Gra',
#  'Americatown',
#  'Amory Wars Good Apollo',
#  'Amory Wars Iii Good Apollo',
#  'Amory Wars Keeping Secrets o',
#  'Arcadia',
#  'Avant-Guards',
#  'Backstagers',
#  'Backstagers Halloween Intermi',
#  'Baker Street Peculiars',
#  'Bee and Puppyca',
#  'Bee and Puppycat',
#  'Betrayal O T Planet O T Apes',
#  'Big Trouble In Little China',
#  'Big Trouble In Little China O',
#  'Big Trouble Little China Esca',
#  'Bill and Ted Go To Hell',
#  'Bill and Ted Most Triumphant Re',
#  'Bill and Ted Save the Universe',
#  'Black Badge',
#  'Black Market',
#  'Bone Parish',
#  'Boom Box 2014 Mix Tape',
#  'Boom Box 2015 Mix Tape',
#  'Boom Box 2016 Mix Tape',
#  'Brave Chef Brianna',
#  'Bravest Warriors',
#  'Bravest Warriors 2014 Annual',
#  'Bravest Warriors Paralyzed Ho',
#  'Bravest Warriors Tales Holo J',
#  'Broken World',
#  'Buffy the Vampire Slayer',
#  'Burning Fields',
#  'Butterfly',
#  'By Night',
#  'Calling Cthulhu Chronicles',
#  'Capture Creatures',
#  'Cars',
#  'Cars Radiator Springs',
#  'Cbgb',
#  'Chip N Dale Rescue Rangers',
#  'Clarence',
#  'Clive Barker Next Testament',
#  'Clive Barkers New Genesis',
#  'Clive Barkers Nightbreed',
#  'Cloaks',
#  'Cluster',
#  'Cluster #2 2nd Ptg (Pp',
#  'Coady and the Creepies',
#  'Coda',
#  'Codebreakers',
#  'Cognetic',
#  'Cold Space',
#  'Curb Stomp',
#  'Curse',
#  'Cursed Pirate Girl Special An',
#  'Dadoes Dust To Dust',
#  'Darkwing Duck']

# %% [markdown]
# Get list, sorted by qty sold

# %%
qtys = temp_df.groupby(['title'], as_index=False).qty_sold.sum().sort_values(by=['qty_sold'], ascending=False)

# %%
qtys.head()
# Out:
#                    title  qty_sold
# 553               Batman      9562
# 6699        Walking Dead      6856
# 229   Amazing Spider-Man      5828
# 5098                Saga      5542
# 5928            Superman      5197

# %%
done_titles = titles[:300]

# %%
titles_needed_df = qtys.loc[~qtys['title'].isin(done_titles)]

# %%
titles_needed_df.shape
# Out:
# (6771, 2)

# %%
titles_need_list = list(titles_needed_df.title.unique())

# %%
#367+246+151
827+151+376+524+5+47+1662+3+162+155+15
# Out:
# 3927

# %%
new_start=3927 #1932

# %%
titles_searching = titles_need_list[new_start:]

# %%
titles_searching
# Out:
# ['DC Comics Presents the Metal',
#  'Onslaught Unleashed',
#  'Star Trek Year Five',
#  'Web of Venom Cult of Carnage',
#  'All Star Section 8',
#  'Klaus and Crying Snowman',
#  '68 Last Rights',
#  'DC Comics Presents Green Lant',
#  'Oberon',
#  'Axis Hobgoblin',
#  'Emily and the Strangers Breakin',
#  'Pantha',
#  'Star Wars Aor Anakin Skywalke',
#  'Black Af Widows and Orphans',
#  'Kull Eternal',
#  'Savage Skullkickers',
#  'Peter Parker',
#  'Spider-Women Omega',
#  'Aphrodite IX Hidden Files',
#  'Gwar Orgasmageddon',
#  'Fall of Hulks Savage She-Hulk',
#  'Muppet King Arthur',
#  'DC Comics Presents J H Willia',
#  'Agent Carter Shield 50th Anni',
#  'Sinestro Annual',
#  'Wwe Then Now Forever',
#  'New Romancer',
#  'Msh Adventures Spider-Man Acr',
#  'Rodd Racer One Sho',
#  'Star Wars Aor Jabba the Hutt',
#  'Night Moves',
#  'Now Moon Girl and Devil Dinos',
#  'Crypt of Shadows',
#  'DC Comics Presents Jack Cros',
#  'Resident Alien the Man With N',
#  'Rowans Ruin',
#  'My Little Pony Annual 2017',
#  'Victorie City',
#  'Dinosaurs Attack',
#  'Resurrection VOL 2',
#  'Muppet Snow White',
#  'Super Sons Dynomutt Special',
#  'Dream Logic',
#  'Shield Infinity Weaver Va',
#  'Adam.3',
#  'Ghostbusters Get Real',
#  'Shoot First',
#  'Red Sonja Wrath of the Gods',
#  'Avengelyne',
#  'Batman 66 Meets the Legion o',
#  'DC Comics Presents Batman',
#  'What If Infinity Dark Reign',
#  'Superior Octopus',
#  'Charlies Angels',
#  'Superior Carnage Annual',
#  'Dream Thief',
#  'All New Secret Skullkickers',
#  'Now Punisher',
#  'Harley Quinn Be Careful What',
#  'Shield Directors Cut',
#  'Eltingville Club One Sho',
#  'Rot and Ruin',
#  'Silver Surfer Annual',
#  'Fathers Day',
#  'Dregs',
#  'Descendent',
#  'Doctor Who Ghost Stories',
#  'Daomu',
#  'Giants',
#  'My Little Pony Equestria Girl',
#  'Sky Doll Space Ship',
#  'Shadow VOL 2',
#  'Starstruck Old Proldiers Neve',
#  'Complete Alice In Wonderland',
#  'Shadow Special',
#  'Stabbity Bunny',
#  'Vertigo Quarterly Sfx',
#  'Prelude To Marvels Avengers',
#  'From Hell Master Edition',
#  'Pariah',
#  'Shadowman (2018)',
#  'Now Star-Lord',
#  'Ninjak Vs Vu',
#  'Bad Luck Chuck',
#  'Gft Goddess Inc',
#  'Galaxy Quest Journey Continue',
#  'We Are Danger',
#  'Rift',
#  'Plunder',
#  'Grave Lilies',
#  'Spectacular Spider-Girl',
#  'Plants Vs Zombies Garden Warf',
#  'Planet of the Apes Annual',
#  'Winterworld Frozen Fleet',
#  'Pathfinder Hollow Mountain',
#  'Shadowland Bullseye',
#  'Robocop Citizens Arrest',
#  'Wakanda Forever X-Men',
#  'Solomon Kane Deaths Black',
#  'DC Retroactive the Flash the',
#  'Okko Cycle of Air',
#  'Empire of Blood',
#  'Disney Frozen Breaking Bounda',
#  'Death Force',
#  'Donald Quest',
#  'Mysterious Ways',
#  'Dark Skullkickers Dark',
#  'Spirit Leaves',
#  'DC Comics Presents Superman S',
#  'Pierce Brown Red Rising',
#  'Spider-Island Deadly Foes',
#  'Seven Percent',
#  'Doctor Who 2015 Four Doctors',
#  'Dr Crowe',
#  'Secret Wars Official Handboo',
#  'Order of the Forge',
#  'Spider-Man Into the Spider-Ve',
#  'Northanger Abbey',
#  'Doctor Who 11th Year 2',
#  'Noir',
#  'Bar Maid',
#  'Returning',
#  'Warhammer 40000 Deathwatch',
#  'Superman Top Cat Special',
#  'Marvels Avengers Untitled Pre',
#  'Lollipop Kids',
#  'Bushido',
#  'Judge Dredd Classics',
#  'Marvel Legacy',
#  'TMNT Micro Series',
#  '68 Jungle Jim One Shot Cvr',
#  'Terrible Lizard',
#  'Transformers Spotlight Bumble',
#  'Young Monsters In Love',
#  'Takio',
#  'Marvel 1602 Mgc',
#  'Marvels Spider-Man City At Wa',
#  'Transformers Spotlight Orion',
#  'Big Lie',
#  'Transformers Spotlight Thunde',
#  'Battlecats',
#  'Joe Golem Occult Detective Co',
#  'Bloodshot Usa',
#  'Cavewoman Feeding Grounds',
#  'I Am An Avenger',
#  'Kodiak (One Shot',
#  'Transformers Bumblebee Movie',
#  'Bomb Queen VI',
#  'Locke and Key Small World Subsc',
#  'Tower Chronicles Dreadstalke',
#  'Kung Fu Panda',
#  'Cave Carson Swamp Thing Speci',
#  'Helldorado',
#  'Locke and Key Welcome To Lovecr',
#  'Batman Hidden Treasures',
#  'Jonah Hex Yosemite Sam Specia',
#  'Lady Mechanika Dame Sans Merc',
#  'Illegitimates',
#  'Supurbia Ongoing',
#  'Cable and X-Force #19 (Pp',
#  'True Believers Droids',
#  'Kodt Black Hands 2010',
#  '68 Hardship One Shot Cvr',
#  'Zojaqan',
#  'True Believers Luke Cage Her',
#  'True Believers What If Silve',
#  'Cartoon Network Action Pack',
#  'Thunderbolts Annual 2013',
#  'Misadventures of Adam West',
#  'Legion of Super Heroes Annua',
#  'Masters of the Universe the O',
#  'Hawken',
#  'Accused',
#  'Jem and the Holograms Misfits I',
#  'Mediterranea',
#  'X-Men (1991)',
#  'Black Terror',
#  'Jem the Misfits',
#  'Magnus',
#  'Berlin',
#  'Kaijumax Season 3',
#  'Legenderry Vampirella',
#  'Legenderry Green Hornet',
#  'Legion of Super Villains',
#  'Battlestar Galactica Starbuc',
#  'Infinity Wars Prime',
#  'Tmnt Color Classics Series 2',
#  'A1',
#  'Let Me In Crossroads',
#  'Carver Paris Story',
#  'True Believers Phoenix Return',
#  'Zombie Tramp Xxxmas Special R',
#  'True Believers Avengers Class',
#  'Terrifics Annual',
#  'Max Ride',
#  'Sinergy',
#  'New Talent Showcase 2018',
#  'Jack Avarice Is the Courier',
#  'Itty Bitty Hellboy Search Fo',
#  'X-Men CoM Storm and Gambit',
#  'Red Sonja Sanctuary One Sho',
#  'Slapstick',
#  'Jem and the Holograms Holiday S',
#  'Jazz Maynard VOL 2',
#  'Transformers Fall of Cybertro',
#  'Transformers Combiner Hunter',
#  'Incognegro Renaissance',
#  'Marvelman Familys Finest',
#  'Station To Station One Sho',
#  'Sky Doll Doll Factory',
#  'Stargate Universe Back To Des',
#  'Wonder Woman Tasmanian Devil',
#  'Bloodshot Reborn Annual 2016',
#  'Star Wars Purge Tyrants Fist',
#  'Aphrodite IX Cyber Force',
#  'What If Infinity Thanos',
#  'Young Terrorists',
#  'What If Infinity Inhumans',
#  'Transformers Punishment (One',
#  'Lightstep',
#  'Reanimator',
#  'Not Brand Echh Le',
#  'Blackest Night Directors Cu',
#  'Now Gamora',
#  'Control',
#  'Forty Coffins One Sho',
#  'Now Ghost Rider',
#  'Our Love Is Real One Shot (Mr',
#  'Lucas Stand',
#  'Lucid',
#  'Tmnt Macroseries Michelangel',
#  'Darkseid Special',
#  'Avp Three World War',
#  'Brutal Nature',
#  'Tmnt Macroseries Donatello Cv',
#  'Bruce Lee Dragon Rises',
#  'Spider-Island Spider-Woman',
#  'DC Looney Tunes 100 Page Spec',
#  'Dark Souls Winters Spite',
#  'Genius Cartel',
#  'Spider-Man Spectacular',
#  'Witchfinder Gates of Heaven',
#  'Magic the Gathering Chandra',
#  'Lowlifes',
#  'Indoctrination',
#  'Witching Hour',
#  'Gft Inferno',
#  'Avengers Vs Atlas',
#  'Time Bomb',
#  'Patricia Briggs Mercy Thompso',
#  'Pathfinder Worldscape',
#  'DC Universe Holiday Special 2',
#  'Pathfinder Origins',
#  'Gft Giant Size 2013 (Unleashe',
#  'Star Mage',
#  'Van Helsing Vs the Werewolf',
#  'Painkiller Jane 22 Brides',
#  'True Believers Wolverine Fata',
#  'One Hit Wonder',
#  'Star Trek Special Flesh and Sto',
#  'Transformers 3 Movie',
#  'True Believers Wolverine the',
#  'Punks the Comic Cbldf Spe',
#  'Now Gwenpool',
#  'Punisher Max Hot Rods of Deat',
#  'The Crow Pestilence',
#  'Deadpool Family',
#  'Curse of Brimstone',
#  'Snap Flash Hustle',
#  'Forever War',
#  'Formic Wars Burning Earth',
#  'Convergence Hawkman',
#  'Star Wars Dawn O T Jedi Priso',
#  'Ghostbusters Annual 2018 Cvr',
#  'Ghostbusters Annual 201',
#  'Prometheus Eternal One Sho',
#  'Vagrant Queen',
#  'Once Our Land',
#  'Thor First Thunder',
#  'Preacher',
#  'Booster Gold Flintstones Annu',
#  'Lorna Relic Wrangler One Sho',
#  'Insufferable',
#  'Angry Birds Comics (2016)',
#  'Angry Birds Comics',
#  'Spawn Resurrection',
#  'Vampblade Season 3',
#  'Angel Special Lorne (One Shot',
#  'Planet of the Nerds',
#  'Fanboys Vs Zombies',
#  'Avengers Black Widow Strikes',
#  'Convergence Blue Beetle',
#  'Sex Death Revolution',
#  'Zombie Tramp VOL 2',
#  'Super Friends',
#  'Bionic Woman Season Four',
#  'Cavewoman Mutation',
#  'Munchkin',
#  'Black Af Devils Dye',
#  'Gumballs',
#  'Zombie Tramp Halloween Sp On',
#  'Goosebumps Monsters At Midnig',
#  'Mighty Skullkickers',
#  'Surviv',
#  'My Little Pony Deviation',
#  'Doctor Who Special 2013',
#  'Epochalypse',
#  'Doc Savage Annual 201',
#  'Shadow Glass',
#  'Black Eyed Kids',
#  'Black Jack Ketchum',
#  'Eternity',
#  'Lady Mechanika #0 and',
#  'Hero Comics 201',
#  'Evil Dead 2',
#  'Catwoman Election Night',
#  'Grumpy Cat Garfield',
#  'Shadowland Elektra',
#  'Self Obsessed One Sho',
#  'True Believers Jessica Jones',
#  'Catalyst Prime Noble',
#  'Assassins Creed',
#  'Karma Police',
#  'Kato Origins Way O T Ninja',
#  'Hate Annual',
#  'Chaos War Chaos King',
#  'Chaos War Ares',
#  'Chaos War God Squad',
#  'Chaos War Alpha Flight',
#  'Dr Strange The Mystic Hands o',
#  'True Believers Punisher War J',
#  'Drones',
#  'Monstro Mechanica',
#  'Miss Fury VOL 2',
#  'Cbldf Liberty Annual 2016 Cv',
#  'Astro Hustle',
#  'X-Files Conspiracy',
#  'Armor Hunters',
#  'War Bears',
#  'Happy Hour In America',
#  'Minions',
#  'Chew Script Book (Mr',
#  'Earth 2 Society Annual',
#  'Superboy Futures End',
#  'Hacktivist VOL 2',
#  'Muirwood Lost Abbey',
#  'Hack Slash Series',
#  'Shadowland Ghost Rider',
#  'True Believers Wolverine Dyin',
#  'Nancy Drew',
#  'Leaving Megalopolis Survivin',
#  'Last Zombie',
#  'Wakanda Forever Amazing Spide',
#  'True Believers Amazing Spider',
#  'Revolutionary War Alpha',
#  'Green Lantern Space Ghost Ann',
#  'Rick and Morty Presents Jerry',
#  'Higher Earth',
#  'Ziggy Pig Silly Seal Comics',
#  'True Believers Amazing Fantas',
#  'Fallen',
#  'Wakanda Forever Avengers',
#  'Repulse One Shot (Mr',
#  'Uncharted',
#  'Diablo House',
#  'Jim Henson Labyrinth 30th Ann',
#  'Lady Mechanika Sangre',
#  'Trinity of Sin Pandora Future',
#  'Tails of Pet Avengers Dogs o',
#  'Disney Pixar Finding Dory',
#  'Black Widow #1',
#  'National Comics Rose and Thor',
#  'John Flood',
#  'True Believers Ant-Man Presen',
#  'Darkstar and Winter Guard',
#  'Jem and the Holograms Infinite',
#  'Dark and Bloody',
#  'Last Stop On Red Line',
#  'Haunted',
#  'She Said Destroy',
#  'Tmnt Idw 2020 Danie',
#  'Jokers Asylum Killer Croc',
#  'Edens Fall',
#  'Eighth Seal',
#  'Zero Jumper',
#  'Garbage Pail Kids Go Hollywoo',
#  'Tmnt Rise of the Tmnt',
#  'Injustice 2 Annual',
#  'Route Des Maisons Rouges',
#  'Angel Yearbook One Sho',
#  'Low Road West',
#  'True Believers Kitty Pryde an',
#  'Brain Boy',
#  'Judge Dredd Under Siege',
#  'King Tiger',
#  'Domino Annual',
#  'Red City',
#  'What If Thor',
#  'Genius',
#  'Bram Stokers Death Ship',
#  'Lazaretto',
#  'Kapow Guinness World Record S',
#  'Incredible Hulks Enigma Forc',
#  'Legend of Oz the Wicked West',
#  'Dracula Company of Monsters',
#  'Jennifer Blood',
#  'Magical Character Rabbit One',
#  'Red Sonja VOL 3',
#  'Diablo',
#  'True Believers Punisher By Gr',
#  'Danger Girl Mayday',
#  'Devil Within',
#  'Brilliant Trash',
#  'True Believers Punisher By En',
#  'Magdalena (Ongoing)',
#  'True Believers Wolverine',
#  'Dust Wars',
#  'Tmnt Amazing Adventures Robot',
#  'Madman New Giant Size Super G',
#  'Gft Alice 10th Anniversary Sp',
#  'Dungeons and Dragons (2016)',
#  'American Way Those Above and',
#  'Seasons Beatings',
#  'War Mother',
#  'Second Sight',
#  'War For Planet of the Apes',
#  'Kill Shakespeare Mask of Nigh',
#  'Revisionist',
#  'Dungeons and Dragons a Darkene',
#  'Spider-Island I Love New Yor',
#  'Spider-Island Heroes For Hir',
#  'Love Romances',
#  'Extraordinary X-Men Annual',
#  'Rook',
#  'Black Kiss 2 Xxxmas In July S',
#  'Vikings',
#  'Vertigo Resurrected the Extre',
#  'Transference',
#  'La Mano Del Destino',
#  'Fearless Dawn Secret O T Swam',
#  'Punisher Max Happy Ending',
#  'Fear Itself Sins Past',
#  'Deadlands One Sho',
#  'Sip (Strangers In Paradise) K',
#  'Punisher Annual',
#  'Public Relations',
#  'Fear Itself Ff',
#  'Bomb Queen Vs Hack Slash Vale',
#  'Atomic Robo Greatest Hit',
#  'Disney Pixar Incredibles 2',
#  'Road of the Dead Highway To H',
#  'Box Office Poison Color Comic',
#  'Transformers Redemptio',
#  'Bo Plushy Gangsta',
#  '13th Artifact One Sho',
#  'Fine and Private Place',
#  'Skull Island Birth of Kong',
#  'Transformers Holiday Specia',
#  'Queen of Bad Dreams',
#  'Lady Mechanika #2 and',
#  'Slash and Burn',
#  'Transformers First Strike',
#  'Deathstroke Annual',
#  'Lady Robotika',
#  'Shadowland After Fall',
#  'Transformers Annual 2017',
#  'Death Be Damned',
#  'Defenders Marvel Feature',
#  'Anne Rice Servant of the Bone',
#  'Formic Wars Silent Strike',
#  'Lockjaw and the Pet Avengers',
#  'Enormous One Shot',
#  'Dead At 17 Blasphemy Throne',
#  'Revolutionary War Dark Angel',
#  'Emily and the Strangers',
#  'Delete',
#  'Predator Hunters Ii',
#  'Angry Birds Transformers',
#  'Joe Hills the Cape One-Sho',
#  '3 Floyds Alpha King',
#  'Southern Dog',
#  'Powerpuff Girls Time Tie',
#  'Sky Doll Sudra',
#  'Eltingville Club',
#  'Dazzler X Song',
#  'Young Romance New 52 Valentin',
#  'Princeless Raven Pirate Princ',
#  'True Believers Hellcat First',
#  'Judge Dredd Annual',
#  'Sesame Street Another Sunny D',
#  'Torchwood',
#  'Book of Death Fall of Bloodsh',
#  'Prometheus Life and Death One S',
#  'Enders Game League Wa',
#  'Prometheus Fire and Stone Omeg',
#  'Fear Itself Black Widow',
#  'Klaws of Panther',
#  'Frankenstein Alive Tri',
#  'Project Superpowers Chapter T',
#  'Sonata',
#  'Lone Ranger VOL 3',
#  'Avengers Enemy Within',
#  'Lone Ranger Vindicated',
#  'Book of Death Fall of Harbing',
#  'Tmnt Macroseries',
#  'Hero Cats Midnight Over Stell',
#  'Now Foolkiller',
#  'Captain America Corps',
#  'The Beautiful Death (Statix)',
#  'True Believers Wolverine Vs V',
#  'Steven Universe 2016 Special',
#  'My Little Pony 2014 Annua',
#  'Surprise Free Variant',
#  'New Gods Special',
#  'True Believers Wolverine Vs S',
#  'Mighty Thor 3d',
#  'True Believers Wolverine Swor',
#  'Abattoir',
#  'Steel',
#  'Martian Manhunter Marvin the',
#  'Star Trek Ds9 Fools Gold',
#  'Image Firsts Morning Glories',
#  'Vampirella Feary Tales',
#  'Gi Joe a Real American Hero S',
#  'True Stories',
#  'Bsg Vs Bsg',
#  'Mindbender',
#  'Optimus Prime First Strike',
#  'Gft Steampunk Alice In Wonder',
#  'Gold Key Alliance',
#  'Now Mosaic',
#  'The October Faction',
#  'Thor Rage of Thor',
#  'Her-Oes',
#  'DC Comics Bombshells Annual',
#  'Stray Bullets (Mr',
#  'DC Comics Presents Batman Bey',
#  'Green Lanterns Annual',
#  'Codename Action',
#  'Cadmus',
#  'Usagi Yojimbo Color Special A',
#  'Mickey Mouse and Friends',
#  'Now Spider-Woman',
#  'Tales From the Crypt',
#  'Castle Waiting VOL Ii',
#  'Green Lantern Movie Prequel S',
#  'Calamity Kate',
#  'Merry X-Men Holiday Special',
#  'Burnouts',
#  'Now Slapstick',
#  'Conan Avenger',
#  'World of Animosity',
#  'Bullseye Perfect Game',
#  'True Believers Wolverine X-Me',
#  'Marvel Guardians of Galaxy VO',
#  'Oddly Normal',
#  'Memorial Imaginary Fiends',
#  'Suicide Girls',
#  'Cosmic Scoundrels',
#  'Marvel Presents',
#  'Night of 1000 Wolves',
#  'Alpha Big Time',
#  'Captain Kronos',
#  'Bedtime Games',
#  'Cbldf Liberty Annual 2015',
#  'DC Retroactive Batman the 70',
#  'Normandy Gold',
#  'Bronze Age Boogie',
#  'Star Spangled War Stories',
#  'Marvels Ant-Man Prelude',
#  'Broken Trinity Pandoras Box',
#  'Batman Arkham Knight Batgirl',
#  'Chastity',
#  'Our Fighting Forces',
#  'Outcast',
#  'Harvester',
#  'X-Files Conspiracy Tmnt',
#  'Minimum Carnage Alpha',
#  'Modern Fantasy',
#  'Nosferatu Wars One Sho',
#  'Haunt #3 2nd Ptg (Pp',
#  'Starcraft Scavengers',
#  'Bad Dreams',
#  'Gft Robyn Hood Age of Darknes',
#  'Hack Slash Vs Vampirella',
#  'X-Files Annual 201',
#  'Brother Nash',
#  'Mmpr Shattered Grid',
#  'Hulk Mgc',
#  'Terminator Sector War',
#  'Jim Thompson Killer Inside M',
#  'Dirk Gently a Spoon Too Shor',
#  'Bloodhound Crowbar Medicine',
#  'Resurrectionists',
#  'Great Divide',
#  'Teen Titans Cold Case',
#  'Battlestar Galactica Six',
#  'Vindication',
#  'Stiletto',
#  'Stargate Daniel Jackson',
#  'Turok',
#  'Human Target',
#  'She-Hulk Sensational',
#  'Battlestar Galactica Gods and M',
#  'Mask Revolution',
#  'Jem and the Holograms Annual 20',
#  'Revenge',
#  'Tales of Honor Bred To Kill',
#  'Herobear and the Kid Special',
#  'True Believers Wolverine Evol',
#  'Godzilla Treasury E',
#  'New Avengers Illuminati',
#  'Blackest Night Wonder Woman',
#  'Avatar Tsu Teys Path',
#  'Batvark',
#  'Hulk Smash Avengers',
#  'New Talent Showcase 2017',
#  'Legion of Super Heroes Bugs B',
#  'Jim Butcher Dresden Files Wa',
#  'Catalyst Prime Accell',
#  'What If Ghost Rider',
#  'Silent Hill Downpour Annes St',
#  'Aardvark Comics',
#  'Red Spike',
#  'Jennifer Blood First Blood',
#  'Teen Titans (2011)',
#  'Max Ride Final Flight',
#  'Dexters Laboratory',
#  'Tattered Man One Shot (Mr',
#  'What If Infinity Avengers',
#  'Country Ass Whuppin Tornado R',
#  'Gore',
#  'Silver Sable Wild Pack',
#  'Glow',
#  'Jim Henson Storyteller Siren',
#  'Tank Girl Dirty Helmets (One',
#  'Mata Hari',
#  'Rescue',
#  'Mega Man Mastermix',
#  'Red Hood and the Outlaws Futu',
#  'Accelerators',
#  'Jim Henson Labyrinth',
#  'Replacer Graphic Novell',
#  'Tank Girl Hairy Heroes (One S',
#  'New Mutants Forever',
#  'What If Spider-Ma',
#  'Auntie Agathas Home For Waywa',
#  'Authority the Lost Year Reade',
#  'Jersey Gods',
#  'True Believers Wolverine Exil',
#  'John Carter a Princess of Mar',
#  'Archer and Armstrong Archer',
#  'Halo Fall of Reach Invasion',
#  'Halo Blood Line',
#  'Eden',
#  'Heartthrob Season 2',
#  'Halloween Eve One Shot Cvr',
#  '1 For $1 Conan the Barbarian',
#  'Batman #23.2 Riddler',
#  'Judge Dredd Toxic',
#  'Biggest Bang',
#  'Batman #23.1 Joker',
#  'Msh Captain Marvel Halloween',
#  'Dog Days of Summer',
#  'Electric Black',
#  'True Believers Star Wars Dart',
#  'Chronos Commandos Dawn Patro',
#  'Hack Slash Ongoing',
#  'Rom Annual 201',
#  'Batman Blank Comic',
#  'Doctor Who Lost Dimension Alp',
#  'Rogues VOL 2',
#  'Bionic Man Vs Bionic Woman',
#  'Archon',
#  'Jungle Girl Season 3',
#  'King',
#  'Dungeons and Dragons Evil At Ba',
#  'Ka-Zar',
#  'Batman Arkham City End Game',
#  'Mister Miracle Directors Cut',
#  'Batman Arkham Knight Annual',
#  'Kevin Smith Kato',
#  'Khaal',
#  'Hawken Melee',
#  'Dungeons and Dragons Cutter',
#  'Chasing Hitler',
#  'Mortal Combat X',
#  'Hanazuki Full of Treasures',
#  'True Believers Power Man and',
#  'Dungeons and Dragons Shadow of',
#  'X-Files Conspiracy Transforme',
#  'Samurai Jack Lost Worlds',
#  'Minions Viva Le Boss',
#  'Batman #23.4 Bane',
#  'Samaritan',
#  'Kill Shakespeare Tide of Bloo',
#  'Harbinger Bleeding Monk',
#  'True Believers Star Wars Clas',
#  'Wynonna Earp Greatest Hits',
#  'Serpent Whispered',
#  'Gunhawks',
#  'Zodiac Starforce Cries of Fir',
#  'My Little Pony Idw 2020 Kuusi',
#  'Guide Marvel Cinematic Univer',
#  'Midnight Society the Black La',
#  'Guardians of Galaxy Mother En',
#  'Cloak and Dagger',
#  'Rise of Tmnt',
#  'Stuff of Legend the Jungle',
#  'Shadowland Blood On Streets',
#  'Micronauts First Strike',
#  'Stuff of Legend Toy Collecto',
#  'Evil Ernie Godeater',
#  'Disneys Hero Squad',
#  'Shadowland Spider-Man',
#  'Ex Con',
#  'Lady Mechanika Main Cvrs (Mr',
#  'Grimm Fairy Tales 2018 Holida',
#  'Street Fighter Legends Cammy',
#  'Mickey Mouse Shorts Season 1',
#  'Exile On the Planet of the Ap',
#  'Robert Heinleins Citizen of t',
#  'Eternal Warrior (Vu)',
#  'Cavewoman Gangster',
#  'Konungar War of Crowns',
#  'Sukeban Turbo',
#  'True Believers Enter the Phoe',
#  'Jsa 80 Page Giant 2011',
#  'City the Mind In the Machine',
#  'Hellboy Wild Hunt',
#  'Mighty Zodiac',
#  'Wwe Survivors Series 2017 Spe',
#  'Rocket Salvage',
#  'Enders Game Mazer In Prison S',
#  'Enders Shadow Command School',
#  'Roche Limit Monadic',
#  'Hellraiser Annual 2013',
#  'Korgi Short Tales Cvr A Slad',
#  'Journey Into Mystery Birth o',
#  'Robotech Voltron',
#  'Doctor Who 10th Year 2',
#  'Wwe Royal Rumble 2018 Specia',
#  'Action Man',
#  'Doctor Strange Mystic Apprent',
#  'Hellraiser Annual',
#  'Doctor Strange From Marvel Va',
#  'Superman 100 Page Spectacula',
#  'Captain America and Secret Av',
#  'Marvel Adventures Fantastic F',
#  'Thor Mgc',
#  'Power Pack',
#  'Gft Wonderland Down Rabbit Ho',
#  'Thor and Warriors Four',
#  'Power Button',
#  'Pound Ghouls Night Out',
#  'Sparta Usa',
#  'Postal Fbi Dossier',
#  'All Star Superman',
#  'Intrepid Escapegoat',
#  'Game of Thrones Clash of King',
#  'Pope Hats',
#  'Love and Capes Ever After',
#  'Axcend',
#  'Garbage Pail Kids Love Stink',
#  'Love and Capes What To Expec',
#  'Ben 10',
#  'Spectacular Spider-Man',
#  'Wildstorm Presents Planetary',
#  'Terminator',
#  'Btvs Season 12 the Reconing',
#  'Long Con',
#  'D4veocracy',
#  'Fraggle Rock',
#  'DC Comics Presents Batman Ark',
#  'DC Comics Presents Batman Dar',
#  'Number 13',
#  'Marvel Now What',
#  'Lone Wolf 2100',
#  'Long Distance',
#  'Sovereigns',
#  'Xed',
#  'DC Comics Presents Ethan Van',
#  'X-Women',
#  'Long Lost Part Two',
#  'Image Firsts Madma',
#  'Valen Outcast',
#  'Dcu Holiday Special 2010',
#  'October Faction Supernatural',
#  'Angelus',
#  'DC Comics Presents Shazam',
#  'Thin',
#  'Avengers Vs Infinity',
#  '68 Hallowed Ground One Shot C',
#  'Image Firsts Walking Dead',
#  'Our Army At War',
#  'Brik',
#  'Penguins of Madagascar',
#  'Marineman',
#  'Gft Hunters Shadowlands',
#  'Wizard Beach',
#  'Gft Genesis Heroes Rising Cv',
#  'Wolverine Mgc',
#  'Star Trek   Legion of Superhe',
#  'Damaged',
#  'Patience Conviction Revenge',
#  'True Believers Wolverine Bloo',
#  'Time Lincoln Cuba Commander O',
#  'Alpha Girl',
#  'DC Retroactive Batman the 90',
#  'Time and Vine',
#  'Gft 2015 Robyn Hood Holiday S',
#  'George Rr Martins Doorways',
#  'Plants Vs Zombies',
#  'Vampirella VOL 3',
#  'Spider King Frostbite One-Sho',
#  'Dawn Swordmasters Daughte',
#  'Star Trek New Visions Made Ou',
#  'Planet of the Apes Cataclysm',
#  'Operation Broken Wings 1936',
#  'Darkhawk',
#  'Optimus Prime Annual 2018 Cv',
#  'Tmnt Macroseries Leonardo Cv',
#  'Ordinary',
#  'Star Trek Deviation',
#  'Image Firsts Nightly News',
#  'Machete',
#  'Pink Panther',
#  'Spider-Man (Idw)',
#  'Pilot Season Test',
#  'Pilot Season Stellar',
#  'Dark Souls Age of Fire',
#  'Infestation 2 Transformers',
#  'Dead Or Alive',
#  'Powerpuff Girls Bureau of Ba',
#  'Giant Size Spider-Man',
#  'Flash Gordon Annual 201',
#  'Quake Shield 50th Anniversar',
#  'Gi Joe Snake Eyes Agent of Co',
#  'Iron Man Noir',
#  'Deadpoolmax X-Mas Special',
#  'Gi Joe Revolution',
#  'Sleepy Hollow Providence',
#  'A-Babies Vs X-Babies',
#  'Alan Robert Killogy',
#  'Albert Einstein Time Mason',
#  'Crow',
#  'Gi Joe Deviations (One Shot',
#  'Trailblazer One Shot (Mr',
#  'Crow Memento Mori',
#  'True Blood Tainted Love',
#  'White',
#  'Punisher Max Mgc',
#  'Little Girl',
#  'Giant Size Atom',
#  'Bloodshots Day Off',
#  'Jack Hammer',
#  'Star Wars Original Marvel Yea',
#  'Victorian Secrets Summer Cata',
#  'Back To Brooklyn',
#  'Trust Fall',
#  'Death Sentence London',
#  'Livewire',
#  'Captain America Mgc',
#  'Death of Love',
#  'Star Wars Lost Tribe O T Sit',
#  'Star Wars Purge Hidden Blade',
#  'Transformers Infestation',
#  'Marvel Zombies Hallowee',
#  'Quantum and Woody Must Die',
#  'Captain America Reborn',
#  'Thanos Final Treat',
#  'Ragman Suit of Souls',
#  'Transformers Salvatio',
#  'Capt Action Cat',
#  'No 1 With a Bullet',
#  'Foolkiller',
#  'Criminal Macabre Final Night',
#  'Iron Man 1.5',
#  'Marvels Avengers Prelude Fury',
#  'James Bond Moneypenny One Sho',
#  'Marvel Tales Thanos',
#  'Curse of the Brimstone',
#  'The Shadow',
#  'Punisher Leg',
#  'James Bond Solstice One Sho',
#  'Forgotten Queen',
#  'Vile',
#  'Time Lincoln Apocalypse Mao O',
#  'Chew #13 2nd Ptg (Mr) (Pp',
#  'Chip',
#  'Ash Vs Aod',
#  'True Believers Kirby 100th Ni',
#  'DC Retroactive Batman the 80',
#  'Dollface',
#  'Batwing Futures End',
#  'Star Trek Discovery Captain S',
#  'Star Trek Discovery Annual 20',
#  'Silencer Annual',
#  'DC House of Horror',
#  'Chaos Bad Kitty One Sho',
#  'Teen Titans Go To the Movies',
#  'Tiny Titans Little Archie',
#  'True Believers Kirby 100th Av',
#  'Time Lincoln Fists of Fuhrer',
#  'Dodge City',
#  'DC Comics Presents Young Just',
#  'DC Retroactive Superman the 8',
#  'Superman #23.1 Bizarro',
#  'Criminal Macabre No Peace Fo',
#  'Donald Duck and Friends',
#  'Dejah of Mars',
#  'Bloodlines',
#  'Van Helsing Vs Robyn Hood',
#  'Star Trek Annual 201',
#  'Dantes Inferno',
#  'Double Jumpers',
#  'Daredevil Black and White',
#  'Blood Realm',
#  'Transformers Requiem of the W',
#  'True Believers What If the F',
#  'True Believers Phoenix Bizarr',
#  'Danger Girl Revolver',
#  'Super Secret Crisis War Grim',
#  'War Is Hell',
#  'Dejah Thoris',
#  'Doodle Jump',
#  'Six Pack and Dogwelder Hard Tra',
#  'True Believers What If Spider',
#  'Spitfire',
#  'Deep Sea One Sho',
#  'Chasing the Dead',
#  'Danger Girl Renegade',
#  'Spider-Man Homecoming Prelud',
#  'Batman Arkham Knight Robin Sp',
#  'Spirit Hunters',
#  'Dr Mirage Second Lives',
#  'Colonized',
#  'September Mourning VOL 0',
#  'Super Heroes',
#  'Deadlands Massacre At Red Win',
#  'Thor Crown of Fools',
#  'True Believers What If Alien',
#  'Catalyst Prime Incidentals',
#  'The Unmentionables (One Shot',
#  'Clue Candlestick',
#  'Clown Fatale',
#  'True Believers What If Avenge',
#  'Snake Eyes Ongoing (Idw)',
#  'Book of Death Legends of Geom',
#  'Ditko Monsters (C: 0-1-2',
#  'Crow Skinning the Wolves',
#  'Divinica',
#  'Shadowhawk',
#  'Source',
#  'Black Racer and Shilo Norman Sp',
#  'Cable and Deadpool Mgc',
#  'Theater',
#  'True Believers Iron Fist By T',
#  'Strayer',
#  'Solar Flare',
#  'Think Tank Military Dossier',
#  'Think Tank VOL 5',
#  'True Believers Avengers Gathe',
#  'Stranger Things Six',
#  'True Believers Avengers Roni',
#  'Comics Comics Quarterly',
#  'Shaft Imitation of Life',
#  'DC Beach Blanket Bad Guys Spe',
#  'Shadowman End Times',
#  'Twilight Zone Shadow',
#  'Sombra',
#  'True Believers Avengers Storm',
#  'Black Panther Prelude',
#  'Tomorrowland',
#  'Black Lightning Cold Dead Han',
#  'Uncanny X-Force Apocalypse So',
#  'Tom Clancy Splinter Cell Echo',
#  'Day Men Pen and Ink',
#  'Cavewoman Cover Gallery',
#  'DC Comics Presents Son of Sup',
#  'DC Comics Presents Superman D',
#  'Cavewoman Hunt',
#  'Solar Man of the Atom',
#  'Doctor Who Classics Series I',
#  'Star Wars Orig Marvel Yrs',
#  'Cavewoman Natural Selection',
#  'Cavewoman Night Out One-Sho',
#  'Star Trek New Visions Cry Ven',
#  'Star Trek Movie Adaptation',
#  'Avengers Origins Ant-Man and',
#  'Cinderella Serial Killer Prin',
#  'Doctor Who Supremacy of the C',
#  'DC Comics Presents Legion Sup',
#  'Suicide Squad War Crimes Spec',
#  'True Believers Deadpool Deadp',
#  'Borderlands Origins',
#  'Black Hops Usa Gi',
#  'Trio',
#  'Suicide Squad Annual',
#  'Shadow Annual 201',
#  ...]

# %% [markdown]
# ## It's the Scraping.

# %%
# for title in sample_titles:
# #     print(title)
cs.scrape_series_covers(browser, titles_searching)
# Out:
# Scraped 0.DC Comics Presents the Metal!
# Scraped 1.Onslaught Unleashed!
# Scraped 2.Star Trek Year Five!
# Scraped 3.Web of Venom Cult of Carnage!
# 4.All Star Section 8 was skipped. No title matched.
# Scraped 5.Klaus and Crying Snowman!
# 6.68 Last Rights was skipped. No title matched.
# Scraped 7.DC Comics Presents Green Lant!
# Scraped 8.Oberon!
# Scraped 9.Axis Hobgoblin!
# 10.Emily and the Strangers Breakin was skipped. No title matched.
# Scraped 11.Pantha!
# 12.Star Wars Aor Anakin Skywalke was skipped. No title matched.
# 13.Black Af Widows and Orphans was skipped. No title matched.
# Scraped 14.Kull Eternal!
# Scraped 15.Savage Skullkickers!
# Scraped 16.Peter Parker!
# Scraped 17.Spider-Women Omega!
# Scraped 18.Aphrodite IX Hidden Files!
# Scraped 19.Gwar Orgasmageddon!
# Scraped 20.Fall of Hulks Savage She-Hulk!
# Scraped 21.Muppet King Arthur!
# 22.DC Comics Presents J H Willia was skipped. No title matched.
# 23.Agent Carter Shield 50th Anni was skipped. No title matched.
# 24.Sinestro Annual was skipped. No title matched.
# Scraped 25.Wwe Then Now Forever!
# Scraped 26.New Romancer!
# 27.Msh Adventures Spider-Man Acr was skipped. No title matched.
# 28.Rodd Racer One Sho was skipped. No title matched.
# 29.Star Wars Aor Jabba the Hutt was skipped. No title matched.
# Scraped 30.Night Moves!
# 31.Now Moon Girl and Devil Dinos was skipped. No title matched.
