# %% [markdown]
# # Scraping Comic Book Covers
#
# **Goal**: Scrape comic covers so can use them as visual touchstones for users in the app.

# %% [markdown]
# ### Libraries

# %%
import psycopg2 as psql  # PostgreSQL DBs
from sqlalchemy import create_engine  # SQL helper
import pandas as pd
import requests
import random
import time
import os
import sys
# Selenium
from selenium.webdriver import Firefox
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.firefox.options import Options
options = Options()
options.headless = False

# Data storage

# %%
sys.path.append("..")

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/72/1a/97ca7494fd268835f2d2ea2c6b6ea3b7cfe271f22c2adb1ef45cf007d7f3/boto3-1.9.199-py2.py3-none-any.whl (128kB)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3)
#   Downloading https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
# Collecting s3transfer<0.3.0,>=0.2.0 (from boto3)
#   Downloading https://files.pythonhosted.org/packages/16/8a/1fc3dba0c4923c2a76e1ff0d52b305c44606da63f718d14d3231e21c51b0/s3transfer-0.2.1-py2.py3-none-any.whl (70kB)
# Collecting botocore<1.13.0,>=1.12.199 (from boto3)
#   Downloading https://files.pythonhosted.org/packages/50/f8/dbe656ee191c2d8b471a86fa07f0d37515611d865deaa034fc2b71dd71e4/botocore-1.12.199-py2.py3-none-any.whl (5.6MB)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version >= "3.4" in c:\users\werlindo\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.199->boto3) (1.24.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in c:\users\werlindo\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.199->boto3) (2.8.0)
# Requirement already satisfied: docutils<0.15,>=0.10 in c:\users\werlindo\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.199->boto3) (0.14)
# Requirement already satisfied: six>=1.5 in c:\users\werlindo\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1; python_version >= "2.7"->botocore<1.13.0,>=1.12.199->boto3) (1.12.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.9.199 botocore-1.12.199 jmespath-0.9.4 s3transfer-0.2.1

# %%
# Custom
import data_fcns as dfc
import keys as keys  # Custom keys lib
import comic_scraper as cs

# %% [markdown]
# ### Initialize Browser

# %%
driver_exe_path = os.path.join(
    os.getcwd(), 'drivers', 'geckodriver-windows.exe')

# %% [markdown]
# driver_exe_path = os.path.join(
#     os.getcwd(), 'drivers', 'geckodriver')

# %%
driver_exe_path
# Out:
# 'D:\\dropbox\\flatiron\\capstone\\comics_rx\\comrx\\dev\\drivers\\geckodriver-windows.exe'

# %% [markdown]
# ls drivers/

# %%
browser = Firefox(options=options, executable_path=driver_exe_path)
url = "http://www.comicbookdb.com/"
browser.get(url)

# %% [markdown]
# ### Make list of Titles!
#
# Get list of titles to scrape covers.

# %%
# Define path to secret
secret_path_aws = os.path.join(os.environ['HOME'], '.secret',
                               'aws_ps_flatiron.json')
secret_path_aws
# Out:
# 'C:\\Users\\werlindo\\.secret\\aws_ps_flatiron.json'

# %%
aws_keys = keys.get_keys(secret_path_aws)
user = aws_keys['user']
ps = aws_keys['password']
host = aws_keys['host']
db = aws_keys['db_name']

aws_ps_engine = ('postgresql://' + user + ':' + ps + '@' + host + '/' + db)

# Setup PSQL connection
conn = psql.connect(
    database=db,
    user=user,
    password=ps,
    host=host,
    port='5432'
)

# %%
# Instantiate cursor
cur = conn.cursor()

# %%
#  Count records.
query = """
    SELECT * from comic_trans;
"""

# %%
# Execute the query
cur.execute(query)

# %%
# Check results
temp_df = pd.DataFrame(cur.fetchall())
temp_df.columns = [col.name for col in cur.description]

# %%
temp_df.head(3)
# Out:
#    index                       publisher    item_id             title_and_num  \
# 0      2  Amaze Ink Slave Labor Graphics  DCD151935           Filler Bunny #2
# 1      3  Amaze Ink Slave Labor Graphics  DCD341726              Gargoyles #6
# 2      4  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
#
#    qty_sold           date_sold account_num                  comic_title
# 0         1 2011-08-14 18:01:03       00174           Filler Bunny (SLG)
# 1         1 2012-06-22 14:11:37       00593              Gargoyles (SLG)
# 2         1 2010-07-21 14:03:07       00226  Royal Historian of Oz (SLG)

# %%
temp_df['title'] = (temp_df['title_and_num'].apply(dfc.cut_issue_num))

# %%
temp_df.head()
# Out:
#    index                       publisher    item_id             title_and_num  \
# 0      2  Amaze Ink Slave Labor Graphics  DCD151935           Filler Bunny #2
# 1      3  Amaze Ink Slave Labor Graphics  DCD341726              Gargoyles #6
# 2      4  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
# 3      5  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
# 4      6  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
#
#    qty_sold           date_sold account_num                  comic_title  \
# 0         1 2011-08-14 18:01:03       00174           Filler Bunny (SLG)
# 1         1 2012-06-22 14:11:37       00593              Gargoyles (SLG)
# 2         1 2010-07-21 14:03:07       00226  Royal Historian of Oz (SLG)
# 3         1 2010-07-14 19:49:40       00399  Royal Historian of Oz (SLG)
# 4         1 2010-07-19 10:39:04       00237  Royal Historian of Oz (SLG)
#
#                    title
# 0           Filler Bunny
# 1              Gargoyles
# 2  Royal Historian of Oz
# 3  Royal Historian of Oz
# 4  Royal Historian of Oz

# %%
temp_df['title'] = (temp_df['title'].apply(lambda x: x.replace('&', 'and'))
                    .apply(lambda x: x.replace('?', ''))
                    .apply(lambda x: x.replace('/', ' '))
                    )

# %% [markdown]
# ### We need to track the titles that need scraping.

# %%
titles = list(temp_df['title'].unique())

# %%
ctr = ( 77 + 45 + 1318 + 1705 + 3 + 284 + 372 + 104 + 89 + 646 + 101 + 39 + 
        33 + 78 + 352 + 400 + 649
      )

# %%
ctr
# Out:
# 6295

# %%
titles_test = titles[ctr:]

# %%
titles_test
# Out:
# ['Hoax Hunters 2015',
#  'Holy F*ck',
#  'Honey Badger Adventures',
#  'Honey West',
#  'Hookjaw',
#  'Hot Lunch Special',
#  'House of Montreso',
#  'How To Be a Comic Book Artis',
#  'Hugh Howeys Wool',
#  'Humbug',
#  'Hyper Force Neo',
#  'I Mage',
#  'I Think Our Friend Dan Might',
#  'Ian Linvingstones Freeway Fig',
#  'Ian Livingstone Freeway Fight',
#  'Ian Livingstones Freeway Figh',
#  'Igloo Barbecue Global Warmin',
#  'Ignited',
#  'Ikebana (One Shot) (Mr',
#  'Immortal Brothers Green Knigh',
#  'Incursion',
#  'Indie Comics',
#  'Indie Comics Magazine',
#  'Indoctrination',
#  'Infernoct',
#  'Infinity 8',
#  'Injury',
#  'Insexts',
#  'Intrepid Escapegoat',
#  'Iron Maiden Legacy of the Bea',
#  'Is This Tomorrow (One Shot',
#  'Island 731',
#  'It Came Out On a Wednesday',
#  'It Will All Hurt',
#  'Ivar Timewalker',
#  'Jack Hammer',
#  'Jack the Lantern',
#  'Jackpot',
#  'Jade Street Protection Servic',
#  'Jaegir One Sho',
#  'Jazz Legend',
#  'Jazz Maynard',
#  'Jazz Maynard VOL 2',
#  'Jimmys Bastards',
#  'John Carpenters Asylum',
#  'Johnny Red',
#  'Jungle Comics',
#  'Jupiter Jet',
#  'Last Zombie',
#  'Justice Society of America An',
#  'Karma Police',
#  'Khaal',
#  'Killbox Chicago',
#  'Killer Groove',
#  'Killer Modus Vivendi',
#  'Kim and Kim',
#  'Kim and Kim Love Is a Battlef',
#  'King',
#  'King!',
#  'KING!',
#  'Kingdom Bum',
#  'Knights of Dinner Table',
#  'Knights of the Dinner Table',
#  'Kodt Black Hands 2010',
#  'Kodt Black Hands 2011 One Sho',
#  'Kong Skull Island Off Comic S',
#  'Konungar War of Crowns',
#  'Kung Fu Panda',
#  'La Mano Del Destino',
#  'Labyrinthectomy Luncheonette',
#  'Lady Death Extinction Expres',
#  'Lady Mechanika #0 and',
#  'Lady Mechanika #2 and',
#  'Lady Mechanika 10 Copy Incv B',
#  'Lady Mechanika Clockwork Assa',
#  'Lady Mechanika Dame Sans Merc',
#  'Lady Mechanika La Belle Dame',
#  'Lady Mechanika La Dama De La',
#  'Lady Mechanika Lost Boys of W',
#  'Lady Mechanika Main Cvrs (Mr',
#  'Lady Mechanika Sangre',
#  'Lady Mechanika Tablet of Dest',
#  'Larks Killer',
#  'Last Born',
#  'Last Song',
#  'Last Space Race',
#  'League of Extraordinary Cereb',
#  'Legend of Bold Riley',
#  'Legend of Oz the Wicked West',
#  'Lenore Volume Ii',
#  'Liberator',
#  'Liberator Earth Crisis',
#  'Liberty Comics 2010',
#  'Life and Death of Toyo Harada',
#  'Life Is Strange',
#  'Little Girl',
#  'Little Nightmares',
#  'Littlest Zombie',
#  'Live Work',
#  'Livewire',
#  'Loeg Tempest',
#  'Logans Run',
#  'Lollipop Kids',
#  'Long Live Pro Wrestling',
#  'Long Lost',
#  'Long Lost Book Two',
#  'Long Lost Part Two',
#  'Lookouts Riddle VOL 01',
#  'Lord of Gore',
#  'Lost City Explorers',
#  'Lost Fleet Corsair',
#  'Love and Aardvarks',
#  'Low Society One Sho',
#  'Lucid',
#  'Lunita',
#  'Mae VOL 2',
#  'Magical Beatdown',
#  'Magical Character Rabbit One',
#  'Malefic',
#  'Mall',
#  'Mama Tits Saves the World On',
#  'Mercy Sparx',
#  'Man Plus',
#  'Mangalicious Tick',
#  'Mary Shelley Monster Hunter',
#  'Maxwells Demons',
#  'Meanwhile',
#  'Mediterranea',
#  'Mega Ghost',
#  'Mega Man Mastermix',
#  'Mens Feelings',
#  'Metalshark Bro',
#  'Mighty Yeti One Sho',
#  'Mike Hammer',
#  'Millennium Girl Who Kicked th',
#  'Millennium Girl Who Played Wi',
#  'Millennium Girl With the Drag',
#  'Mindbender',
#  'Minions',
#  'Minions Viva Le Boss',
#  'Minky Woodcock Girl Who Handc',
#  'Miraculous',
#  'Miraculous Adventures Ladybu',
#  'Misadventures of Adam West',
#  'Misadventures of Adam West On',
#  'Misbegotten Runaway Nun',
#  'Mistry Pi',
#  'Mixtape',
#  'Mlk Montgomery Story One Sho',
#  'Mono',
#  'Monster World',
#  'Monstro Mechanica',
#  'Monty the Dinosaur',
#  'Moonstones Modern Myths Black',
#  'Moth and Whisper',
#  'Motor Girl',
#  'Mouse Guard Black Axe',
#  'Mouse Guard Legends O T Guar',
#  'Mr Crypt',
#  'Mr. Natural',
#  'Muirwood Lost Abbey',
#  'Murder Book',
#  'Namwolf',
#  'Nancy Dragon In Hell One Sho',
#  'National Comics Eternity',
#  'National Comics Looker',
#  'New Humanz',
#  'Ninjak',
#  'Ninja-K',
#  'Ninjak Vs Vu',
#  'Niobe She Is Life',
#  'No Angel',
#  'No Better Words One Shot (A)',
#  'Nobody Is In Control',
#  'Normals',
#  'Norman',
#  'Normandy Gold',
#  'North Guard',
#  'Northern Guard',
#  'Northguard',
#  'Null Faeries',
#  'Number One',
#  'Numbercruncher',
#  'Nutmeg',
#  'Nutmeg TP VOL 0',
#  'Nvrlnd',
#  'Nycc 2013 Captain America Liv',
#  'Obamous',
#  'Oberon',
#  'Obliv18n',
#  'Oblivion',
#  'Occupy Comics',
#  'Oddwell',
#  'Oh S#!t Its Kim and Kim',
#  'Okko Cycle of Air',
#  'Okko Cycle of Earth',
#  'Penny Dreadful',
#  'Once Our Land',
#  'Once Our Land Book Two',
#  'Order of Dagonet',
#  'Ordinary',
#  'Orphan Age',
#  'Outfoxed One Sho',
#  'Outliers',
#  'Oxymoron Loveliest Nightmare',
#  'Oz Wonderland Chronicles Jac',
#  'Pacific Rim Aftermath',
#  'Patience Conviction Revenge',
#  'Peek',
#  'Peek the First (One Shot)',
#  'Penguins of Madagascar',
#  'Penguins of Madagascar Elites',
#  'Penny For Your Soul',
#  'Pestilence',
#  'Pestilence Story of Satan',
#  'Pink Panther',
#  'Pink Panther Cartoon Hour Spe',
#  'Pink Panther Pink Winter Spec',
#  'Pink Panther Super Special Bl',
#  'Pink Panther Trick Or Pink',
#  'Pink Panther Vs Inspector',
#  'Pinocchio Vampire Slayer and th',
#  'Pitiful Human Lizard',
#  'Planet of Daemons',
#  'Planet of the Nerds',
#  'Plume',
#  'Political Power',
#  'Pood',
#  'Pope Hats',
#  'Power Button',
#  'Powerless',
#  'Priest Purgatory',
#  'Princeless Make Yourself',
#  'Princeless Pirate Princess',
#  'Princeless Raven Pirate Princ',
#  'Prisoner',
#  'Prometheus Eternal One Sho',
#  'Ps238',
#  'Pterodactyl Hunters In the Gi',
#  'Public Relations',
#  'Punk Mambo',
#  'Q2 Rtn Quantum and Woody',
#  'Quantum and Woody',
#  'Quantum and Woody (2017)',
#  'Quantum and Woody Goat',
#  'Quantum and Woody Must Die',
#  'Quantum Teens Are Go',
#  'Quarrys War',
#  'Queen of Bad Dreams',
#  'Queen of Vampires',
#  'Rachel Rising',
#  'Rad Erwank and Conspiracy Dog (',
#  'Rad Island (One Shot',
#  'Rai',
#  'Rai History of Valiant Univ',
#  'Raid',
#  'Ramiel Wrath of God',
#  'Rapture',
#  'Rasl',
#  'Reactor',
#  'Reassignment',
#  'Rebel',
#  'Red Dog',
#  'Reich',
#  'Reincarnation Man',
#  'Relay',
#  'Rem 8',
#  'Replacer Graphic Novell',
#  'Replica',
#  'Retailer Summit 2019 Guardian',
#  'Retailer Summit 2019 Savage A',
#  'Retailer Summit 2019 Venom',
#  'Retailer Summit 2019 War of R',
#  'Revisionist',
#  'Richelle Mead Dark Swan',
#  'Ride Southern Gothic',
#  'Riftworld Chronicles',
#  'Ritual Three Vile Decay (Mr',
#  'Rivers of London Detective St',
#  'Robot 13',
#  'Robotech',
#  'Rogues',
#  'Rogues the Burning Heart',
#  'Rogues VOL 2',
#  'Rotten',
#  'Rotten and Zomb Vs Cheerleader',
#  'Rough Riders',
#  'Rough Riders Ride Or Die',
#  'Route Des Maisons Rogues',
#  'Route Des Maisons Rouges',
#  'Sabretooth Dan',
#  'Sally O T Wasteland',
#  'Samurai',
#  'Sar',
#  'Sarah Palin Rogue Warrior On',
#  'Savage',
#  'Savants',
#  'Scab County One Sho',
#  'Schizophrenic Onesho',
#  'Science a Discovery In Comic',
#  'Scratch 9',
#  'Scratch9 Cat of Nine Worlds',
#  'Scum O T Earth',
#  'Sdcc 2011 Godzilla Gangsters',
#  'Sdcc 2014 Legendary Star Lor',
#  'Sdcc 2014 Rocket Raccoon',
#  'Sdcc 2014 Spider-Man 2099',
#  'Sdcc 2015 Civil War',
#  'Sdcc 2015 Darth Vader',
#  'Sdcc 2015 Secret Wars',
#  'Sdcc 2015 Star Wars Lando',
#  'Sdcc 2015 X-Men 92',
#  'Sdcc 2016 Civil War Ii',
#  'Sea of Thieves',
#  'Season of the Snake',
#  'Sec One Shot (Mr',
#  'Second Helping Drawing Asst M',
#  'Second Sight',
#  'Secret History Book 07 (Of 7',
#  'Secret History Book 08 (Mr',
#  'Secret History Book 09 (Mr',
#  'Secret History Book 10 (Mr',
#  'Secret History Book 11 (Mr',
#  'Secret History Book 12 (Mr',
#  'Secret History Book 13 (Mr',
#  'Secret History Book 14 (Mr',
#  'Secret History Book 15 (Mr',
#  'Secret History Book 16 (Mr',
#  'Secret History Book 17 (Mr',
#  'Secret History Book 18 (Mr',
#  'Secret History Book 19 (Mr',
#  'Secret History Book 20 (Mr',
#  'Secret Weapons',
#  'Secret Weapons Owens Story',
#  'Self Storage',
#  'Serpent Whispered',
#  'Serving Supes',
#  'Sesame Street',
#  'Sesame Street Another Sunny D',
#  'Sex Death Revolution',
#  'Shades of Magic',
#  'Shadowman',
#  'Shadowman (2018)',
#  'Shadowman (New)',
#  'Shadowman (Vu)',
#  'Shadowman End Times',
#  'Shadowman Rae Sremmurd',
#  'She Said Destroy',
#  'Shekhar Kapur Devi Rebirth',
#  'Sherlock a Study In Pink',
#  'Shipwreck',
#  'Shiver Bureau',
#  'Shonen Jump',
#  'Shonen Jump April 2010 (C: 1-',
#  'Shonen Jump April 2011 (C: 1-',
#  'Shonen Jump April 2012 (C: 1-',
#  'Shonen Jump August 2010 (C: 1',
#  'Shonen Jump August 2011 (C: 1',
#  'Shonen Jump December 2010 (C',
#  'Shonen Jump December 2011 (C',
#  'Shonen Jump February 2010 (C',
#  'Shonen Jump February 2011 (C',
#  'Shonen Jump February 2012 (C',
#  'Shonen Jump January 2011 (C:',
#  'Shonen Jump January 2012 (C:',
#  'Shonen Jump July 2010 (C: 1-1',
#  'Shonen Jump June 2010 (C: 1-1',
#  'Shonen Jump June 2011 (C: 1-1',
#  'Shonen Jump March 2011 (C: 1-',
#  'Shonen Jump May 2010 (C: 1-1-',
#  'Shonen Jump May 2011 (C: 1-1-',
#  'Shonen Jump November 2010 (C',
#  'Shonen Jump October 09 (C: 1-',
#  'Shonen Jump October 2010 (C:',
#  'Shonen Jump October 2011 (C:',
#  'Shonen Jump September 2010 (C',
#  'Shonen Jump September 2011 (C',
#  'Shrek',
#  'Sim City',
#  'Sim City Iss After and Teenage',
#  'Sink',
#  'Sip (Strangers In Paradise) K',
#  'Siren School One Sho',
#  'Six',
#  'Skeleton Story',
#  'Skeptics',
#  'Skip To the End',
#  'Skull Island Birth of Kong',
#  'Sky Doll Sudra',
#  'Slasher',
#  'Sleeper Ca',
#  'Sleigher Heavy Metal Santa Cl',
#  'Snap Flash Hustle',
#  'Solar Flare',
#  'Solar Flare Season 2',
#  'Solar Flare Season Three',
#  'Solar Flare: Season Two',
#  'Solid State Tank Girl',
#  'Songs For the Dead',
#  'Sonitus',
#  'Source',
#  'Southern Dog',
#  'Space Riders',
#  'Space Riders Galaxy of Brutal',
#  'Spencer and Locke',
#  'Spirit Collectors Se',
#  'Spirit Leaves',
#  'Spiritus',
#  'Spookhouse',
#  'Spookhouse 2',
#  'Squarriors',
#  'Squarriors VOL 02 Summer',
#  'Srg Presents Wolves of Odin O',
#  'Ssb Ii Polybagged Ed (Mr',
#  'Stabbity Bunny',
#  'Stained',
#  'Stargate Atlantis Singularit',
#  'Stargate Universe',
#  'Stargate Universe Back To Des',
#  'Starring Sonya Devereaux',
#  'Steam Wars',
#  'Steamcraft',
#  'Steampunk Palin One-Sho',
#  'Steampunk Snow White One Sho',
#  'Stiletto',
#  'Strange Aeons',
#  'Strange Cerebus',
#  'Strangers In Paradise Xxv',
#  'Strayer',
#  'Street Fighter Ii Turbo',
#  'Street Fighter Legends Cammy',
#  'Street Fighter Swimsuit Speci',
#  'Street Fighter Unlimited',
#  'Street Fighter Vs Darkstalker',
#  'Street Tiger',
#  'Stronghold',
#  'Stuff of Legend Jesters Tale',
#  'Stuff of Legend the Jungle',
#  'Stuff of Legend Toy Collecto',
#  'Submerged',
#  'Summit',
#  'Sunflower',
#  'Super Human Resources',
#  'Supermansion',
#  'Superzero',
#  'Survival Fetish',
#  'Survivalist One Shot (C: 0-1-',
#  'Taarna',
#  'Tales From the Crypt',
#  'Tales From the Hyperverse (On',
#  'Tales From the Suicide Fores',
#  'Tales of Fear',
#  'Tales of Tmnt',
#  'Tank Girl',
#  'Tank Girl 2 Girls 1 Tank',
#  'Tank Girl Action Alley',
#  'Tank Girl All Stars',
#  'Tank Girl Bad Wind Rising',
#  'Tank Girl Carioca',
#  'Tank Girl Full Color Classic',
#  'Tank Girl Gold',
#  'Tank Girl Skidmarks',
#  'Tank Girl World War Tank Gir',
#  'Tarot Witch of the Black Ros',
#  'Teenage Mutant Ninja Cerebi',
#  'Terra Flats',
#  'The 7 Deadly Sin',
#  'The Beautiful Death',
#  'The Beautiful Death (Statix)',
#  'The Castoffs',
#  'The Dregs',
#  'The Forevers',
#  'The Mummy',
#  'The Skeptics',
#  'The Troll (One Shot',
#  'The Unmentionables (One Shot',
#  'The Valiant',
#  'The Willows One Sho',
#  'The XII',
#  'Theres Nothing There',
#  'These Savage Shores',
#  'Thin',
#  'This Love So Brief One Sho',
#  'Three O Clock Club',
#  'Three Stooges Boys Are Back',
#  'Three Stooges Red White and Sto',
#  'Three Stooges Stoogeapalooza',
#  'Tick',
#  'Tick 2017',
#  'Tick Edlund Epic',
#  'Time Lincoln Apocalypse Mao O',
#  'Time Lincoln Cuba Commander O',
#  'Time Lincoln Fists of Fuhrer',
#  'Time Lincoln Jack To the Futu',
#  'Time Lincoln One Sho',
#  'Tinkers of the Wasteland',
#  'Tinseltown',
#  'Titan',
#  'Tomorrowland',
#  'Torchwood',
#  'Torchwood 2',
#  'Tower Chronicles Dreadstalke',
#  'Town Called Dragon',
#  'Trancers',
#  'Transference',
#  'Transformers Timelines',
#  'True Stories',
#  'Trust Fall',
#  'Turnbuckle Titans',
#  'Un-Bedable Vark',
#  'Undateable Cerebus',
#  'Under (Statix)',
#  'Unholy Grail',
#  'Unity',
#  'Unlikely Trio Last Barn On th',
#  'Untamed Ii',
#  'Vagrant Queen',
#  'Valiant One Dollar Debut Bund',
#  'Vampblade',
#  'Vampblade Season 3',
#  'Vampblade Season Two',
#  'Vampire Hunter D Message Mar',
#  'Vargav One Shot (C: 0-1-1',
#  'Vark Knight Returns',
#  'Victorian Secret 2013 Summer',
#  'Victorian Secrets Summer Cata',
#  'Viewotron (Mr',
#  'Vikings',
#  'Vile',
#  'Violence Valley One Sho',
#  'Volition',
#  'Voltron Legendary Defender',
#  'Voltron Legendary Defender VO',
#  'Voracious',
#  'Vu Handbook 2014 One Dollar D',
#  'Wakfu',
#  'Walk Through Hell',
#  'War Mother',
#  'War of the Independents',
#  'Warhammer 40000 Dawn of War I',
#  'Warhammer 40000 Deathwatch',
#  'Warhammer Dawn of War',
#  'Wasted Space',
#  'Watchvark',
#  'We Are Danger',
#  'We Can Never Go Home',
#  'Weed Magic',
#  'Welcome To Paradise',
#  'Welcome To Showside',
#  'Wes Craven Coming of Rage',
#  'Westwood Witches',
#  'What Is a Glacier (One Shot)',
#  'Whispers In Walls',
#  'White',
#  'White Clay One Sho',
#  'Wilds',
#  'Wonderful World of Tank Girl',
#  'World of Animosity',
#  'World Reader',
#  'Worlds Finite Cerebus',
#  'Wraithborn',
#  'Wrapped Up',
#  'Wrath of the Eternal Warrior',
#  'Wrath of the Titans Revenge',
#  'Wwe Ongoing',
#  'Xed',
#  'X-O Manowar',
#  'X-O Manowar (2017)',
#  'X-O Manowar (2017) (New Arc)',
#  'X-O Manowar (Ongoing)',
#  'X-O Manowar (Ongoing) 2nd Pt',
#  'X-O Manowar (Vu)',
#  'X-O Manowar 25th Ann Special',
#  'Yankee',
#  'Yi Soon Shin',
#  'You Can Try Again One Shot (M',
#  'Young Terrorists',
#  'Zen Hard Bounty',
#  'Zero Jumper',
#  'Zinnober',
#  'Zoe Dare Vs Disasteroid',
#  'Zojaqan',
#  'Zombie Tramp 2017 Easter Spec',
#  'Zombie Tramp Halloween 2016 S',
#  'Zombie Tramp Halloween Sp On',
#  'Zombie Tramp New Years Eve 20',
#  'Zombie Tramp Ongoing',
#  'Zombie Tramp Origins',
#  'Zombie Tramp Vd Special One S',
#  'Zombie Tramp VOL 2',
#  'Zombie Tramp Vs Vampblade',
#  'Zombie Tramp Xxxmas Special A',
#  'Zombie Tramp Xxxmas Special M',
#  'Zombie Tramp Xxxmas Special R',
#  'Zombie Tramp Xxxmas Special T',
#  'Abattoir',
#  'After Dark',
#  'Coil Damaged Flip Boo',
#  'Damaged',
#  'Driver For the Dead',
#  'Fvza',
#  'Hotwire Deep Cut',
#  'Last Days of American Crime',
#  'Radical Premiere Mata Har',
#  'Rising',
#  'Ryder On the Storm',
#  'Time Bomb',
#  'After Eden',
#  'Atomic Robo Deadly Art of Sci',
#  'Atomic Robo Dogs of War',
#  'Atomic Robo Flying She Devil',
#  'Atomic Robo Ghost of Station',
#  'Atomic Robo Knights O T Golde',
#  'Atomic Robo Real Science Adv',
#  'Atomic Robo Revenge O T Vampi',
#  'Atomic Robo Savage Sword of D',
#  'Atomic Robo Shadow From Beyon',
#  'Bad Dreams',
#  'Bodie Troll',
#  'Chasing Hitler',
#  'Dead Or Alive',
#  'Foster Broussard',
#  'Haunted',
#  'Haunted Other Side',
#  'Kulipari Heritage',
#  'Moon Girl',
#  'Neozoic Traders Gambit',
#  'Rift',
#  'Riptide',
#  'Seven Percent',
#  'Zmd Zombies of Mass Destructi',
#  'Fcbd 2015 Motorcycle Samura',
#  'Aliens Vs Zombies',
#  'Bar Maid',
#  'Belle Beast Hunter',
#  'Black Sable',
#  'Brimstone',
#  'Charmed',
#  'Charmed Season 10',
#  'Cinderella Serial Killer Prin',
#  'Conspiracy',
#  'Conspiracy the Illuminati',
#  'Courier',
#  'Death Force',
#  'Escape From Wonderland',
#  'Evil Heroes',
#  'Gft 2013 Holiday Special a Cv',
#  'Gft 2015 Robyn Hood Holiday S',
#  'Gft 2016 Photo Shoot Cvr C Ri',
#  'Gft Alice 10th Anniversary Sp',
#  'Gft Animated Series One Shot',
#  'Gft Annual 2013 a Cvr Qualan',
#  'Gft Wonderland Birth of Madne',
#  'Gft Wonderland Clash of Queen',
#  'Gft Wonderland Down Rabbit Ho',
#  'Gft Wonderland Ongoing Epilog',
#  'Gft Wonderland Ttlg',
#  'Gft Zombies Cursed',
#  'Giant Size Gft 2012 B Cvr Rey',
#  'Giant-Size Gft 2009 Holiday E',
#  'Giant-Size Gft 2010 Holiday E',
#  'Giant-Size Gft 2011 Holiday E',
#  'Giant-Size Gft 2011 Sinbad a',
#  'Giant-Size Gft 2012 a Cvr Myc',
#  'Grimm Fairy Tales',
#  'Grimm Fairy Tales 2017 Holida',
#  'Grimm Fairy Tales 2018 Holida',
#  'Grimm Fairy Tales 2019 Annua',
#  'Grimm Fairy Tales Annual 201',
#  'Grimm Fairy Tales Annual Las',
#  'Hellchild Inferno One Shot',
#  'Hellchild the Unholy',
#  'Hit List',
#  'Hollywood Zombie Apocalypse',
#  'Jasmine Crown of Kings',
#  'Musketeers',
#  'Revenge of Wonderland',
#  'Robyn Hood the Curse',
#  'Salems Daughter',
#  'Science Fiction and Fantasy Ill',
#  'Screwed',
#  'Spirit Hunters',
#  'Tales From Neverland',
#  'Tfw Red Rose Oneshot a Cvr Qu',
#  'Tfw White Knight Oneshot a Cv',
#  'Theater',
#  'Van Helsing Vs Robyn Hood',
#  'Van Helsing Vs the Werewolf',
#  'Zodiac']

# %%
cs.scrape_series_covers(browser, titles_test)
# Out:
# 0.Hoax Hunters 2015 was skipped. No title matched.
# 1.Holy F*ck was skipped. No covers were found.
# 2.Honey Badger Adventures was skipped. No title matched.
# Scraped 3.Honey West!
# 4.Hookjaw was skipped. No title matched.
# Scraped 5.Hot Lunch Special!
# Scraped 6.House of Montreso!
# Scraped 7.How To Be a Comic Book Artis!
# 8.Hugh Howeys Wool was skipped. No title matched.
# Scraped 9.Humbug!
# Scraped 10.Hyper Force Neo!
# Scraped 11.I Mage!
# 12.I Think Our Friend Dan Might was skipped. No title matched.
# 13.Ian Linvingstones Freeway Fig was skipped. No title matched.
# Scraped 14.Ian Livingstone Freeway Fight!
# 15.Ian Livingstones Freeway Figh was skipped. No title matched.
# 16.Igloo Barbecue Global Warmin was skipped. No title matched.
# 17.Ignited was skipped. No covers were found.
# 18.Ikebana (One Shot) (Mr was skipped. No title matched.
# Scraped 19.Immortal Brothers Green Knigh!
# Scraped 20.Incursion!
# Scraped 21.Indie Comics!
# Scraped 22.Indie Comics Magazine!
# Scraped 23.Indoctrination!
# 24.Infernoct was skipped. No covers were found.
# Scraped 25.Infinity 8!
# Scraped 26.Injury!
# Scraped 27.Insexts!
# Scraped 28.Intrepid Escapegoat!
# Scraped 29.Iron Maiden Legacy of the Bea!
# 30.Is This Tomorrow (One Shot was skipped. No title matched.
# Scraped 31.Island 731!
# Scraped 32.It Came Out On a Wednesday!
# Scraped 33.It Will All Hurt!
# Scraped 34.Ivar Timewalker!
# Scraped 35.Jack Hammer!
# Scraped 36.Jack the Lantern!
# Scraped 37.Jackpot!
# Scraped 38.Jade Street Protection Servic!
# 39.Jaegir One Sho was skipped. No title matched.
# Scraped 40.Jazz Legend!
# Scraped 41.Jazz Maynard!
# 42.Jazz Maynard VOL 2 was skipped. No title matched.
# 43.Jimmys Bastards was skipped. No title matched.
# 44.John Carpenters Asylum was skipped. No title matched.
# Scraped 45.Johnny Red!
# Scraped 46.Jungle Comics!
# Scraped 47.Jupiter Jet!
# Scraped 48.Last Zombie!
# 49.Justice Society of America An was skipped. No title matched.
# 50.Karma Police was skipped. No title matched.
# Scraped 51.Khaal!
# 52.Killbox Chicago was skipped. No title matched.
# Scraped 53.Killer Groove!
# 54.Killer Modus Vivendi was skipped. No covers were found.
# Scraped 55.Kim and Kim!
# 56.Kim and Kim Love Is a Battlef was skipped. No title matched.
# Scraped 57.King!
# 58.King! was skipped. No covers were found.
# 59.KING! was skipped. No covers were found.
# Scraped 60.Kingdom Bum!
# Scraped 61.Knights of Dinner Table!
# Scraped 62.Knights of the Dinner Table!
# 63.Kodt Black Hands 2010 was skipped. No title matched.
# 64.Kodt Black Hands 2011 One Sho was skipped. No title matched.
# 65.Kong Skull Island Off Comic S was skipped. No title matched.
# 66.Konungar War of Crowns was skipped. No title matched.
# Scraped 67.Kung Fu Panda!
# Scraped 68.La Mano Del Destino!
# 69.Labyrinthectomy Luncheonette was skipped. No title matched.
# Scraped 70.Lady Death Extinction Expres!
# Scraped 71.Lady Mechanika #0 and!
# Scraped 72.Lady Mechanika #2 and!
# 73.Lady Mechanika 10 Copy Incv B was skipped. No title matched.
# Scraped 74.Lady Mechanika Clockwork Assa!
# Scraped 75.Lady Mechanika Dame Sans Merc!
# Scraped 76.Lady Mechanika La Belle Dame!
# Scraped 77.Lady Mechanika La Dama De La!
# Scraped 78.Lady Mechanika Lost Boys of W!
# 79.Lady Mechanika Main Cvrs (Mr was skipped. No title matched.
# Scraped 80.Lady Mechanika Sangre!
# Scraped 81.Lady Mechanika Tablet of Dest!
# 82.Larks Killer was skipped. No title matched.
# Scraped 83.Last Born!
# Scraped 84.Last Song!
# Scraped 85.Last Space Race!
# Scraped 86.League of Extraordinary Cereb!
# Scraped 87.Legend of Bold Riley!
# Scraped 88.Legend of Oz the Wicked West!
# 89.Lenore Volume Ii was skipped. No title matched.
# Scraped 90.Liberator!
# Scraped 91.Liberator Earth Crisis!
# 92.Liberty Comics 2010 was skipped. No title matched.
# Scraped 93.Life and Death of Toyo Harada!
# Scraped 94.Life Is Strange!
# Scraped 95.Little Girl!
# Scraped 96.Little Nightmares!
# Scraped 97.Littlest Zombie!
# 98.Live Work was skipped. No title matched.
# Scraped 99.Livewire!
# 100.Loeg Tempest was skipped. No title matched.
# 101.Logans Run was skipped. No title matched.
# Scraped 102.Lollipop Kids!
# 103.Long Live Pro Wrestling was skipped. No title matched.
# Scraped 104.Long Lost!
# 105.Long Lost Book Two was skipped. No title matched.
# 106.Long Lost Part Two was skipped. No title matched.
# 107.Lookouts Riddle VOL 01 was skipped. No title matched.
# Scraped 108.Lord of Gore!
# Scraped 109.Lost City Explorers!
# 110.Lost Fleet Corsair was skipped. No title matched.
# Scraped 111.Love and Aardvarks!
# 112.Low Society One Sho was skipped. No title matched.
# Scraped 113.Lucid!
# Scraped 114.Lunita!
# 115.Mae VOL 2 was skipped. No title matched.
# Scraped 116.Magical Beatdown!
# 117.Magical Character Rabbit One was skipped. No title matched.
# Scraped 118.Malefic!
# 119.Mall was skipped. No covers were found.
# 120.Mama Tits Saves the World On was skipped. No title matched.
# Scraped 121.Mercy Sparx!
# Scraped 122.Man Plus!
# Scraped 123.Mangalicious Tick!
# Scraped 124.Mary Shelley Monster Hunter!
# 125.Maxwells Demons was skipped. No title matched.
# Scraped 126.Meanwhile!
# Scraped 127.Mediterranea!
# Scraped 128.Mega Ghost!
# Scraped 129.Mega Man Mastermix!
# 130.Mens Feelings was skipped. No title matched.
# Scraped 131.Metalshark Bro!
# 132.Mighty Yeti One Sho was skipped. No title matched.
# Scraped 133.Mike Hammer!
# 134.Millennium Girl Who Kicked th was skipped. No covers were found.
# 135.Millennium Girl Who Played Wi was skipped. No covers were found.
# Scraped 136.Millennium Girl With the Drag!
# Scraped 137.Mindbender!
# Scraped 138.Minions!
# Scraped 139.Minions Viva Le Boss!
# Scraped 140.Minky Woodcock Girl Who Handc!
# Scraped 141.Miraculous!
# 142.Miraculous Adventures Ladybu was skipped. No title matched.
# 143.Misadventures of Adam West was skipped. No title matched.
# 144.Misadventures of Adam West On was skipped. No title matched.
# 145.Misbegotten Runaway Nun was skipped. No covers were found.
# 146.Mistry Pi was skipped. No title matched.
# Scraped 147.Mixtape!
# 148.Mlk Montgomery Story One Sho was skipped. No title matched.
# Scraped 149.Mono!
# Scraped 150.Monster World!
# Scraped 151.Monstro Mechanica!
# Scraped 152.Monty the Dinosaur!
# 153.Moonstones Modern Myths Black was skipped. No title matched.
# 154.Moth and Whisper was skipped. No title matched.
# Scraped 155.Motor Girl!
# Scraped 156.Mouse Guard Black Axe!
# Scraped 157.Mouse Guard Legends O T Guar!
# Scraped 158.Mr Crypt!
# Scraped 159.Mr. Natural!
# Scraped 160.Muirwood Lost Abbey!
# 161.Murder Book was skipped. No covers were found.
# 162.Namwolf was skipped. No covers were found.
# 163.Nancy Dragon In Hell One Sho was skipped. No title matched.
# Scraped 164.National Comics Eternity!
# Scraped 165.National Comics Looker!
# Scraped 166.New Humanz!
# Scraped 167.Ninjak!
# 168.Ninja-K was skipped. No title matched.
# 169.Ninjak Vs Vu was skipped. No title matched.
# Scraped 170.Niobe She Is Life!
# Scraped 171.No Angel!
# 172.No Better Words One Shot (A) was skipped. No title matched.
# Scraped 173.Nobody Is In Control!
# Scraped 174.Normals!
# Scraped 175.Norman!
# Scraped 176.Normandy Gold!
# Scraped 177.North Guard!
# Scraped 178.Northern Guard!
# Scraped 179.Northguard!
# Scraped 180.Null Faeries!
# Scraped 181.Number One!
# Scraped 182.Numbercruncher!
# Scraped 183.Nutmeg!
# 184.Nutmeg TP VOL 0 was skipped. No title matched.
# Scraped 185.Nvrlnd!
# 186.Nycc 2013 Captain America Liv was skipped. No title matched.
# Scraped 187.Obamous!
# Scraped 188.Oberon!
# 189.Obliv18n was skipped. No title matched.
# Scraped 190.Oblivion!
# Scraped 191.Occupy Comics!
# 192.Oddwell was skipped. No title matched.
# Scraped 193.Oh S#!t Its Kim and Kim!
# Scraped 194.Okko Cycle of Air!
# 195.Okko Cycle of Earth was skipped. No covers were found.
# Scraped 196.Penny Dreadful!
# Scraped 197.Once Our Land!
# 198.Once Our Land Book Two was skipped. No title matched.
# Scraped 199.Order of Dagonet!
# Scraped 200.Ordinary!
# Scraped 201.Orphan Age!
# 202.Outfoxed One Sho was skipped. No title matched.
# Scraped 203.Outliers!
# Scraped 204.Oxymoron Loveliest Nightmare!
# Scraped 205.Oz Wonderland Chronicles Jac!
# Scraped 206.Pacific Rim Aftermath!
# Scraped 207.Patience Conviction Revenge!
# 208.Peek was skipped. No covers were found.
# 209.Peek the First (One Shot) was skipped. No title matched.
# Scraped 210.Penguins of Madagascar!
# 211.Penguins of Madagascar Elites was skipped. No title matched.
# Scraped 212.Penny For Your Soul!
# Scraped 213.Pestilence!
# Scraped 214.Pestilence Story of Satan!
# Scraped 215.Pink Panther!
# Scraped 216.Pink Panther Cartoon Hour Spe!
# Scraped 217.Pink Panther Pink Winter Spec!
# 218.Pink Panther Super Special Bl was skipped. No title matched.
# Scraped 219.Pink Panther Trick Or Pink!
# Scraped 220.Pink Panther Vs Inspector!
# Scraped 221.Pinocchio Vampire Slayer and th!
# Scraped 222.Pitiful Human Lizard!
# 223.Planet of Daemons was skipped. No title matched.
# Scraped 224.Planet of the Nerds!
# 225.Plume was skipped. No covers were found.
# Scraped 226.Political Power!
# Scraped 227.Pood!
# Scraped 228.Pope Hats!
# Scraped 229.Power Button!
# Scraped 230.Powerless!
# Scraped 231.Priest Purgatory!
# Scraped 232.Princeless Make Yourself!
# Scraped 233.Princeless Pirate Princess!
# Scraped 234.Princeless Raven Pirate Princ!
# Scraped 235.Prisoner!
# 236.Prometheus Eternal One Sho was skipped. No title matched.
# Scraped 237.Ps238!
# Scraped 238.Pterodactyl Hunters In the Gi!
# Scraped 239.Public Relations!
# Scraped 240.Punk Mambo!
# 241.Q2 Rtn Quantum and Woody was skipped. No title matched.
# Scraped 242.Quantum and Woody!
# 243.Quantum and Woody (2017) was skipped. No title matched.
# 244.Quantum and Woody Goat was skipped. No title matched.
# Scraped 245.Quantum and Woody Must Die!
# Scraped 246.Quantum Teens Are Go!
# 247.Quarrys War was skipped. No title matched.
# Scraped 248.Queen of Bad Dreams!
# 249.Queen of Vampires was skipped. No covers were found.
# Scraped 250.Rachel Rising!
# 251.Rad Erwank and Conspiracy Dog ( was skipped. No title matched.
# 252.Rad Island (One Shot was skipped. No title matched.
# Scraped 253.Rai!
# Scraped 254.Rai History of Valiant Univ!
# Scraped 255.Raid!
# Scraped 256.Ramiel Wrath of God!
# 257.Rapture was skipped. No covers were found.
# Scraped 258.Rasl!
# Scraped 259.Reactor!
# 260.Reassignment was skipped. No title matched.
# Scraped 261.Rebel!
# Scraped 262.Red Dog!
# Scraped 263.Reich!
# Scraped 264.Reincarnation Man!
# Scraped 265.Relay!
# Scraped 266.Rem 8!
# 267.Replacer Graphic Novell was skipped. No title matched.
# Scraped 268.Replica!
# 269.Retailer Summit 2019 Guardian was skipped. No title matched.
# 270.Retailer Summit 2019 Savage A was skipped. No title matched.
# 271.Retailer Summit 2019 Venom was skipped. No title matched.
# 272.Retailer Summit 2019 War of R was skipped. No title matched.
# Scraped 273.Revisionist!
# 274.Richelle Mead Dark Swan was skipped. No covers were found.
# Scraped 275.Ride Southern Gothic!
# 276.Riftworld Chronicles was skipped. No title matched.
# 277.Ritual Three Vile Decay (Mr was skipped. No title matched.
# 278.Rivers of London Detective St was skipped. No title matched.
# Scraped 279.Robot 13!
# Scraped 280.Robotech!
# Scraped 281.Rogues!
# 282.Rogues the Burning Heart was skipped. No title matched.
# 283.Rogues VOL 2 was skipped. No title matched.
# Scraped 284.Rotten!
# 285.Rotten and Zomb Vs Cheerleader was skipped. No title matched.
# Scraped 286.Rough Riders!
# Scraped 287.Rough Riders Ride Or Die!
# 288.Route Des Maisons Rogues was skipped. No title matched.
# 289.Route Des Maisons Rouges was skipped. No covers were found.
# 290.Sabretooth Dan was skipped. No title matched.
# Scraped 291.Sally O T Wasteland!
# Scraped 292.Samurai!
# Scraped 293.Sar!
# 294.Sarah Palin Rogue Warrior On was skipped. No title matched.
# Scraped 295.Savage!
# 296.Savants was skipped. No title matched.
# 297.Scab County One Sho was skipped. No title matched.
# 298.Schizophrenic Onesho was skipped. No title matched.
# 299.Science a Discovery In Comic was skipped. No title matched.
# Scraped 300.Scratch 9!
# Scraped 301.Scratch9 Cat of Nine Worlds!
# Scraped 302.Scum O T Earth!
# 303.Sdcc 2011 Godzilla Gangsters was skipped. No title matched.
# 304.Sdcc 2014 Legendary Star Lor was skipped. No title matched.
# 305.Sdcc 2014 Rocket Raccoon was skipped. No title matched.
# 306.Sdcc 2014 Spider-Man 2099 was skipped. No title matched.
# 307.Sdcc 2015 Civil War was skipped. No title matched.
# 308.Sdcc 2015 Darth Vader was skipped. No title matched.
# 309.Sdcc 2015 Secret Wars was skipped. No title matched.
# 310.Sdcc 2015 Star Wars Lando was skipped. No title matched.
# 311.Sdcc 2015 X-Men 92 was skipped. No title matched.
# 312.Sdcc 2016 Civil War Ii was skipped. No title matched.
# Scraped 313.Sea of Thieves!
# Scraped 314.Season of the Snake!
# 315.Sec One Shot (Mr was skipped. No title matched.
# 316.Second Helping Drawing Asst M was skipped. No title matched.
# Scraped 317.Second Sight!
# 318.Secret History Book 07 (Of 7 was skipped. No title matched.
# 319.Secret History Book 08 (Mr was skipped. No title matched.
# 320.Secret History Book 09 (Mr was skipped. No title matched.
# 321.Secret History Book 10 (Mr was skipped. No title matched.
# 322.Secret History Book 11 (Mr was skipped. No title matched.
# 323.Secret History Book 12 (Mr was skipped. No title matched.
# 324.Secret History Book 13 (Mr was skipped. No title matched.
# 325.Secret History Book 14 (Mr was skipped. No title matched.
# 326.Secret History Book 15 (Mr was skipped. No title matched.
# 327.Secret History Book 16 (Mr was skipped. No title matched.
# 328.Secret History Book 17 (Mr was skipped. No title matched.
# 329.Secret History Book 18 (Mr was skipped. No title matched.
# 330.Secret History Book 19 (Mr was skipped. No title matched.
# 331.Secret History Book 20 (Mr was skipped. No title matched.
# Scraped 332.Secret Weapons!
# 333.Secret Weapons Owens Story was skipped. No title matched.
# Scraped 334.Self Storage!
# 335.Serpent Whispered was skipped. No title matched.
# Scraped 336.Serving Supes!
# Scraped 337.Sesame Street!
# Scraped 338.Sesame Street Another Sunny D!
# Scraped 339.Sex Death Revolution!
# Scraped 340.Shades of Magic!
# Scraped 341.Shadowman!
# 342.Shadowman (2018) was skipped. No title matched.
# 343.Shadowman (New) was skipped. No title matched.
# 344.Shadowman (Vu) was skipped. No title matched.
# Scraped 345.Shadowman End Times!
# Scraped 346.Shadowman Rae Sremmurd!
# Scraped 347.She Said Destroy!
# 348.Shekhar Kapur Devi Rebirth was skipped. No title matched.
# 349.Sherlock a Study In Pink was skipped. No title matched.
# Scraped 350.Shipwreck!
# Scraped 351.Shiver Bureau!
# Scraped 352.Shonen Jump!
# 353.Shonen Jump April 2010 (C: 1- was skipped. No title matched.
# 354.Shonen Jump April 2011 (C: 1- was skipped. No title matched.
# 355.Shonen Jump April 2012 (C: 1- was skipped. No title matched.
# 356.Shonen Jump August 2010 (C: 1 was skipped. No title matched.
# 357.Shonen Jump August 2011 (C: 1 was skipped. No title matched.
# 358.Shonen Jump December 2010 (C was skipped. No title matched.
# 359.Shonen Jump December 2011 (C was skipped. No title matched.
# 360.Shonen Jump February 2010 (C was skipped. No title matched.
# 361.Shonen Jump February 2011 (C was skipped. No title matched.
# 362.Shonen Jump February 2012 (C was skipped. No title matched.
# 363.Shonen Jump January 2011 (C: was skipped. No title matched.
# 364.Shonen Jump January 2012 (C: was skipped. No title matched.
# 365.Shonen Jump July 2010 (C: 1-1 was skipped. No title matched.
# 366.Shonen Jump June 2010 (C: 1-1 was skipped. No title matched.
# 367.Shonen Jump June 2011 (C: 1-1 was skipped. No title matched.
# 368.Shonen Jump March 2011 (C: 1- was skipped. No title matched.
# 369.Shonen Jump May 2010 (C: 1-1- was skipped. No title matched.
# 370.Shonen Jump May 2011 (C: 1-1- was skipped. No title matched.
# 371.Shonen Jump November 2010 (C was skipped. No title matched.
# 372.Shonen Jump October 09 (C: 1- was skipped. No title matched.
# 373.Shonen Jump October 2010 (C: was skipped. No title matched.
# 374.Shonen Jump October 2011 (C: was skipped. No title matched.
# 375.Shonen Jump September 2010 (C was skipped. No title matched.
# 376.Shonen Jump September 2011 (C was skipped. No title matched.
# Scraped 377.Shrek!
# Scraped 378.Sim City!
# 379.Sim City Iss After and Teenage was skipped. No title matched.
# Scraped 380.Sink!
# 381.Sip (Strangers In Paradise) K was skipped. No title matched.
# 382.Siren School One Sho was skipped. No title matched.
# 383.Six was skipped. No covers were found.
# Scraped 384.Skeleton Story!
# Scraped 385.Skeptics!
# Scraped 386.Skip To the End!
# Scraped 387.Skull Island Birth of Kong!
# Scraped 388.Sky Doll Sudra!
# 389.Slasher was skipped. No covers were found.
# Scraped 390.Sleeper Ca!
# Scraped 391.Sleigher Heavy Metal Santa Cl!
# Scraped 392.Snap Flash Hustle!
# Scraped 393.Solar Flare!
# 394.Solar Flare Season 2 was skipped. No title matched.
# 467.The Beautiful Death was skipped. No title matched.
# 468.The Beautiful Death (Statix) was skipped. No title matched.
# Scraped 469.The Castoffs!
# Scraped 470.The Dregs!
# Scraped 471.The Forevers!
# Scraped 472.The Mummy!
# Scraped 473.The Skeptics!
# 474.The Troll (One Shot was skipped. No title matched.
# 475.The Unmentionables (One Shot was skipped. No title matched.
# Scraped 476.The Valiant!
# 477.The Willows One Sho was skipped. No title matched.
# Scraped 478.The XII!
# 479.Theres Nothing There was skipped. No title matched.
# Scraped 480.These Savage Shores!
# Scraped 481.Thin!
# 482.This Love So Brief One Sho was skipped. No title matched.
# Scraped 483.Three O Clock Club!
# Scraped 484.Three Stooges Boys Are Back!
# 485.Three Stooges Red White and Sto was skipped. No title matched.
# 486.Three Stooges Stoogeapalooza was skipped. No title matched.
# Scraped 487.Tick!
# Scraped 488.Tick 2017!
# Scraped 489.Tick Edlund Epic!
# Scraped 490.Time Lincoln Apocalypse Mao O!
# Scraped 491.Time Lincoln Cuba Commander O!
# Scraped 492.Time Lincoln Fists of Fuhrer!
# Scraped 493.Time Lincoln Jack To the Futu!
# 494.Time Lincoln One Sho was skipped. No title matched.
# 495.Tinkers of the Wasteland was skipped. No title matched.
# 496.Tinseltown was skipped. No title matched.
# Scraped 497.Titan!
# Scraped 498.Tomorrowland!
# Scraped 499.Torchwood!
# 500.Torchwood 2 was skipped. No title matched.
# Scraped 501.Tower Chronicles Dreadstalke!
# Scraped 502.Town Called Dragon!
# 503.Trancers was skipped. No covers were found.
# 504.Transference was skipped. No covers were found.
# Scraped 505.Transformers Timelines!
# Scraped 506.True Stories!
# Scraped 507.Trust Fall!
# Scraped 508.Turnbuckle Titans!
# Scraped 509.Un-Bedable Vark!
# Scraped 510.Undateable Cerebus!
# 511.Under (Statix) was skipped. No title matched.
# Scraped 512.Unholy Grail!
# 513.Unity was skipped. No covers were found.
# 514.Unlikely Trio Last Barn On th was skipped. No title matched.
# 515.Untamed Ii was skipped. No title matched.
# Scraped 516.Vagrant Queen!
# 517.Valiant One Dollar Debut Bund was skipped. No title matched.
# Scraped 518.Vampblade!
# Scraped 519.Vampblade Season 3!
# 520.Vampblade Season Two was skipped. No title matched.
# Scraped 521.Vampire Hunter D Message Mar!
# 522.Vargav One Shot (C: 0-1-1 was skipped. No title matched.
# Scraped 523.Vark Knight Returns!
# Scraped 524.Victorian Secret 2013 Summer!
# 525.Victorian Secrets Summer Cata was skipped. No title matched.
# 526.Viewotron (Mr was skipped. No title matched.
# Scraped 527.Vikings!
# Scraped 528.Vile!
# 529.Violence Valley One Sho was skipped. No title matched.
# Scraped 530.Volition!
# 531.Voltron Legendary Defender was skipped. No title matched.
# 532.Voltron Legendary Defender VO was skipped. No title matched.
# Scraped 533.Voracious!
# 534.Vu Handbook 2014 One Dollar D was skipped. No title matched.
# Scraped 535.Wakfu!
# Scraped 536.Walk Through Hell!
# Scraped 537.War Mother!
# Scraped 538.War of the Independents!
# 539.Warhammer 40000 Dawn of War I was skipped. No title matched.
# 540.Warhammer 40000 Deathwatch was skipped. No title matched.
# 730.Gft Van Helsing Vs the Mummy was skipped. No title matched.
# 731.Gft Vs Wonderland was skipped. No title matched.
# 732.Gft Warlord of Oz was skipped. No title matched.
# 733.Gft Werewolves Hunger was skipped. No title matched.
# 734.Gft Wonderland was skipped. No title matched.
# 735.Gft Wonderland Age of Darknes was skipped. No title matched.
# 736.Gft Wonderland Annual 2010 B was skipped. No title matched.
# 737.Gft Wonderland Annual 2011 a was skipped. No title matched.
# 738.Gft Wonderland Asylum was skipped. No title matched.
# 739.Gft Wonderland Birth of Madne was skipped. No title matched.
# 740.Gft Wonderland Clash of Queen was skipped. No title matched.
# 741.Gft Wonderland Down Rabbit Ho was skipped. No title matched.
# 742.Gft Wonderland Ongoing Epilog was skipped. No title matched.
# 743.Gft Wonderland Ttlg was skipped. No title matched.
# 744.Gft Zombies Cursed was skipped. No title matched.
# 745.Giant Size Gft 2012 B Cvr Rey was skipped. No title matched.
# 746.Giant-Size Gft 2009 Holiday E was skipped. No title matched.
# 747.Giant-Size Gft 2010 Holiday E was skipped. No title matched.
# 748.Giant-Size Gft 2011 Holiday E was skipped. No title matched.
# 749.Giant-Size Gft 2011 Sinbad a was skipped. No title matched.
# 750.Giant-Size Gft 2012 a Cvr Myc was skipped. No title matched.
# Scraped 751.Grimm Fairy Tales!
# Scraped 752.Grimm Fairy Tales 2017 Holida!
# Scraped 753.Grimm Fairy Tales 2018 Holida!
# 754.Grimm Fairy Tales 2019 Annua was skipped. No title matched.
# Scraped 755.Grimm Fairy Tales Annual 201!
# 756.Grimm Fairy Tales Annual Las was skipped. No title matched.
# 757.Hellchild Inferno One Shot was skipped. No title matched.
# Scraped 758.Hellchild the Unholy!
# Scraped 759.Hit List!
# Scraped 760.Hollywood Zombie Apocalypse!
# Scraped 761.Jasmine Crown of Kings!
# Scraped 762.Musketeers!
# Scraped 763.Revenge of Wonderland!
# Scraped 764.Robyn Hood the Curse!
# 765.Salems Daughter was skipped. No title matched.
# 766.Science Fiction and Fantasy Ill was skipped. No title matched.
# Scraped 767.Screwed!
# Scraped 768.Spirit Hunters!
# Scraped 769.Tales From Neverland!
# 770.Tfw Red Rose Oneshot a Cvr Qu was skipped. No title matched.
# 771.Tfw White Knight Oneshot a Cv was skipped. No title matched.
# Scraped 772.Theater!
# Scraped 773.Van Helsing Vs Robyn Hood!
# 774.Van Helsing Vs the Werewolf was skipped. No title matched.
# Scraped 775.Zodiac!
# Total Runtime: 8699.17 seconds

# %%
titles_test

# %%
test_title = 'Vampironica'

# %%
search_title(browser, test_title)

# %%
click_first_link(browser, test_title, True)

# %%
go_cover_gallery(browser)

# %%
click_first_image(browser)

# %%
click_cover_image(browser)

# %%
    """
Find the cover image and click it!"""
cover_img_path = ('/html/body/table/tbody/tr[2]/td[3]/table/tbody/tr/' + 
                  'td/table[1]/tbody/tr[1]/td[1]/a[1]/img')

# %%
cover_img = browser.find_element_by_xpath(cover_img_path)

# %%
cover_img.click()

# %%
#    cover_img.click()
url = cover_img.get_attribute('src')

# %%
cover_img.get_attribute

# %%
print(url)

# %%
cover_box_path = '/html/body/table/tbody/tr[2]/td[3]/table/tbody/tr/td/table[1]/tbody/tr[1]/td[1]/a[1]'

cover_box = browser.find_element_by_xpath(cover_box_path)

# %%
url = cover_box.get_attribute('href')

# %%
save_large_image(browser, test_title)

# %% [markdown]
# ### Update the code to scrape the large images.

# %%
def scrape_series_covers(browser, titles):
    """Use Selenium to scrape images for comic book titles"""
    start_time = time.time()

    for idx, title in enumerate(titles):
        # Search for the title
        search_title(browser, title)
        if not no_results_found(browser):
            # Once on search results, just select first issue of results
            click_first_link(browser, title, True)

            # Go to the cover gallery of issue page
            go_cover_gallery(browser)

            # Once in cover gallery, just scrape the first image
            try:
#                 get_first_image(browser, title)
                click_first_image(browser)
                click_cover_image(browser)
                save_large_image(browser, title)
                print("Scraped {}.{}!".format(idx, title))
            except NoSuchElementException:
                print("{}.{} was skipped. No covers were found."
                      .format(idx, title))

                # Go back to homepage so can do it again!
                # go_back_home_comicbookdb(browser)
        else:
            print("{}.{} was skipped. No title matched.".format(idx, title))
            # Wait random time
            time.sleep(2 + random.random()*5)

    print('Total Runtime: {:.2f} seconds'.format(time.time() - start_time))

#     print("All done!")

# %%
def no_results_found(browser):
    """Return no result found if path fails"""
    xpath = '/html/body/table/tbody/tr[2]/td[3]'
    result = browser.find_element_by_xpath(xpath)
    return result.text == 'No results found.'

# %%
def search_title(browser, title):
    """
    Given Selenium browser obj and a comic title to search for
    Enter title into search box and Search
    """
    # Find search box and enter search text
    text_area = browser.find_element_by_id('form_search')
    text_area.send_keys(Keys.CONTROL, "a")
    text_area.send_keys(title)

    # Find Search type dropdown and make sure it says 'Title'
    search_type = Select(browser.find_element_by_name('form_searchtype'))
    search_type.select_by_value('Title')

    # Push the search button!
    sb_xpath = ('/html/body/table/tbody/tr[2]/td[1]' +
                '/table/tbody/tr[4]/td/form/input[2]')
    search_button = browser.find_element_by_xpath(sb_xpath)
    search_button.click()

# %%
def search_site(browser, title):
    """
    Given Selenium browser obj and a comic title to search for
    Enter title into search box and Search
    """
    # Find search box and enter search text
    text_area = browser.find_element_by_id('form_search')
    text_area.send_keys(Keys.CONTROL, "a")
    text_area.send_keys(title)

    # Find Search type dropdown and make sure it says 'Title'
    # Push the search button!
    sb_xpath = ('/html/body/table/tbody/tr[2]/td[1]' +
                '/table/tbody/tr[4]/td/form/input[2]')
    search_button = browser.find_element_by_xpath(sb_xpath)
    search_button.click()

# %%
def click_first_link(browser, title, title_search_flag):
    """
    Find first issue link and click it
    """
    # Find first issue link in search results
    if title_search_flag:
        x_path = '/html/body/table/tbody/tr[2]/td[3]/a[1]'
    else:
        x_path = '/html/body/table/tbody/tr[2]/td[3]/table/tbody/tr/td/a[1]'

    first_issue_link = browser.find_element_by_xpath(x_path)

    # Click
    first_issue_link.click()

# %%
def go_cover_gallery(browser):
    """
    Click on Cover Gallery button
    """
    gb_xpath = ("/html/body/table/tbody/tr[2]/td[3]/table[1]" +
                "/tbody/tr/td/a[4]/img"
                )
    gb_xpath = '//a[img/@src="graphics/button_title_covergallery.gif"]'

    gallery_btn = browser.find_element_by_xpath(gb_xpath)
    gallery_btn.click()

# %%
def click_first_image(browser):
    """
    Find first image in cover gallery and click it!
    """
    # Find first image
    first_img_path = ('/html/body/table/tbody/tr[2]/td[3]/' +
                      'table/tbody/tr[1]/td[1]/a/img')
    first_img = browser.find_element_by_xpath(first_img_path)   
    first_img.click()

def click_cover_image(browser):
    """
    Find the cover image and click it!"""
    cover_img_path = ('/html/body/table/tbody/tr[2]/td[3]/table/tbody/tr/' + 
                      'td/table[1]/tbody/tr[1]/td[1]/a[1]/img')
    cover_img = browser.find_element_by_xpath(cover_img_path)
    cover_img.click()
#     url = cover_img.get

def save_large_image(browser, title):
    """
    Assuming you are on page with large cover image, scrape it
    """
#     cover_img_path = ('/html/body/img')
#     cover_img = browser.find_element_by_xpath(cover_img_path)    

    cover_box_path = ('/html/body/table/tbody/tr[2]/td[3]/table/tbody/tr/' + 
                      'td/table[1]/tbody/tr[1]/td[1]/a[1]')
    cover_box = browser.find_element_by_xpath(cover_box_path)
    url = cover_box.get_attribute('href')
    
    # Construct path and file name
    filename = ('./raw_data/covers_large/' + title.replace(' ', '_').lower()
                + '.jpg'
                )

    # Save the file in the file/path
    scrape_image_url(url, filename)
    

def scrape_image_url(url, filename):
    """Save an image element as filename"""
    response = requests.get(url)
    img_data = response.content
    with open(filename, 'wb') as f:
        f.write(img_data)

# %%
def get_first_image(browser, title):
    """
    Find first image in cover gallery and scrape it!
    """
    # Find first image
    first_img_path = ('/html/body/table/tbody/tr[2]/td[3]/' +
                      'table/tbody/tr[1]/td[1]/a/img')
    first_img = browser.find_element_by_xpath(first_img_path)
    
    
    # Construct path and file name
    filename = ('./raw_data/covers/' + title.replace(' ', '_').lower()
                + '.jpg'
                )

    # Save the file in the file/path
    scrape_image(first_img, filename)

    return

# %%
def scrape_image(img, filename):
    """Save an image element as filename"""
    response = requests.get(img.get_attribute('src'))
    img_data = response.content
    with open(filename, 'wb') as f:
        f.write(img_data)

# %%
def go_back_home_comicbookdb(browser):
    """Go directly back to comicbookdb.com home via logolink"""
    # Find image link to go back home
    home_pg_xpath = ('/html/body/table/tbody/tr[1]/td/table/tbody' +
                     '/tr[1]/td/table/tbody/tr/td[1]/a/img')
    logo_btn = browser.find_element_by_xpath(home_pg_xpath)

    # Click!
    logo_btn.click()

# %%
sample_titles = titles[:300]

# %%
sample_titles

# %% [markdown]
# Get list, sorted by qty sold

# %%
qtys = temp_df.groupby(['title'], as_index=False).qty_sold.sum(
).sort_values(by=['qty_sold'], ascending=False)

# %%
qtys.head()

# %% [markdown]
# #### ...And scraping periodically fails. Have manually tracked the 'stopping' point.

# %%
done_titles = titles[:300]

# %%
titles_needed_df = qtys.loc[~qtys['title'].isin(done_titles)]

# %%
titles_needed_df.shape

# %%
titles_need_list = list(titles_needed_df.title.unique())

# %%
# 367+246+151
827+151+376+524+5+47+1662+3+162+155+15+295+927+143+60

# %%
new_start = 5352  # 1932

# %%
titles_searching = titles_need_list[new_start:]

# %%
titles_searching

# %% [markdown]
# ## It's the Scraping.

# %%
# for title in sample_titles:
# #     print(title)
cs.scrape_series_covers(browser, titles_searching)
