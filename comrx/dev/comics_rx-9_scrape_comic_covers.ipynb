# %% [markdown]
# # Scraping Comic Book Covers
#
# **Goal**: Scrape comic covers so can use them as visual touchstones for users in the app.

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import requests
import random
import time
import os

# Selenium
from selenium.webdriver import Firefox
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.firefox.options import Options
options = Options()
options.headless = True

# Data storage
from sqlalchemy import create_engine # SQL helper
import psycopg2 as psql #PostgreSQL DBs

# Custom
import lib.data_fcns as dfc
import lib.keys as keys  # Custom keys lib
import lib.comic_scraper as cs

# %% [markdown]
# ### Initialize Browser

# %%
browser = Firefox(options=options)
url = "http://www.comicbookdb.com/"
browser.get(url)

# %% [markdown]
# ### Make list of Titles!
#
# Get list of titles to scrape covers.

# %%
# Define path to secret
secret_path_aws = os.path.join(os.environ['HOME'], '.secret', 
                           'aws_ps_flatiron.json')
secret_path_aws
# Out:
# '/Users/werlindo/.secret/aws_ps_flatiron.json'

# %%
aws_keys = keys.get_keys(secret_path_aws)
user = aws_keys['user']
ps = aws_keys['password']
host = aws_keys['host']
db = aws_keys['db_name']

aws_ps_engine = ('postgresql://' + user + ':' + ps + '@' + host + '/' + db)

# Setup PSQL connection
conn = psql.connect(
    database=db,
    user=user,
    password=ps,
    host=host,
    port='5432'
)

# %%
# Instantiate cursor
cur = conn.cursor()

# %%
#  Count records.
query = """
    SELECT * from comic_trans;
"""

# %%
# Execute the query
cur.execute(query)

# %%
# Check results
temp_df = pd.DataFrame(cur.fetchall())
temp_df.columns = [col.name for col in cur.description]

# %%
temp_df.head(3)
# Out:
#    index                       publisher    item_id             title_and_num  \
# 0      2  Amaze Ink Slave Labor Graphics  DCD151935           Filler Bunny #2
# 1      3  Amaze Ink Slave Labor Graphics  DCD341726              Gargoyles #6
# 2      4  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
#
#    qty_sold           date_sold account_num                  comic_title
# 0         1 2011-08-14 18:01:03       00174           Filler Bunny (SLG)
# 1         1 2012-06-22 14:11:37       00593              Gargoyles (SLG)
# 2         1 2010-07-21 14:03:07       00226  Royal Historian of Oz (SLG)

# %%
temp_df['title'] = ( temp_df['title_and_num'].apply(dfc.cut_issue_num) )

# %%
temp_df.head()
# Out:
#    index                       publisher    item_id             title_and_num  \
# 0      2  Amaze Ink Slave Labor Graphics  DCD151935           Filler Bunny #2
# 1      3  Amaze Ink Slave Labor Graphics  DCD341726              Gargoyles #6
# 2      4  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
# 3      5  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
# 4      6  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
#
#    qty_sold           date_sold account_num                  comic_title  \
# 0         1 2011-08-14 18:01:03       00174           Filler Bunny (SLG)
# 1         1 2012-06-22 14:11:37       00593              Gargoyles (SLG)
# 2         1 2010-07-21 14:03:07       00226  Royal Historian of Oz (SLG)
# 3         1 2010-07-14 19:49:40       00399  Royal Historian of Oz (SLG)
# 4         1 2010-07-19 10:39:04       00237  Royal Historian of Oz (SLG)
#
#                    title
# 0           Filler Bunny
# 1              Gargoyles
# 2  Royal Historian of Oz
# 3  Royal Historian of Oz
# 4  Royal Historian of Oz

# %%
temp_df['title'] = temp_df['title'].apply(lambda x : x.replace('&' ,'and'))

# %%
titles = list(temp_df['title'].unique())

# %%
sample_titles = titles[:300]

# %%
sample_titles
# Out:
# ['Filler Bunny',
#  'Gargoyles',
#  'Royal Historian of Oz',
#  'Warlord of Io and Other Storie',
#  'Afterlife With Archie',
#  'Afterlife With Archie Magazin',
#  'Archie',
#  'Boys',
#  'Archie and Friends Double Diges',
#  'Archie and Friends Double Doubl',
#  'Archie 1941',
#  'Archie and Me Comics Digest',
#  'Archie and Me Jumbo Comics Di',
#  'Archie Collectors E',
#  'Archie Comics Annual Digest',
#  'Archie Comics Double Digest',
#  'Archie Double Digest',
#  'Archie Jumbo Comics Digest',
#  'Archie Meets Batman 66',
#  'Archie Meets Ramones One Sho',
#  'Archie Vs Sharknado One Shot',
#  'Archies',
#  'Archies Halloween Spectacula',
#  'Archies One Shot Cvr A Jaime',
#  'Archies Superteens Vs Crusade',
#  'B and V Friends Double Digest',
#  'B and V Friends Halloween Annua',
#  'B and V Friends Jumbo Comics Di',
#  'Betty and Veronica',
#  'Betty and Veronica Comics Annua',
#  'Betty and Veronica Comics Diges',
#  'Betty and Veronica Comics Doubl',
#  'Betty and Veronica Friends Fore',
#  'Betty and Veronica Holiday Annu',
#  'Betty and Veronica Jumbo Comic',
#  'Betty and Veronica Friends Fo',
#  'Betty and Veronica Vixens',
#  'Big Moose One Shot Cvr A Reg',
#  'Black Hood',
#  'Black Hood Season 2',
#  'Blossoms 666',
#  'Chilling Adv of Sabrina',
#  'Fox #1 2nd Ptg (Pp',
#  'Fox',
#  'Fox (Dark Circle)',
#  'Hangman',
#  'Josie and the Pussycats',
#  'Jughead',
#  'Jughead and Archie Comics Doubl',
#  'Jughead Hunger Vs Vampironic',
#  'Jughead the Hunger',
#  'Jughead the Hunger One Shot C',
#  'Jughead Time Police',
#  'Jugheads Double Digest',
#  'Kevin Keller',
#  'Life With Archie',
#  'Life With Archie Comic',
#  'Little Archie One Shot Cvr A',
#  'Marvel Comics Digest',
#  'Mega Man',
#  'Mega Man Worlds Unite Battle',
#  'Monster Sized Chilling Advent',
#  'Reggie and Me',
#  'Riverdale',
#  'Riverdale (Ongoing)',
#  'Riverdale Digest',
#  'Riverdale Season 3',
#  'Sabrina',
#  'Sabrina Teenage Witch',
#  'Shield (Dark Circle)',
#  'Mercury Heat',
#  'Sonic Boom',
#  'Sonic Mega Drive Next Level O',
#  'Sonic Mega Drive One Shot (C',
#  'Sonic Super Digest',
#  'Sonic Super Special Magazine',
#  'Sonic the Hedgehog',
#  'Sonic Universe',
#  'Sonic Worlds Unite Battles',
#  'Tales From Riverdale Digest',
#  'Vampironica',
#  'World of Archie Comics Doubl',
#  'World of Archie Double Diges',
#  'World of Archie Jumbo Comics',
#  'All New Fathom',
#  'All New Soulfire',
#  'Aspen Splash 2010 Swimsuit Sp',
#  'Bubblegun VOL 2',
#  'Charismagic',
#  'Charismagic Death Princess',
#  'Dead Mans Run',
#  'Executive Assistant Iris',
#  'Executive Assistant Iris VOL',
#  'Fathom',
#  'Fathom Annual',
#  'Fathom Blue Descent',
#  'Fathom Elite Saga',
#  'Fathom Kiani VOL 3',
#  'Fathom Kiani VOL 4',
#  'Fathom VOL 4',
#  'Haunted City',
#  'Jirni VOL 2',
#  'Lady Mechanika',
#  'Lady Mechanika Collected Edit',
#  'Lola Xoxo',
#  'No World',
#  'Soulfire',
#  'Soulfire Annual',
#  'Soulfire Despair',
#  'Soulfire Hope',
#  'Soulfire New World Order',
#  'Soulfire VOL 3',
#  'Soulfire VOL 4',
#  'Soulfire VOL Two',
#  'Soulfire Volume Two',
#  'Trish Out of Water',
#  'Absolution Happy Kitty Specia',
#  'Absolution Rubicon',
#  'Alan Moore Neonomicon Hornboo',
#  'Anna Mercury 2',
#  'Belladonna',
#  'Caliban',
#  'Caligula',
#  'Caligula Heart of Rome',
#  'Captain Swing',
#  'Chronicles of Wormwood Last B',
#  'Chronicles of Wormwood Lb',
#  'Chronicles of Wormwood Lb Pre',
#  'Cinema Purgatorio',
#  'Cinema Purgatorio Dlx HC',
#  'Code Pru',
#  'Crossed',
#  'Crossed Annual 2013',
#  'Crossed Annual 2014 (Mr',
#  'Crossed Badlands',
#  'Crossed Badlands Patient Zer',
#  'Crossed Dead Or Alive',
#  'Crossed Family Values',
#  'Crossed Plus 100',
#  'Crossed Plus 100 Mimic',
#  'Crossed Psycho',
#  'Crossed Psychopath',
#  'Crossed Special 2013 (Mr',
#  'Crossed Special 2013 Torture',
#  'Crossed Special 2014 (Mr',
#  'Crossed Wish You Were Here As',
#  'Dan the Unharmable',
#  'Dark Gods',
#  'Dicks',
#  'Dicks Color Ed',
#  'Do Anything VOL 0',
#  'Doktor Sleepless',
#  'Extinction Parade',
#  'Extinction Parade War',
#  'Fashion Beast',
#  'Ferals',
#  'Fevre Dream',
#  'George Rr Martin In the Hous',
#  'George Rr Martin Skin Trade',
#  'God Is Dead',
#  'God Is Dead Book of Acts Alph',
#  'God Is Dead Book of Acts Omeg',
#  'Gravel',
#  'Gravel Combat Magician',
#  'Hero Worship',
#  'Neonomicon',
#  'Night O/T Living Dead',
#  'Night O/T Living Dead 2011 An',
#  'Night O/T Living Dead Afterma',
#  'Night O/T Living Dead Death V',
#  'Night O/T Living Dead Holida',
#  'Night of the Living Dead',
#  'Providence',
#  'Providence Ltd HC Act 01 (Mr',
#  'Rover Red Charlie',
#  'Sdcc 2014 Extinction Parade W',
#  'Stitched',
#  'Streets of Glory',
#  'Supergod',
#  'Uber',
#  'Uber Invasion',
#  'Uber Special',
#  'War Stories',
#  'Wolfskin Hundredth Dream',
#  'Bart Simpson',
#  'Bart Simpson Comics',
#  'Bart Simpsons Pal Milhouse',
#  'Bart Simpsons Treehouse of Ho',
#  'Bartman`s Spectaculary Super',
#  'Chief Wiggums Felonious Funni',
#  'Comic Book Guy the Comic Boo',
#  'Duffman Adventures',
#  'Futurama Annual',
#  'Futurama Comics',
#  'Grampa Simpsons Choose Your O',
#  'Jimbo Jones',
#  'Kang and Kodos',
#  'Krusty the Clown (One Shot',
#  'Lil Homer',
#  'Malevolent Mr Burns',
#  'Mcbain',
#  'Mighty Moe Szyslak',
#  'Simpsons Comics',
#  'Professor Frink Fantastic Sci',
#  'Ralph Wiggum Comics',
#  'Sergio Aragones Funnies',
#  'Simpsons Illustrated',
#  'Simpsons Summer Shindig',
#  'Simpsons Super Spectacular',
#  'Simpsons Treehouse of Horror',
#  'Simpsons Winter Wingding',
#  'Spongebob Comics',
#  'Spongebob Comics Annual Gian',
#  'Wonderful World of Lisa Simps',
#  '3 Guns',
#  'Abbott',
#  'Abigail and the Snowman',
#  'Adv Time Banana Guard Academ',
#  'Adventure Time',
#  'Adventure Time 2013 Spoooktac',
#  'Adventure Time 2014 Annual',
#  'Adventure Time 2014 Special',
#  'Angel',
#  'Adventure Time 2015 Spoooktac',
#  'Adventure Time 2016 Spoooktac',
#  'Adventure Time 2017 Spoooktac',
#  'Adventure Time Annual',
#  'Adventure Time Beginning of E',
#  'Adventure Time Candy Capers',
#  'Adventure Time Comics',
#  'Adventure Time Fionna and Cake',
#  'Adventure Time Flip Side',
#  'Adventure Time Ice King',
#  'Adventure Time Marceline Gon',
#  'Adventure Time Marceline Scre',
#  'Adventure Time Marcy and Simon',
#  'Adventure Time Regular Show',
#  'Adventure Time Season 11',
#  'Adventure Time Summer Specia',
#  'Aliens Vs Parker',
#  'Amazing World of Gumball',
#  'Amazing World of Gumball 201',
#  'Amazing World of Gumball Gra',
#  'Americatown',
#  'Amory Wars Good Apollo',
#  'Amory Wars Iii Good Apollo',
#  'Amory Wars Keeping Secrets o',
#  'Arcadia',
#  'Avant-Guards',
#  'Backstagers',
#  'Backstagers Halloween Intermi',
#  'Baker Street Peculiars',
#  'Bee and Puppyca',
#  'Bee and Puppycat',
#  'Betrayal O/T Planet O/T Apes',
#  'Big Trouble In Little China',
#  'Big Trouble In Little China O',
#  'Big Trouble Little China Esca',
#  'Bill and Ted Go To Hell',
#  'Bill and Ted Most Triumphant Re',
#  'Bill and Ted Save the Universe',
#  'Black Badge',
#  'Black Market',
#  'Bone Parish',
#  'Boom Box 2014 Mix Tape',
#  'Boom Box 2015 Mix Tape',
#  'Boom Box 2016 Mix Tape',
#  'Brave Chef Brianna',
#  'Bravest Warriors',
#  'Bravest Warriors 2014 Annual',
#  'Bravest Warriors Paralyzed Ho',
#  'Bravest Warriors Tales Holo J',
#  'Broken World',
#  'Buffy the Vampire Slayer',
#  'Burning Fields',
#  'Butterfly',
#  'By Night',
#  'Calling Cthulhu Chronicles',
#  'Capture Creatures',
#  'Cars',
#  'Cars Radiator Springs',
#  'Cbgb',
#  'Chip N Dale Rescue Rangers',
#  'Clarence',
#  'Clive Barker Next Testament',
#  'Clive Barkers New Genesis',
#  'Clive Barkers Nightbreed',
#  'Cloaks',
#  'Cluster',
#  'Cluster #2 2nd Ptg (Pp',
#  'Coady and the Creepies',
#  'Coda',
#  'Codebreakers',
#  'Cognetic',
#  'Cold Space',
#  'Curb Stomp',
#  'Curse',
#  'Cursed Pirate Girl Special An',
#  'Dadoes Dust To Dust',
#  'Darkwing Duck']

# %% [markdown]
# Get list, sorted by qty sold

# %%
qtys = temp_df.groupby(['title'], as_index=False).qty_sold.sum().sort_values(by=['qty_sold'], ascending=False)

# %%
qtys.head()
# Out:
#                    title  qty_sold
# 553               Batman      9562
# 6700        Walking Dead      6856
# 229   Amazing Spider-Man      5828
# 5098                Saga      5542
# 5929            Superman      5197

# %%
done_titles = titles[:300]

# %%
titles_needed_df = qtys.loc[~qtys['title'].isin(done_titles)]

# %%
titles_needed_df.shape
# Out:
# (6773, 2)

# %%
titles_need_list = list(titles_needed_df.title.unique())

# %%
#367+246+151
827+151+376
# Out:
# 1354

# %%
titles_need_list[1358:]
# Out:
# ['Siege',
#  'Flashpoint Deadman and the Fl',
#  'Bat Mite',
#  'Beasts of Burden Hellboy One',
#  'Daredevil Annual',
#  'Star Wars Han Solo Imperial C',
#  'Other Dead',
#  'Forever Evil Rogues Rebellio',
#  '4 Kids Walk Into a Bank',
#  'Batman Lost',
#  'Baltimore Cult of the Red Kin',
#  'Atomic Robo Flying She Devil',
#  'Do Androids Dream Dust To Dus',
#  'Occupy Avengers',
#  'Dark Tower Gunslinger Man In',
#  'Punks the Comic',
#  'Abe Sapien Devil Does Not Jes',
#  'Abe Sapien Abyssal Plain',
#  'Shadow Year One',
#  'Superman War of the Supermen',
#  'Secret Wars Journal',
#  'Chew Warrior Chicken Poyo',
#  'Red Wolf',
#  'Kevin Smith Green Hornet',
#  'Wonder Woman Annual',
#  'Kill the Minotaur',
#  'Courtney Crumrin Ongoing',
#  'Mass Effect Foundation',
#  'Gft Red Agent',
#  'All New X-Men Annual',
#  'Artifacts',
#  'Moonstruck',
#  'Frankenstein Alive Alive',
#  'Discipline',
#  'Plastic',
#  'Garth Ennis Red Team',
#  'Fear Itself Uncanny X-Force',
#  'Resident Alien',
#  'Hellboy Buster Oakley Gets Hi',
#  'True Believers Captain Marve',
#  'Limbo',
#  'Justice League Rebirth',
#  'Star Trek Green Lantern',
#  'Kevin Smith Bionic Man',
#  'Unholy Grail',
#  'Bobs Burgers',
#  'Gamma One Shot (C: 1-0-0',
#  'Strange Science Fantasy',
#  'Age of X-Man Prisoner X',
#  'Earth 2 Annual',
#  'Black Kiss Ii',
#  'Black Knight',
#  'Death of Haggard West One Sho',
#  'Joe Golem',
#  'Mcmlxxv',
#  'Killer Modus Vivendi',
#  'Image Firsts Revival Curr Pt',
#  'Memoir',
#  'Harbinger',
#  'New Mutants Dead Souls',
#  'King City',
#  'Dark Engine',
#  'Mantle',
#  'Thanos Vs Hulk',
#  'Escape From New York',
#  'Goddess Mode',
#  'Groo Friends and Foes',
#  'Prism Stalker',
#  'Serenity Float Out One Shot',
#  'Seven To Eternity Giant Size',
#  'Symbiote Spider-Man',
#  'Green Hornet Year One',
#  'Savior',
#  'Atomic Robo Deadly Art of Sci',
#  'War of Realms War Scrolls',
#  'Journey To Star Wars Last Jed',
#  'Transformers Prime Beast Hunt',
#  'Now Black Panther',
#  'Penguin Pain and Prejudice',
#  'Gi Joe',
#  'Flashpoint the World of Flash',
#  'Doctor Strange Last Days of M',
#  'Hellboy and Bprd 1954',
#  'Shadows On the Grave',
#  'Strain Night Eternal',
#  'Men of War',
#  'Violent Love',
#  'Atlas',
#  'Convergence Justice League',
#  'Death of Wolverine Weapon X P',
#  'Material',
#  'Hellboy and Bprd 1955 Occult In',
#  'Loeg Tempest',
#  'Weatherman',
#  'Batman Odyssey VOL 2',
#  'Frostbite',
#  'Ghostbusters International',
#  'Zodiac Starforce',
#  'Criminal Sinners',
#  'Dark Knights Rising the Wild',
#  'Helena Crash',
#  'Mae',
#  'Darth Vader Annual',
#  'The Humans',
#  'True Believers Infinity Gaunt',
#  'Star Wars Screaming Citadel',
#  'Fear Agent',
#  'Knight and Squire',
#  'Jim Henson Power of Dark Crys',
#  'Itty Bitty Hellboy',
#  'Halcyon',
#  'Tmnt Dimension X',
#  'Secret Identities',
#  'Hadrians Wall',
#  'Wonder Woman Rebirth',
#  'Luke Cage',
#  'Great Ten',
#  'Tmnt Bebop and Rocksteady Destr',
#  'Will Eisner Spirit',
#  'Grrl Scouts Magic Socks',
#  'Robotech',
#  'Go-Bots',
#  'Flashpoint Hal Jordan',
#  'Angela Queen of Hel',
#  'Buzzard',
#  'Unstoppable Wasp',
#  'Lookouts Riddle VOL 01',
#  'Civil War Ii Amazing Spider-M',
#  'All New Doop',
#  'Aquaman Annual',
#  'John Byrne Next Men',
#  'Star Wars Special C-3po',
#  'Slots',
#  'Pestilence',
#  'Mera Queen of Atlantis',
#  'Joyride',
#  'Spider-Girls',
#  'Motor Crush',
#  'Billy the Kid Ghastly Fiend L',
#  'Convergence Green Lantern Par',
#  'Dark Tower Battle',
#  'Darth Maul',
#  'Harley Quinn and Suicide Squad',
#  'Faith (Ongoing)',
#  'Lantern City',
#  'Suicide Squad Most Wanted Dea',
#  'Star Trek Vs Transformers',
#  'Injustice Vs the Masters of t',
#  'Marvel Team-Up',
#  'Motherlands',
#  'Bullet To the Head',
#  'Minimum Wage',
#  'Heroic Age Prince of Power',
#  'Hunt For Wolverine Claws of K',
#  'Magnus Robot Fighter',
#  'Midnighter and Apollo',
#  'Red Hood Lost Days',
#  'Ei8ht',
#  'Metalocalypse Dethklok',
#  'D4ve',
#  'Hunt For Wolverine Mystery Ma',
#  'X Classified',
#  'Killmonger',
#  'Spider-Man and X-Men',
#  'Deadpool and Mercs For Money',
#  'Atomic Robo Knights O/T Golde',
#  'X-Men Prime',
#  'Criminal Savage Ed Magazine S',
#  'Mother Panic Gotham a D',
#  'Hercules',
#  'Hellboy and Bprd 1954 Ghost M',
#  'Jacked',
#  'Image Firsts Saga Curr Ptg',
#  'New Lieutenants of Metal',
#  '30 Days of Night',
#  'Invincible Iron Man Annual',
#  'Twilight Zone Lost Tales One',
#  'Think Tank',
#  'Agents of Shield',
#  'All New X-Men Special',
#  'Edge of Spider-Geddon',
#  'Michael Avon Oemings Victorie',
#  'Batman 66 Meets Wonder Woman',
#  'Poison Ivy Cycle of Life and',
#  'Devolution',
#  'Disney Star Vs the Forces of',
#  'Astounding Wolf-Man',
#  'Bprd Hell On Earth Pickens Co',
#  'Xenoholics',
#  'Mage Hero Denied',
#  'Age of Ultron Vs Marvel Zombi',
#  'Convergence Superman',
#  'Flashpoint Emperor Aquaman',
#  'Deadpool Kills Deadpool',
#  'Gft Coven',
#  'Cloudia and Rex',
#  'Quantum and Woody',
#  'Tmnt Villain Microseries',
#  'Mystery Science Theater 3000',
#  'Dv8 Gods and Monsters',
#  'Eye of Newt',
#  'Bruce Wayne the Road Home Bat',
#  'Ronin Island',
#  'The Spider',
#  'Walt Disney Comics and Stories',
#  'Hawkeye and Mockingbird',
#  'Mice Templar IV Legend',
#  'Walking Dead the Governor Spe',
#  'Hunt For Wolverine Weapon Los',
#  'Pathfinder',
#  'E Is For Extinction',
#  'Jla Gods and Monsters',
#  'Age of X-Man Apocalypse and X',
#  'Motro',
#  'Power Up',
#  'Star Wars Legacy Ii',
#  'Justice League Darkseid War S',
#  'Fear Itself Home Front',
#  'Hero Comics 2011 (One Shot',
#  'Sun Bakery',
#  'Vengeance',
#  'Roger Langridges Snarked',
#  'X-Tinction Agenda',
#  'Die!Die!Die!',
#  'Briggs Land',
#  'Batman Kings of Fear',
#  'Blackest Night Untold Tales o',
#  'Lobster Johnson Scent of Lotu',
#  'Mask Mobile Armored Strike Ko',
#  'Prowler',
#  'True Believers Venom Vs Spide',
#  'Franken-Castle',
#  'Welcome Back',
#  'Burn the Orphanage Reign of T',
#  'Gft Robyn Hood I Love Ny',
#  'Gasolina',
#  'Robin Rises Omega',
#  'Civil War Ii Choosing Sides',
#  'Planet O/T Apes Cataclysm',
#  'Future Quest Showcase',
#  'Deadpool Too Soon',
#  'Sundowners',
#  'Vote Loki',
#  'Wonder Woman 77 Bionic Woman',
#  'Shadow Midnight Moscow',
#  'Before Watchmen Moloch',
#  'Lord of the Jungle',
#  'Evolution',
#  'Cyber Force',
#  'Weird Detective',
#  'My Little Pony Legends of Mag',
#  'Wormwood Goes To Washington',
#  'Todd the Ugliest Kid On Eart',
#  'Green Lantern Corps Annual',
#  'Wicked and Divine 1831 One Sho',
#  'House of Penance',
#  '1872',
#  'Carnage Usa',
#  'Kirby Genesis',
#  'Dollhouse Epitaphs',
#  'Man-Thing',
#  'Spookhouse',
#  'Battlefields 09-10',
#  '12 Reasons To Die',
#  'Flashpoint Lois Lane and the',
#  'Assassinistas',
#  'X-Men Hellbound',
#  'Ghostbusters Crossing Over',
#  'Captain America and Iron Man',
#  'Image Firsts Invincible',
#  'Star Wars Doctor Aphra Annua',
#  'Deathlok',
#  'Batman and Batgirl',
#  'Tales Designed To Thrizzle',
#  'Disney Princess',
#  'George Perez Sirens',
#  'Family Trade',
#  'Tom Strong and the Planet of',
#  'Hellboy Double Feature of Evi',
#  'Batman Widening Gyre',
#  'Hunt For Wolverine',
#  'Mirror',
#  'Star Trek Countdown To Darkne',
#  'X-Files (2016)',
#  'Criminal Special Ed One Shot',
#  'Marvel Zombies',
#  'Harvest',
#  'Bprd Hell On Earth Return O/',
#  'Wolverine and X-Men Alpha an',
#  'Rinse',
#  'Planet of Apes Green Lantern',
#  'Convergence Speed Force',
#  'No Place Like Home',
#  'Green Lantern the Animated Se',
#  'Flash Rebirth',
#  'Judge Dredd Blessed Earth',
#  'Batwoman Annual',
#  'Dick Tracy Dead Or Alive',
#  'Batman and Nightwing',
#  'Hellboy In Mexico Or Drunken',
#  'Spy Seal',
#  'Amazing Spider-Man Special',
#  'Cape 1969',
#  'Animosity Evolution',
#  'Paradiso',
#  'Astro City the Dark Age Book',
#  'Sentry',
#  'Demo VOL 2',
#  'Black Panther Vs Deadpool',
#  'Penny Dreadful',
#  'Howling Commandos of Shield',
#  'Skin and Earth',
#  'Fear Itself Deadpool',
#  'Buffy the Vampire Slayer Spik',
#  'Uncanny X-Men Special',
#  'Batman Who Laughs the Grim Kn',
#  'Vader Dark Visions',
#  'Red Hood Outlaw',
#  'Tmnt Ghostbusters',
#  'Hit-Girl #1 (of 5) (Mr) (Pp',
#  'Legenderry a Steampunk Adv',
#  'Deadpool the Duck',
#  'Survivors Club',
#  'Image Firsts Manhattan Projec',
#  'Burn the Orphanage Born To Lo',
#  'Zombies Vs Robots',
#  'Magic the Gathering Theros',
#  'Sideways',
#  'Lobster Johnson Metal Monster',
#  'Chew Demon Chicken Poyo',
#  'Renato Jones One Percent',
#  'Convergence Harley Quinn',
#  'Batman Superman Annual',
#  'Dexter',
#  'Batman and Catwoman',
#  'Last Contract',
#  'Snapshot',
#  'Marvel Legac',
#  'X-Force Sex and Violence',
#  'Divided States of Hysteria',
#  'Emerald City of Oz',
#  'Star-Lord and Kitty Pryde',
#  'Scribblenauts Unmasked Crisi',
#  'Astonishing X-Men Annual',
#  'Superior Carnage',
#  'Thanos Annual',
#  'Modok Assassin',
#  'Star Wars Vader Dark Visions',
#  'American Vampire Anthology',
#  'Mister Terrific',
#  'Deadman',
#  'Henchgirl',
#  'Wonder Twins',
#  'Infinity Wars Arachknight',
#  'Skylanders',
#  'Wrath of the Eternal Warrior',
#  'Winnebago Graveyard',
#  'Joe Golem Occult Detective Ou',
#  'Now Champions',
#  'Superman Family Adventures',
#  'Captain America and Black Wid',
#  'Bprd Hell On Earth Monsters',
#  'Brothers Dracul',
#  'Untold Tales of Punisher Max',
#  'Transformers Monstrosity',
#  'Gotham City Garage',
#  'Spike',
#  'Drumhellar (Previously Strang',
#  'Magnificent Ms Marvel',
#  'Deadpool Mercs For Money',
#  'Hack Slash Resurrection',
#  'Unexpected',
#  'Blackcross',
#  'Strain the Fall',
#  'Infinity Wars Weapon Hex',
#  'Infinity Wars Soldier Suprem',
#  'Teenage Mutant Ninja Turtles',
#  'Lockjaw',
#  'Image Firsts Outcast',
#  'Amazing X-Men Annual',
#  'Black Dynamite',
#  'Rat Bastards',
#  'Where Monsters Dwell',
#  'Bprd Hell On Earth Exorcism',
#  'Popeye Classics Ongoing',
#  '21st Century Tank Girl',
#  'Damage',
#  'Marvel Knights Spider-Man',
#  'Transformers Heart Darkness',
#  'Generations Morales and Parker',
#  'High Level',
#  'Glitterbomb',
#  'Solomon Kane Red Shadows',
#  'X-Men Gold Annual',
#  'Nightworld',
#  'Hellraiser Masterpieces',
#  'Deadpool Back In Black',
#  'Avengers Annual 2013',
#  'Convergence Wonder Woman',
#  'Cataclysm Ultimates',
#  'Mice Templar VOL 3',
#  'Exit Stage Left the Snagglepu',
#  'Ant-Man and the Wasp',
#  'Star Wars Rebel Heist',
#  'Fantastic Four Wedding Specia',
#  'Domino',
#  'Hellboy Being Human One Sho',
#  'God Complex',
#  'Superior Spider-Man Team Up S',
#  'Flashpoint Frankenstein Creat',
#  'A Voice In the Dark',
#  'Flashpoint Citizen Cold',
#  'Jetsons',
#  'Tales of Suspense',
#  'Locke and Key Guide To Known Ke',
#  'Locke and Key Small Worl',
#  'Flashpoint the Outsider',
#  'Magic the Gathering',
#  'Paybacks',
#  'Convergence Flash',
#  'Convergence Nightwing Oracle',
#  'Star Wars Dawn of the Jedi',
#  'Neil Gaiman American Gods Mom',
#  'Star Wars Darth Vader and Lost',
#  'Falcon',
#  'Journey Star Wars Last Jedi C',
#  'Titans Annual',
#  'Infinity Wars Iron Hammer',
#  'Tiny Titans Return To the Tre',
#  'Hulkverines',
#  'Now Black Panther World of Wa',
#  'Hyperion',
#  'Baltimore Empty Graves',
#  'Timely Comics Moon Girl and D',
#  'Goosebumps Download and Die',
#  'Cage',
#  'Port of Earth',
#  'Generation X',
#  'Guardians of Galaxy Annual',
#  'Gunning For Hits',
#  'World of Tanks',
#  '47 Ronin',
#  'Buffy the Vampire Slayer Rile',
#  'Spontaneous',
#  'Dark Knight Returns the Last',
#  'Tyson Hesse Diesel',
#  'Cover',
#  'X-Men Second Coming',
#  'Mystic',
#  'Convergence Detective Comics',
#  'Secret Empire Brave New Worl',
#  'Wytches Bag Egg Halloween Spe',
#  'Mrs Deadpool and Howling Comm',
#  'Figment',
#  'Morbius Living Vampire',
#  'Telos',
#  'Civil War Ii X-Men',
#  'Punisher Platoon',
#  'Gft Grimm Tales of Terror',
#  'Vertigo Quarterly',
#  'Lady Mechanika La Dama De La',
#  'Britannia',
#  'Flash Gordon Zeitgeist',
#  'Venom First Host',
#  'Warning',
#  'Larks Killer',
#  'Ghostbusters 101',
#  'Baltimore the Red Kingdom',
#  'Old Lady Harley',
#  'King Conan Conqueror',
#  'Old Man Quill',
#  'Hellboy Winter Special 2016',
#  'Green Lantern Red Lanterns',
#  'Saviors',
#  'Infinity 8',
#  'Fury of Firestorm',
#  'Rise of the Black Flame',
#  'Skybourne',
#  'Korvac Saga',
#  'Tmnt Amazing Adventures',
#  'Angel Illyria',
#  'Fight Like a Girl',
#  'Assassin Nation',
#  'Eerie Comics',
#  'Doctor Who Ongoing',
#  'Godzilla Cataclysm',
#  'Cataclysm Ultimate X-Men',
#  'Superannuated Man',
#  'Goldie Vance',
#  'Nightwing Rebirth',
#  'Green Lanterns Rebirth',
#  'Grand Passion',
#  'Justice League Futures End',
#  'Divinity',
#  'Zombies Vs Robots Aventure',
#  'Jim Hensons Storyteller Witch',
#  'Pitiful Human Lizard',
#  'Hotwire Deep Cut',
#  'Elric the Balance Lost',
#  'Flash Gordon',
#  'Silver Surfer Black',
#  "Cap'n Dinosaur One Sho",
#  'Graveyard of Empires',
#  'James Bond Kill Chain',
#  'Batman the Devastator',
#  'Hawkeye Annual',
#  'Gotg and X-Men Black Vortex O',
#  '1602 Witch Hunter Angela',
#  'Haunted Mansion',
#  'Beasts of Burden Presence of',
#  'Star Wars Darth Vader Ghost P',
#  'Archer and Armstrong (New)',
#  'Now Jessica Jones',
#  'Superman Rebirth',
#  'This Damned Band',
#  'Marvel Universe Avengers Asse',
#  'Star Wars Invasion Rescues',
#  'Demon Hell Is Earth',
#  'Last Days of American Crime',
#  'Mercenary Sea',
#  'Orc Stain',
#  'Kim and Kim',
#  'Marvel Comics Presents',
#  'Adventures of Superman (2013',
#  'Batman Creature of the Night',
#  'Amazing Spider-Man/Venom Veno',
#  'Convergence Swamp Thing',
#  'Groo Vs Conan',
#  'Wonder Woman and Jl Dark Witchi',
#  'Beasts of Burden',
#  'Blackwood',
#  'Mech Cadet Yu',
#  'Skyward',
#  'Baltimore Witch of Harju',
#  'House of M',
#  'Transformers Windblade Combin',
#  'Last Broadcast',
#  'Namor First Mutant',
#  'Hero Cats',
#  'Convergence Green Lantern Cor',
#  'Citizen Jack',
#  'Star Trek Tng Terra Incognit',
#  'Lodger',
#  'Convergence Action Comics',
#  'Rocketeer At War',
#  'Demonic',
#  'Infinity Entity',
#  'Taskmaster',
#  'Team 7',
#  'Calexit',
#  'Marvel Rising',
#  'Gladstones School For World C',
#  'Ragemoor',
#  'Black Cat',
#  'Katana',
#  'Hellboy Krampusnacht',
#  'Kill Shakespeare',
#  'Major X',
#  'Image United',
#  'Drums',
#  'King Conan Hour O/T Dragon',
#  'Sherlock Holmes Liverpool Dem',
#  'Justice League Cry For',
#  'Alters',
#  'Injustice Ground Zero',
#  'Doomwar',
#  'Uncanny',
#  'Locke and Key Grindhouse One Sh',
#  'Guardians of Galaxy Galaxys M',
#  'Amazing Spider-Man and Silk S',
#  'Come Into Me',
#  'Xerxes Fall of House of Dariu',
#  'Shade the Changing Woman',
#  'Lobster Johnson Pirates Ghos',
#  'Monocyte',
#  'Original Sin Annual',
#  'Disney Frozen',
#  'Miss Fury',
#  'Mighty Thor Gates of Valhall',
#  'Secret Empire Omega',
#  'Stan Lee Starborn',
#  'Few',
#  'Hellboy Bprd 1953 Witch Tree',
#  'Transformers Sins of Wrecker',
#  'Inhumanity Spider-Man',
#  'Hellboy and Bprd 1953 Phantom H',
#  'Kingsman Red Diamond',
#  'Dead Rabbit',
#  'Realm of Kings Inhumans',
#  'Goners',
#  'Batwoman Rebirth',
#  'Usagi Yojimbo Senso',
#  'Gft Jungle Book Fall Wild',
#  'Archer and Armstrong (Vu)',
#  'Baltimore Infernal Train',
#  'Spider-Island Cloak and Dagge',
#  'Hex Wives',
#  'Death Vigil',
#  'Future Quest Presents',
#  'Convergence New Teen Titans',
#  'Now Mighty Thor',
#  'Batman the Red Death',
#  'It Will All Hurt',
#  'Mystery Society',
#  'My Little Pony Micro Series',
#  'Analog',
#  'Forever Evil Argus',
#  'Fear Itself Spider-Man',
#  'Superman Secret Origin',
#  'Batman the Drowned',
#  'Farscape Ongoing',
#  'Batman and Carrie Kelley',
#  'Red She-Hulk',
#  'Now Captain America Steve Rog',
#  'Convergence Adventures of Sup',
#  'Transformers Primacy',
#  'Star Trek Khan',
#  'Darkness',
#  'Now Invincible Iron Man',
#  'Infinite Dark',
#  'She Wolf',
#  'Now Avengers',
#  'Orphan Black',
#  'Sherlock Holmes Year One',
#  'Stephen Kings N',
#  'Star Trek Tng Mirror Broken',
#  'Ninja-K',
#  'Captain Britain and Mighty De',
#  'Thanos a God Up There Listeni',
#  'Thats Because Youre a Robot O',
#  'Infinitys Wars Prime',
#  'Stan Lee Traveler',
#  'X-Men Black Emma Frost',
#  'Pumpkinhead',
#  'Grindhouse Drive In Bleed Ou',
#  'Spider-Girl',
#  'Mad Max Fury Road Mad Max',
#  'Flashpoint Secret Seven',
#  'Wasted Space',
#  'Angelic',
#  'Tmnt Shredder In Hell',
#  'Batman Incorporated Special',
#  'Solar Man O/T Atom',
#  'Grayson Annual',
#  'Deadpool Max 2',
#  'Hunt',
#  'Kong On Planet of Apes',
#  'Brass Sun',
#  'Hellblazer Rebirth',
#  'Grim Leaper',
#  'Gi Combat',
#  'Batman the Merciless',
#  'Titans Rebirth',
#  'Convergence Justice League Am',
#  'Infinite Loop',
#  'Prometheus Fire and Stone',
#  'Kennel Block Blues',
#  'Predator Hunters',
#  'Image Firsts Sex Criminals',
#  'Convergence Aquaman',
#  'My Little Pony Movie Prequel',
#  'Dark Shadows',
#  'Convergence Superman Man of S',
#  'Star Wars Droids Unplugged',
#  'Alabaster Wolves',
#  'Multiple Warheads Down Fall O',
#  'Green Lantern New Guardians A',
#  'Another Castle',
#  'Cerebus In Hell',
#  'Legends Dark Knight 100 Page',
#  'Tech Jacket',
#  'Doctor Who 13th',
#  'Wolverine and X-Men Annual',
#  'Tmnt New Animated Adventures',
#  'Lot 13',
#  'Eternal Empire',
#  'Fear Itself Prologu',
#  'Thanos Legacy',
#  'Figment 2',
#  'Civil War Ii Gods of War',
#  'Dexter Down Under',
#  'Miami Vice Remix',
#  'Hellboy Winter Special 2017 O',
#  'Rock Candy Mountain',
#  'Marvel Universe Guardians of',
#  'Convergence Batgirl',
#  'X-Men Regenesis',
#  'Image Firsts I Kill Giants',
#  'Clint',
#  'Cannibal',
#  'Gi Joe VOL 2 Ongoing',
#  'Fear Itself Youth In Revolt',
#  'Ultron',
#  'Justice League of America Reb',
#  'Super Hero Squad',
#  'Translucid',
#  'Strange Tales 2',
#  'Strange Case of Mr Hyde',
#  'Now Cage',
#  'Witcher',
#  'Frenemy of the State',
#  'Deadpool and Cable',
#  'Godshaper',
#  'Fatima the Blood Spinners',
#  'Nights Dominion',
#  '68 Scars',
#  'Bloodshot (Ongoing)',
#  'X-Men Black Magneto',
#  'United States Vs Murder Inc',
#  'Dcs Year of the Villain',
#  'Exorsisters',
#  'Deadpool Bi-Annual',
#  'Sharkey Bounty Hunter',
#  'Indestructible Hulk Annual',
#  'Supergirl Being Super',
#  'Justice League Dark Annual',
#  'Superman Wonder Woman Annual',
#  'Avengers 1959',
#  'Batman the Dawnbreaker',
#  'Regular Show Skips',
#  'Clue',
#  'Criminal Macabre Goon When Fr',
#  'Archangel',
#  'Weapons of Mutant Destructio',
#  'American Vampire the Long Roa',
#  'Clone Conspiracy Omeg',
#  'Batman and Aquaman',
#  'House Amok',
#  'Grindhouse Doors Open At Midn',
#  'Grendel Vs Shadow',
#  'Tmnt Mutanimals',
#  'Justice League Aquaman Drowne',
#  'Bettie Page',
#  'Deadpool Killustrated',
#  'Looney Tunes',
#  'Infinity Wars Ghost Panther',
#  'I Hate Fairyland Spec Ed Cvr',
#  'Hell Yeah',
#  'Adventures of Superman',
#  'Tmnt Turtles In Time',
#  'Doctor Strange Punisher Magi',
#  'Last of Us American Dreams',
#  'Jla the 99',
#  'Marvel Universe Avengers Eart',
#  'Marvel Rising Ms Marvel Squir',
#  'Harbinger (Vu)',
#  'Dragon Age Magekiller',
#  'Magic the Gathering Spell Thi',
#  'Flashpoint Kid Flash Lost',
#  'Empty',
#  'Nightwing Annual',
#  'Kingpin',
#  'Wonder Woman Futures End',
#  'Guardians of Galaxy Tomorrow',
#  'Harley Quinn Road Trip Specia',
#  'DC Comics Presents Batman Got',
#  'Kaijumax Season 2',
#  'Giant Man',
#  'Spider-Man Clone Saga',
#  'Planet of the Apes Ursus',
#  'Female Furies',
#  'Wicked and Divine 455 Ad',
#  'Star Trek Next Generation Hiv',
#  'Over Garden Wall Ongoing',
#  'Wild Blue Yonder',
#  'Wonder Woman Bionic Woman 77',
#  'Optic Nerve',
#  '68 (Sixty Eight)',
#  'Thunder Agents',
#  'Jl Dark and Wonder Woman the Wi',
#  'Flashpoint Deathstroke the Cu',
#  'Feathers',
#  'Heralds',
#  'Infidel',
#  'Generations Unworthy Thor and M',
#  'Ballistic',
#  'Indestructible Hulk Special',
#  'Meta 4',
#  'Witch Doctor Mal Practice',
#  'Guild',
#  'Static Shock',
#  'Lady Mechanika Clockwork Assa',
#  'Osborn',
#  'Raven Daughter of Darkness',
#  'Conan People O/T Black Circl',
#  'Strange Adventures',
#  'Lazarus Risen',
#  'Legends of Red Sonja',
#  'Doctor Who 9th',
#  'Avengers Standoff Assault On',
#  'Rocket',
#  'Marvel Zombies Supreme',
#  'Robert E Howards Savage Swor',
#  'Convergence Supergirl Matrix',
#  'Princess Ugg',
#  'Twilight Zone',
#  'Black Hammer Cthu-Louise Cvr',
#  'Dry County',
#  'Angel City',
#  'Misfit City',
#  'True Believers Miles Morales',
#  'Dirk Gentlys Holistic Detecti',
#  'Royals Masters of War',
#  'Death of Hawkman',
#  'American Monster',
#  'Army of Darkness Bubba Hotep',
#  'Battlestar Galactica',
#  'Star Wars Galaxys Edge',
#  'Aquaman Justice League Drowne',
#  'Age of Conan Belit',
#  'Vertigo Resurrected',
#  'What If Age of Ultron',
#  'Rat God',
#  'Batman and Ras Al Ghul',
#  'Harley Quinn Annual',
#  'Spider-Gwen Aka Ghost Spider',
#  'Ragman',
#  'Ultimate Spider-Man',
#  'James Bond Felix Leiter',
#  'New York Five',
#  'Negative Space',
#  'Garbage Pail Kids Gross Encou',
#  'Jade Street Protection Servic',
#  'Harbinger Renegade',
#  'Spider-Man Annual',
#  'Marvel Tsum Tsum',
#  'Dark Matter',
#  'Image Firsts Monstress',
#  'Moriarty',
#  'Transformers Unicron',
#  'Thor Mighty Avenger',
#  'Generations Phoenix and Jean Gr',
#  'X-Men Worst X-Man Ever',
#  'Now Hawkeye',
#  'Now Infamous Iron Man',
#  'Now Thanos',
#  'Aliens Dust To Dust',
#  'Blackest Night Jsa',
#  'DC Vs Masters of the Univers',
#  'Rat Queens Special Neon Stati',
#  'Lumberjanes Special Makin Gho',
#  'All Time Comics Crime Destroy',
#  'Hellraiser Bestiary',
#  'Revolution',
#  'Batman the Maxx Arkham Dream',
#  'Grizzly Shark',
#  'Amazing Spider-Man Venom Inc',
#  'Convergence Titans',
#  'Lil Depressed Boy Supposed T',
#  'Surgeon X',
#  'Ghostbusters Answer the Call',
#  'Reset',
#  'Sovereign',
#  'Lady Mechanika Lost Boys of W',
#  'Conan the Cimmerian',
#  'Catwoman Annual',
#  'King!',
#  'Fearless Dawn',
#  'Rockos Modern Life',
#  'Hellraiser Road Below',
#  'Occupy Comics',
#  'Stan Lee Soldier Zero',
#  'Dark Red',
#  'Tmnt Ghostbusters Ii',
#  'Godkiller Walk Among Us',
#  'Arclight',
#  'King Conan Scarlet Citadel',
#  'Star Wars Knight Errant Delug',
#  'Invaders Now',
#  'Multiple Man',
#  'Lake of Fire',
#  'Muppet Show',
#  'Star Trek Waypoint',
#  'Star Wars Crimson Empire Iii',
#  'New Challengers',
#  'Armor Wars',
#  'Night Force',
#  'Batman and Wonder Woman',
#  'Fear Itself Deep',
#  'Star Wars Dawn O/T Jedi Forc',
#  'Change',
#  'Shadow Batman',
#  'Infinity Countdown Champions',
#  'X-Men Exterminated',
#  'Hawkman Found',
#  'My Little Pony Nightmare Knig',
#  'Thought Bubble Anthology 201',
#  'Goon In Theatre Bizarre',
#  'Peter Cannon Thunderbolt',
#  'Lobster Johnson Prayer of Nef',
#  'Tmnt Urban Legends',
#  'Blackhawks',
#  'Whispers',
#  'Terminator Salvation Final Ba',
#  'Gft Satans Hollow',
#  'Dream Police',
#  'Zinnober',
#  'Smoke and Mirrors',
#  'Hail Hydra',
#  'Green Arrow Rebirth',
#  'Lumberjanes Beyond Bay Leaf',
#  'Relay',
#  'Marvel Rising Omega',
#  'Lost Boys',
#  'Lobster Johnson Caput Mortuu',
#  'Earth 2 #2 Earth Two',
#  'Longshot Saves Marvel Univers',
#  'Jericho Season 4',
#  'Red Hood and the Outlaws Annu',
#  'Atomahawk',
#  'Point One',
#  'Image Firsts Head Lopper',
#  'Tmnt Bebop Rocksteady Hit th',
#  'Iron Patriot',
#  'Marvel Two-In-One Annual',
#  'Marvel Universe Ultimate Spid',
#  'X-Men Black Juggernaut',
#  'Doctor Who 8th',
#  'Now Ultimates 2',
#  'Conan Red Sonja',
#  'Rat Queens Special Orc Dave',
#  'Phillip K Dicks Electric Ant',
#  'Cave Carson Has An Interstell',
#  'Gft Oz Reign of Witch Queen',
#  'Garfield',
#  'Charmed',
#  'Dead Hand',
#  'No Mercy',
#  'Image Firsts Nailbiter',
#  'Uncanny Avengers Ultron Forev',
#  'Captain America Annual',
#  'Robocop Last Stand',
#  'Immortal Men',
#  'Twisted Romance',
#  'Cold War',
#  'Green Lantern Futures End',
#  'Backways',
#  'Day Men',
#  'Now Spider-Man',
#  'Baltimore Dr Leskovars Remed',
#  'Batman and Frankenstein',
#  'Dia De Los Muertos',
#  'Empowered Special',
#  'Elisabeth Dumn Against the De',
#  'Star Wars Poe Dameron Annual',
#  'Mouse Guard Legends of Guard',
#  'Heathen',
#  'Euthanauts',
#  'Fence',
#  'Elephantmen Man and Elephantm',
#  'Dial H For Hero',
#  'X-Men Black Mystique',
#  'Jimmys Bastards',
#  'Disciples',
#  'Super Powers',
#  'Batgirl Endgame',
#  'Suicide Squad Amanda Waller',
#  'Marvel Rising Alpha',
#  'Detective Comics Futures End',
#  'Adventures of Supergirl',
#  'Batman and the Outsiders',
#  'Jim Henson Beneath Dark Cryst',
#  'Justice League Annual',
#  'X-Men Blue Annual',
#  'Death Orb',
#  'Deep State',
#  'Justice League of Americas Vi',
#  'My Little Pony Ponyville Myst',
#  'Defenders Silver Surfer',
#  'My Little Pony Fiendship Is M',
#  'Batgirl Futures End',
#  'Image Firsts',
#  'Superman Leviathan Rising Spe',
#  'Convergence Batman and Robin',
#  'X-Men Grand Design X-Tinctio',
#  'Twilight Zone Annual 201',
#  'Jla Gods and Monsters Superma',
#  'Hellboy Winter Special 2018 C',
#  'Harley Loves Joker',
#  'Vampblade',
#  'Marvel Rising Squirrel Girl M',
#  'Weavers',
#  'Hellboy and Bprd 1954 Unreaso',
#  'Quantum Teens Are Go',
#  'Gi Joe Origins',
#  'Billy Batson and the Magic o',
#  'All Time Comics Blind Justic',
#  'James Bond the Body',
#  'Superman Batman Annual',
#  'Supergirl Rebirth',
#  'Realm of Kings Imperial Guar',
#  'Ride Southern Gothic',
#  'Gi Joe Sierra Muerte',
#  'Valhalla Mad',
#  'Ash and the Army of Darkness',
#  'Life Is Strange',
#  'Image Firsts Wytches',
#  'Fairlady',
#  'Aliens Fire and Stone',
#  'Guild Tink One Shot Ron Chan',
#  ...]

# %%
titles_searching = titles_need_list[980:]

# %%
titles_searching
# Out:
# ['Rick and Morty Vs Dungeons and Dr',
#  'Goon Once Upon a Hard Time',
#  'Black Bolt',
#  'Conan Road of Kings',
#  'Constantine Hellblazer City o',
#  'Trinity of Sin the Phantom St',
#  'X-O Manowar (Ongoing)',
#  'Death of Wolverine Logan Lega',
#  'Ballad of Sang',
#  'Star Wars Thrawn',
#  'Phantom Stranger',
#  'Larfleeze',
#  'Airboy',
#  'Superior Spider-Man Annual',
#  'Ghost',
#  'Suiciders',
#  'Rasputin Voice of Dragon',
#  'Spider-Man Life Story',
#  'Godzilla Gangsters and Goliath',
#  'Gft Robyn Hood Ongoing',
#  'Animal Man Annual',
#  'Axe Cop Bad Guy Earth',
#  'Drumhellar',
#  'Dark Tower Gunslinger',
#  'Now Doctor Strange',
#  'Godzilla Kingdom of Monsters',
#  'Robin Rises Alpha',
#  'Captain Midnight',
#  'X-O Manowar',
#  'Ad After Death Book 02 (of 3',
#  'The Squidder',
#  'Fantastic Four Annual',
#  'Cry Havoc',
#  'Wasteland',
#  'Captain Atom',
#  'Tales From the Darkside',
#  'Bullseye',
#  'Captain Marvel and Carol Corp',
#  'Action Comics Annual',
#  'Five Weapons',
#  'Spider-Geddon',
#  'Herc',
#  'Umbral',
#  'Dark Tower Gunslinger Way Sta',
#  'Mythic',
#  'Marvelous Land of Oz',
#  'Punk Rock Jesus',
#  'Arkham Manor',
#  'Bunker',
#  'Plastic Man',
#  'Flintstones',
#  'Ninjak',
#  'Gft Realm War',
#  'Eclipse',
#  'Glory',
#  'Hellraiser Dark Watch',
#  'Wonder Woman 77 Special',
#  'Black Hammer 45 From World o',
#  'Robin War',
#  'James Bond Hammerhead',
#  'Chin Music',
#  'Doctor Who 11th',
#  'Rose',
#  'Wonder Woman Conan',
#  'Star Wars Classified',
#  'Cataclysm Ultimate Spider-Ma',
#  'Doctor Strange Sorcerers Supr',
#  'Crosswind',
#  'Midas Flesh',
#  'Men of Wrath',
#  'Savage Avengers',
#  'Pearl',
#  'Bitter Root',
#  'Snowfall',
#  'Man Without Fear',
#  'Twilight Zone SandS',
#  'Stand Hardcases',
#  'Infinity Man and the Forever',
#  'Deadpool Vs Old Man Logan',
#  'Vampirella',
#  'Realm',
#  'Sixth Gun Valley of Death',
#  'Judge Dredd (Ongoing)',
#  'Rebels These Free and Independe',
#  'Gft Oz',
#  'Deathbed',
#  'Sword of Sorcery',
#  'Harley and Ivy Meet Betty and Ver',
#  'I Zombie',
#  'Original Sins',
#  'Giant Size Little Marvel Avx',
#  'Surface',
#  'Swamp Thing Annual',
#  'Hip Hop Family Tree',
#  'Flavor',
#  'Superman Annual',
#  'Jean Grey',
#  'Visitor How and Why He Staye',
#  'Donald Duck',
#  'Image Giant Sized Artists Pro',
#  'Halo Rise of Atriox',
#  'Ravagers',
#  'Superior Spider-Man Team Up',
#  'Spirit',
#  'Ascender',
#  'Vinegar Teeth',
#  'Titans Hunt',
#  'Star Trek Tng Doctor Who Assi',
#  'Walking Dead Michonne Specia',
#  'Mysterious Strangers',
#  'Conan the Slayer',
#  'Insexts',
#  'Rockstars',
#  'October Faction',
#  'Slayer Repentless',
#  'Batman 66 Meets Green Hornet',
#  'Captain America and Hawkeye',
#  'Green Lantern New Gods Godhea',
#  'Haunted Horror',
#  'Age of X-Man Amazing Nightcra',
#  'Lady Mechanika Tablet of Dest',
#  'Saucer Country',
#  'Deadpool Kills Marvel Univers',
#  'Grimm',
#  'Strangers',
#  'Locke and Key Keys To the Kingd',
#  'Suicide Squad Rebirth',
#  'Vault',
#  'Rocketeer Hollywood Horror',
#  'Stand Night Has Come',
#  'Ad After Death Book 03 (of 3',
#  'Star Trek Green Lantern VOL',
#  'X-O Manowar (2017)',
#  'Near Death',
#  'Highest House',
#  'Punisher War Zone',
#  'Pastaways',
#  'Batman Arkham Unhinged',
#  'Joe Hill the Cape',
#  'C.o.w.l.',
#  'Spider-Verse Team Up',
#  'Witchfinder Mysteries of Unla',
#  'Contest of Champions',
#  'Black Road',
#  'Nighthawk',
#  'Doctor Who Prisoners of Time',
#  'Axe Cop President O/T World',
#  'Briggs Land Lone Wolves',
#  'Hellboy and Bprd 1956',
#  'Rom',
#  'Bloodstrike',
#  'Batman Odyssey',
#  'Locke and Key Alpha',
#  'Inhumanity',
#  'Stand No Mans Land',
#  'Gravediggers Union',
#  'Star-Lord',
#  'Squidder',
#  'Popeye',
#  'First Strike',
#  'DC Nation',
#  'Iron Man Legacy',
#  'Doctor Who Ongoing VOL 2',
#  'Garth Ennis Jennifer Blood',
#  'Creep',
#  'War of Realms Uncanny X-Men',
#  'Unnatural',
#  'Art Ops',
#  'Brave and the Bold Batman and Won',
#  'Madame Xanadu',
#  'Captain America White',
#  'Billy Kids Oddities and Orm Loc',
#  'Star Wars Jedi Republic Mace',
#  'Pigs',
#  'Star Trek Boldly Go',
#  'Deadpool Vs Punisher',
#  'Freedom Fighters',
#  'Mockingbird',
#  'Starfire',
#  'Vision Directors Cut',
#  'Beasts of Burden Wise Dogs an',
#  'Dark Days the Casting',
#  'Invincible Universe',
#  'Hexed',
#  'Baltimore Plague Ships',
#  'Multiversity Thunderworld',
#  'Atomic Robo Ghost of Station',
#  'Star Wars Darth Maul',
#  'Avengers X-Sanction',
#  'He Man Thundercats',
#  'Americas Got Powers',
#  'New Avengers Finale',
#  'Gft Code Red',
#  'Batman the Return',
#  'Debris',
#  'Illuminati',
#  'Aliens Defiance',
#  'Storm',
#  'Hoax Hunters',
#  'Bodies',
#  'Avx Consequences',
#  'Starve',
#  'Mickey Mouse',
#  'Sidekick',
#  'Inferno',
#  'Little Nemo Return To Slumber',
#  'Evil Empire',
#  'Godzilla Rage Across Time',
#  'Star Wars Old Republic',
#  'Sword Daughter',
#  'Sword of Ages',
#  'Star Wars Lando Double Or Not',
#  'Bprd Hell On Earth Long Deat',
#  'Movement',
#  'Great Lakes Avengers',
#  'Casanova Gula',
#  'Deadpool Vs Carnage',
#  'Dark Corridor',
#  'Massive Ninth Wave',
#  'Cosmic Ghost Rider Destroys M',
#  'Scooby Doo Team Up',
#  'Proof Endangered',
#  'Age of X-Man Nextgen',
#  'Sledgehammer 44',
#  'Generation Gone',
#  'Love and Rockets Magazine',
#  'Age of X-Man Marvelous X-Men',
#  'Uncanny Avengers Annual',
#  'Archer and Armstrong',
#  'Rocketeer Spirit Pulp Frictio',
#  'Batman and the Signal',
#  'Hungry Ghosts',
#  'Thor Annual',
#  'Red Skull',
#  'Murder Book',
#  'Ragnarok',
#  'Joe Golem Occult Detective',
#  'Runlovekill',
#  'Batman Arkham City',
#  'Stray Bullets the Killers',
#  'Invaders',
#  'Chew Secret Agent Poyo',
#  'Night of Living Deadpool',
#  'Fiction',
#  'Shadow Roads',
#  'Bully Wars',
#  'Star Wars Adventures',
#  'Ducktales',
#  'The Damned',
#  'Jim Henson Labyrinth Coronati',
#  'Quantum Age From World of Bla',
#  'Red One',
#  'Godzilla Rulers of the Earth',
#  'Batman Futures End',
#  'Capt Victory and Galactic Range',
#  'Ruse',
#  'Bprd Hell On Earth Gods',
#  'Rai',
#  'Wolverine Max',
#  'Naomi',
#  'Ghostbusters',
#  'Storm Dogs',
#  'Cowboy Ninja Viking',
#  'Flashpoint Project Superman',
#  'Star Trek City O/T Edge of Fo',
#  'Roche Limit Clandestiny',
#  'The Lone Ranger',
#  'Stellar',
#  'Dark Days the Forge',
#  'Empty Zone',
#  'Shadow Show',
#  'New Avengers Annual',
#  'Bprd King of Fear',
#  'Forever Evil Arkham War',
#  'Mouse Guard Black Axe',
#  'Atomic Robo Savage Sword of D',
#  'Batman Last Knight On Earth',
#  'Master of Kung Fu',
#  'Maxx Maxximized',
#  'Brilliant',
#  'Shield Infinit',
#  'Strange Fruit',
#  'Bucky Barnes Winter Soldier',
#  'Strange Talent of Luther Stro',
#  'Batman Incorporated Leviatha',
#  'Exodus Life After',
#  'Ether Copper Golems',
#  'Silencer',
#  'Winter Soldier Bitter March',
#  'Teen Titans Annual',
#  'Black',
#  'Secret Wars 2099',
#  'Now Unworthy Thor',
#  'Ame Comi Girls',
#  'Toil and Trouble',
#  'Tomb Raider',
#  'Buffy the Vampire Slayer Will',
#  'Effigy',
#  'Infinity Wars Sleepwalker',
#  'Catalyst Comix',
#  'Multiversity Ultra Comics',
#  'Peanuts VOL 2',
#  'Huntress',
#  'Strain',
#  'Hawk and Dove',
#  'Border Town',
#  'Star Wars Solo Adaptation',
#  'Go Go Power Rangers',
#  'Masks',
#  'Avengers Undercover',
#  'It Girl and the Atomics',
#  'Squadron Sinister',
#  'Gft Hellchild',
#  'Undying Love',
#  'Help Us Great Warrior',
#  'Annihilators',
#  'Eternity Girl',
#  'Stumptown',
#  'Symmetry',
#  'Red Thorn',
#  'Inhumans Once Future Kings',
#  'War of Realms New Agents of A',
#  'Flashpoint Wonder Woman and t',
#  'Amazing Forest',
#  'Injustice Gods Among Us',
#  'Invisible Kingdom',
#  'Angel Season 11',
#  'Gft Presents Apocalypse',
#  'Crimson Lotus',
#  'A Plus X',
#  'Batman Rebirth',
#  'Screamland Ongoing',
#  'Orchid',
#  'Sledgehammer 44 Lightning Wa',
#  'Flashpoint Abin Sur the Gree',
#  'Rush Clockwork Angels',
#  'Transformers Windblade',
#  'Age of X-Man X-Tremists',
#  'Faith',
#  'Hunt For Wolverine Adamantiu',
#  'Annihilators Earthfall',
#  'And Then Emily Was Gone',
#  'Prophet Strikefile',
#  'Bprd Hell On Earth Devils Eng',
#  'Rebel Blood',
#  'Casanova',
#  'Daredevil Reborn',
#  'Gft Warlord of Oz',
#  'Brave and the Bold',
#  'Nick Fury',
#  'Godzilla Ongoing',
#  'Walk Through Hell',
#  'Hillbilly Red Eyed Witchery F',
#  'Angela Asgards Assassin',
#  'Daredevil Dark Nights',
#  'Planetoid',
#  'Where Is Jake Ellis',
#  'Punisher In Blood',
#  'Stranger Things',
#  'Horizon',
#  'Star Wars Last Jedi Adaptatio',
#  'Rogue and Gambit',
#  'Egos',
#  'Road To Oz',
#  'Gft Tales From Oz',
#  'Star Wars Legacy War',
#  'Farscape',
#  'Half Past Danger',
#  'Casanova Avaritia',
#  'Batman Jokers Daughter',
#  'Criminal 10th Anniversary Spe',
#  'Black Panther Most Dangerous',
#  'War of Realms Punisher',
#  'Deadpool Vs Gambit',
#  'Batman Lil Gotham',
#  'Bprd Dead Remembered',
#  'X-Men Schism Prelude',
#  'Chew / Revival',
#  'Siege',
#  'Flashpoint Deadman and the Fl',
#  'Bat Mite',
#  'Beasts of Burden Hellboy One',
#  'Daredevil Annual',
#  'Star Wars Han Solo Imperial C',
#  'Other Dead',
#  'Forever Evil Rogues Rebellio',
#  '4 Kids Walk Into a Bank',
#  'Batman Lost',
#  'Baltimore Cult of the Red Kin',
#  'Atomic Robo Flying She Devil',
#  'Do Androids Dream Dust To Dus',
#  'Occupy Avengers',
#  'Dark Tower Gunslinger Man In',
#  'Punks the Comic',
#  'Abe Sapien Devil Does Not Jes',
#  'Abe Sapien Abyssal Plain',
#  'Shadow Year One',
#  'Superman War of the Supermen',
#  'Secret Wars Journal',
#  'Chew Warrior Chicken Poyo',
#  'Red Wolf',
#  'Kevin Smith Green Hornet',
#  'Wonder Woman Annual',
#  'Kill the Minotaur',
#  'Courtney Crumrin Ongoing',
#  'Mass Effect Foundation',
#  'Gft Red Agent',
#  'All New X-Men Annual',
#  'Artifacts',
#  'Moonstruck',
#  'Frankenstein Alive Alive',
#  'Discipline',
#  'Plastic',
#  'Garth Ennis Red Team',
#  'Fear Itself Uncanny X-Force',
#  'Resident Alien',
#  'Hellboy Buster Oakley Gets Hi',
#  'True Believers Captain Marve',
#  'Limbo',
#  'Justice League Rebirth',
#  'Star Trek Green Lantern',
#  'Kevin Smith Bionic Man',
#  'Unholy Grail',
#  'Bobs Burgers',
#  'Gamma One Shot (C: 1-0-0',
#  'Strange Science Fantasy',
#  'Age of X-Man Prisoner X',
#  'Earth 2 Annual',
#  'Black Kiss Ii',
#  'Black Knight',
#  'Death of Haggard West One Sho',
#  'Joe Golem',
#  'Mcmlxxv',
#  'Killer Modus Vivendi',
#  'Image Firsts Revival Curr Pt',
#  'Memoir',
#  'Harbinger',
#  'New Mutants Dead Souls',
#  'King City',
#  'Dark Engine',
#  'Mantle',
#  'Thanos Vs Hulk',
#  'Escape From New York',
#  'Goddess Mode',
#  'Groo Friends and Foes',
#  'Prism Stalker',
#  'Serenity Float Out One Shot',
#  'Seven To Eternity Giant Size',
#  'Symbiote Spider-Man',
#  'Green Hornet Year One',
#  'Savior',
#  'Atomic Robo Deadly Art of Sci',
#  'War of Realms War Scrolls',
#  'Journey To Star Wars Last Jed',
#  'Transformers Prime Beast Hunt',
#  'Now Black Panther',
#  'Penguin Pain and Prejudice',
#  'Gi Joe',
#  'Flashpoint the World of Flash',
#  'Doctor Strange Last Days of M',
#  'Hellboy and Bprd 1954',
#  'Shadows On the Grave',
#  'Strain Night Eternal',
#  'Men of War',
#  'Violent Love',
#  'Atlas',
#  'Convergence Justice League',
#  'Death of Wolverine Weapon X P',
#  'Material',
#  'Hellboy and Bprd 1955 Occult In',
#  'Loeg Tempest',
#  'Weatherman',
#  'Batman Odyssey VOL 2',
#  'Frostbite',
#  'Ghostbusters International',
#  'Zodiac Starforce',
#  'Criminal Sinners',
#  'Dark Knights Rising the Wild',
#  'Helena Crash',
#  'Mae',
#  'Darth Vader Annual',
#  'The Humans',
#  'True Believers Infinity Gaunt',
#  'Star Wars Screaming Citadel',
#  'Fear Agent',
#  'Knight and Squire',
#  'Jim Henson Power of Dark Crys',
#  'Itty Bitty Hellboy',
#  'Halcyon',
#  'Tmnt Dimension X',
#  'Secret Identities',
#  'Hadrians Wall',
#  'Wonder Woman Rebirth',
#  'Luke Cage',
#  'Great Ten',
#  'Tmnt Bebop and Rocksteady Destr',
#  'Will Eisner Spirit',
#  'Grrl Scouts Magic Socks',
#  'Robotech',
#  'Go-Bots',
#  'Flashpoint Hal Jordan',
#  'Angela Queen of Hel',
#  'Buzzard',
#  'Unstoppable Wasp',
#  'Lookouts Riddle VOL 01',
#  'Civil War Ii Amazing Spider-M',
#  'All New Doop',
#  'Aquaman Annual',
#  'John Byrne Next Men',
#  'Star Wars Special C-3po',
#  'Slots',
#  'Pestilence',
#  'Mera Queen of Atlantis',
#  'Joyride',
#  'Spider-Girls',
#  'Motor Crush',
#  'Billy the Kid Ghastly Fiend L',
#  'Convergence Green Lantern Par',
#  'Dark Tower Battle',
#  'Darth Maul',
#  'Harley Quinn and Suicide Squad',
#  'Faith (Ongoing)',
#  'Lantern City',
#  'Suicide Squad Most Wanted Dea',
#  'Star Trek Vs Transformers',
#  'Injustice Vs the Masters of t',
#  'Marvel Team-Up',
#  'Motherlands',
#  'Bullet To the Head',
#  'Minimum Wage',
#  'Heroic Age Prince of Power',
#  'Hunt For Wolverine Claws of K',
#  'Magnus Robot Fighter',
#  'Midnighter and Apollo',
#  'Red Hood Lost Days',
#  'Ei8ht',
#  'Metalocalypse Dethklok',
#  'D4ve',
#  'Hunt For Wolverine Mystery Ma',
#  'X Classified',
#  'Killmonger',
#  'Spider-Man and X-Men',
#  'Deadpool and Mercs For Money',
#  'Atomic Robo Knights O/T Golde',
#  'X-Men Prime',
#  'Criminal Savage Ed Magazine S',
#  'Mother Panic Gotham a D',
#  'Hercules',
#  'Hellboy and Bprd 1954 Ghost M',
#  'Jacked',
#  'Image Firsts Saga Curr Ptg',
#  'New Lieutenants of Metal',
#  '30 Days of Night',
#  'Invincible Iron Man Annual',
#  'Twilight Zone Lost Tales One',
#  'Think Tank',
#  'Agents of Shield',
#  'All New X-Men Special',
#  'Edge of Spider-Geddon',
#  'Michael Avon Oemings Victorie',
#  'Batman 66 Meets Wonder Woman',
#  'Poison Ivy Cycle of Life and',
#  'Devolution',
#  'Disney Star Vs the Forces of',
#  'Astounding Wolf-Man',
#  'Bprd Hell On Earth Pickens Co',
#  'Xenoholics',
#  'Mage Hero Denied',
#  'Age of Ultron Vs Marvel Zombi',
#  'Convergence Superman',
#  'Flashpoint Emperor Aquaman',
#  'Deadpool Kills Deadpool',
#  'Gft Coven',
#  'Cloudia and Rex',
#  'Quantum and Woody',
#  'Tmnt Villain Microseries',
#  'Mystery Science Theater 3000',
#  'Dv8 Gods and Monsters',
#  'Eye of Newt',
#  'Bruce Wayne the Road Home Bat',
#  'Ronin Island',
#  'The Spider',
#  'Walt Disney Comics and Stories',
#  'Hawkeye and Mockingbird',
#  'Mice Templar IV Legend',
#  'Walking Dead the Governor Spe',
#  'Hunt For Wolverine Weapon Los',
#  'Pathfinder',
#  'E Is For Extinction',
#  'Jla Gods and Monsters',
#  'Age of X-Man Apocalypse and X',
#  'Motro',
#  'Power Up',
#  'Star Wars Legacy Ii',
#  'Justice League Darkseid War S',
#  'Fear Itself Home Front',
#  'Hero Comics 2011 (One Shot',
#  'Sun Bakery',
#  'Vengeance',
#  'Roger Langridges Snarked',
#  'X-Tinction Agenda',
#  'Die!Die!Die!',
#  'Briggs Land',
#  'Batman Kings of Fear',
#  'Blackest Night Untold Tales o',
#  'Lobster Johnson Scent of Lotu',
#  'Mask Mobile Armored Strike Ko',
#  'Prowler',
#  'True Believers Venom Vs Spide',
#  'Franken-Castle',
#  'Welcome Back',
#  'Burn the Orphanage Reign of T',
#  'Gft Robyn Hood I Love Ny',
#  'Gasolina',
#  'Robin Rises Omega',
#  'Civil War Ii Choosing Sides',
#  'Planet O/T Apes Cataclysm',
#  'Future Quest Showcase',
#  'Deadpool Too Soon',
#  'Sundowners',
#  'Vote Loki',
#  'Wonder Woman 77 Bionic Woman',
#  'Shadow Midnight Moscow',
#  'Before Watchmen Moloch',
#  'Lord of the Jungle',
#  'Evolution',
#  'Cyber Force',
#  'Weird Detective',
#  'My Little Pony Legends of Mag',
#  'Wormwood Goes To Washington',
#  'Todd the Ugliest Kid On Eart',
#  'Green Lantern Corps Annual',
#  'Wicked and Divine 1831 One Sho',
#  'House of Penance',
#  '1872',
#  'Carnage Usa',
#  'Kirby Genesis',
#  'Dollhouse Epitaphs',
#  'Man-Thing',
#  'Spookhouse',
#  'Battlefields 09-10',
#  '12 Reasons To Die',
#  'Flashpoint Lois Lane and the',
#  'Assassinistas',
#  'X-Men Hellbound',
#  'Ghostbusters Crossing Over',
#  'Captain America and Iron Man',
#  'Image Firsts Invincible',
#  'Star Wars Doctor Aphra Annua',
#  'Deathlok',
#  'Batman and Batgirl',
#  'Tales Designed To Thrizzle',
#  'Disney Princess',
#  'George Perez Sirens',
#  'Family Trade',
#  'Tom Strong and the Planet of',
#  'Hellboy Double Feature of Evi',
#  'Batman Widening Gyre',
#  'Hunt For Wolverine',
#  'Mirror',
#  'Star Trek Countdown To Darkne',
#  'X-Files (2016)',
#  'Criminal Special Ed One Shot',
#  'Marvel Zombies',
#  'Harvest',
#  'Bprd Hell On Earth Return O/',
#  'Wolverine and X-Men Alpha an',
#  'Rinse',
#  'Planet of Apes Green Lantern',
#  'Convergence Speed Force',
#  'No Place Like Home',
#  'Green Lantern the Animated Se',
#  'Flash Rebirth',
#  'Judge Dredd Blessed Earth',
#  'Batwoman Annual',
#  'Dick Tracy Dead Or Alive',
#  'Batman and Nightwing',
#  'Hellboy In Mexico Or Drunken',
#  'Spy Seal',
#  'Amazing Spider-Man Special',
#  'Cape 1969',
#  'Animosity Evolution',
#  'Paradiso',
#  'Astro City the Dark Age Book',
#  'Sentry',
#  'Demo VOL 2',
#  'Black Panther Vs Deadpool',
#  'Penny Dreadful',
#  'Howling Commandos of Shield',
#  'Skin and Earth',
#  'Fear Itself Deadpool',
#  'Buffy the Vampire Slayer Spik',
#  'Uncanny X-Men Special',
#  'Batman Who Laughs the Grim Kn',
#  'Vader Dark Visions',
#  'Red Hood Outlaw',
#  'Tmnt Ghostbusters',
#  'Hit-Girl #1 (of 5) (Mr) (Pp',
#  'Legenderry a Steampunk Adv',
#  'Deadpool the Duck',
#  'Survivors Club',
#  'Image Firsts Manhattan Projec',
#  'Burn the Orphanage Born To Lo',
#  'Zombies Vs Robots',
#  'Magic the Gathering Theros',
#  'Sideways',
#  'Lobster Johnson Metal Monster',
#  'Chew Demon Chicken Poyo',
#  'Renato Jones One Percent',
#  'Convergence Harley Quinn',
#  'Batman Superman Annual',
#  'Dexter',
#  'Batman and Catwoman',
#  'Last Contract',
#  'Snapshot',
#  'Marvel Legac',
#  'X-Force Sex and Violence',
#  'Divided States of Hysteria',
#  'Emerald City of Oz',
#  'Star-Lord and Kitty Pryde',
#  'Scribblenauts Unmasked Crisi',
#  'Astonishing X-Men Annual',
#  'Superior Carnage',
#  'Thanos Annual',
#  'Modok Assassin',
#  'Star Wars Vader Dark Visions',
#  'American Vampire Anthology',
#  'Mister Terrific',
#  'Deadman',
#  'Henchgirl',
#  'Wonder Twins',
#  'Infinity Wars Arachknight',
#  'Skylanders',
#  'Wrath of the Eternal Warrior',
#  'Winnebago Graveyard',
#  'Joe Golem Occult Detective Ou',
#  'Now Champions',
#  'Superman Family Adventures',
#  'Captain America and Black Wid',
#  'Bprd Hell On Earth Monsters',
#  'Brothers Dracul',
#  'Untold Tales of Punisher Max',
#  'Transformers Monstrosity',
#  'Gotham City Garage',
#  'Spike',
#  'Drumhellar (Previously Strang',
#  'Magnificent Ms Marvel',
#  'Deadpool Mercs For Money',
#  'Hack Slash Resurrection',
#  'Unexpected',
#  'Blackcross',
#  'Strain the Fall',
#  'Infinity Wars Weapon Hex',
#  'Infinity Wars Soldier Suprem',
#  'Teenage Mutant Ninja Turtles',
#  'Lockjaw',
#  'Image Firsts Outcast',
#  'Amazing X-Men Annual',
#  'Black Dynamite',
#  'Rat Bastards',
#  'Where Monsters Dwell',
#  'Bprd Hell On Earth Exorcism',
#  'Popeye Classics Ongoing',
#  '21st Century Tank Girl',
#  'Damage',
#  'Marvel Knights Spider-Man',
#  'Transformers Heart Darkness',
#  'Generations Morales and Parker',
#  'High Level',
#  'Glitterbomb',
#  'Solomon Kane Red Shadows',
#  'X-Men Gold Annual',
#  'Nightworld',
#  'Hellraiser Masterpieces',
#  'Deadpool Back In Black',
#  'Avengers Annual 2013',
#  'Convergence Wonder Woman',
#  'Cataclysm Ultimates',
#  'Mice Templar VOL 3',
#  'Exit Stage Left the Snagglepu',
#  'Ant-Man and the Wasp',
#  'Star Wars Rebel Heist',
#  'Fantastic Four Wedding Specia',
#  'Domino',
#  'Hellboy Being Human One Sho',
#  'God Complex',
#  'Superior Spider-Man Team Up S',
#  'Flashpoint Frankenstein Creat',
#  'A Voice In the Dark',
#  'Flashpoint Citizen Cold',
#  'Jetsons',
#  'Tales of Suspense',
#  'Locke and Key Guide To Known Ke',
#  'Locke and Key Small Worl',
#  'Flashpoint the Outsider',
#  'Magic the Gathering',
#  'Paybacks',
#  'Convergence Flash',
#  'Convergence Nightwing Oracle',
#  'Star Wars Dawn of the Jedi',
#  'Neil Gaiman American Gods Mom',
#  'Star Wars Darth Vader and Lost',
#  'Falcon',
#  'Journey Star Wars Last Jedi C',
#  'Titans Annual',
#  'Infinity Wars Iron Hammer',
#  'Tiny Titans Return To the Tre',
#  'Hulkverines',
#  'Now Black Panther World of Wa',
#  'Hyperion',
#  'Baltimore Empty Graves',
#  'Timely Comics Moon Girl and D',
#  'Goosebumps Download and Die',
#  'Cage',
#  'Port of Earth',
#  'Generation X',
#  'Guardians of Galaxy Annual',
#  'Gunning For Hits',
#  'World of Tanks',
#  '47 Ronin',
#  'Buffy the Vampire Slayer Rile',
#  'Spontaneous',
#  'Dark Knight Returns the Last',
#  'Tyson Hesse Diesel',
#  'Cover',
#  'X-Men Second Coming',
#  'Mystic',
#  'Convergence Detective Comics',
#  'Secret Empire Brave New Worl',
#  'Wytches Bag Egg Halloween Spe',
#  'Mrs Deadpool and Howling Comm',
#  'Figment',
#  'Morbius Living Vampire',
#  'Telos',
#  'Civil War Ii X-Men',
#  'Punisher Platoon',
#  'Gft Grimm Tales of Terror',
#  'Vertigo Quarterly',
#  'Lady Mechanika La Dama De La',
#  'Britannia',
#  'Flash Gordon Zeitgeist',
#  'Venom First Host',
#  'Warning',
#  'Larks Killer',
#  'Ghostbusters 101',
#  'Baltimore the Red Kingdom',
#  'Old Lady Harley',
#  'King Conan Conqueror',
#  'Old Man Quill',
#  'Hellboy Winter Special 2016',
#  'Green Lantern Red Lanterns',
#  'Saviors',
#  'Infinity 8',
#  'Fury of Firestorm',
#  'Rise of the Black Flame',
#  'Skybourne',
#  'Korvac Saga',
#  'Tmnt Amazing Adventures',
#  'Angel Illyria',
#  'Fight Like a Girl',
#  'Assassin Nation',
#  'Eerie Comics',
#  'Doctor Who Ongoing',
#  'Godzilla Cataclysm',
#  'Cataclysm Ultimate X-Men',
#  'Superannuated Man',
#  'Goldie Vance',
#  'Nightwing Rebirth',
#  'Green Lanterns Rebirth',
#  'Grand Passion',
#  'Justice League Futures End',
#  'Divinity',
#  'Zombies Vs Robots Aventure',
#  'Jim Hensons Storyteller Witch',
#  'Pitiful Human Lizard',
#  'Hotwire Deep Cut',
#  'Elric the Balance Lost',
#  'Flash Gordon',
#  'Silver Surfer Black',
#  "Cap'n Dinosaur One Sho",
#  'Graveyard of Empires',
#  'James Bond Kill Chain',
#  'Batman the Devastator',
#  'Hawkeye Annual',
#  'Gotg and X-Men Black Vortex O',
#  '1602 Witch Hunter Angela',
#  'Haunted Mansion',
#  'Beasts of Burden Presence of',
#  'Star Wars Darth Vader Ghost P',
#  'Archer and Armstrong (New)',
#  'Now Jessica Jones',
#  'Superman Rebirth',
#  'This Damned Band',
#  'Marvel Universe Avengers Asse',
#  'Star Wars Invasion Rescues',
#  'Demon Hell Is Earth',
#  'Last Days of American Crime',
#  'Mercenary Sea',
#  'Orc Stain',
#  'Kim and Kim',
#  'Marvel Comics Presents',
#  'Adventures of Superman (2013',
#  'Batman Creature of the Night',
#  'Amazing Spider-Man/Venom Veno',
#  'Convergence Swamp Thing',
#  'Groo Vs Conan',
#  'Wonder Woman and Jl Dark Witchi',
#  'Beasts of Burden',
#  'Blackwood',
#  'Mech Cadet Yu',
#  'Skyward',
#  'Baltimore Witch of Harju',
#  'House of M',
#  'Transformers Windblade Combin',
#  'Last Broadcast',
#  'Namor First Mutant',
#  'Hero Cats',
#  'Convergence Green Lantern Cor',
#  'Citizen Jack',
#  'Star Trek Tng Terra Incognit',
#  'Lodger',
#  'Convergence Action Comics',
#  'Rocketeer At War',
#  'Demonic',
#  'Infinity Entity',
#  'Taskmaster',
#  'Team 7',
#  'Calexit',
#  'Marvel Rising',
#  'Gladstones School For World C',
#  'Ragemoor',
#  'Black Cat',
#  'Katana',
#  'Hellboy Krampusnacht',
#  'Kill Shakespeare',
#  'Major X',
#  'Image United',
#  'Drums',
#  'King Conan Hour O/T Dragon',
#  'Sherlock Holmes Liverpool Dem',
#  'Justice League Cry For',
#  'Alters',
#  'Injustice Ground Zero',
#  'Doomwar',
#  'Uncanny',
#  'Locke and Key Grindhouse One Sh',
#  'Guardians of Galaxy Galaxys M',
#  'Amazing Spider-Man and Silk S',
#  'Come Into Me',
#  'Xerxes Fall of House of Dariu',
#  'Shade the Changing Woman',
#  'Lobster Johnson Pirates Ghos',
#  'Monocyte',
#  'Original Sin Annual',
#  'Disney Frozen',
#  'Miss Fury',
#  'Mighty Thor Gates of Valhall',
#  'Secret Empire Omega',
#  'Stan Lee Starborn',
#  'Few',
#  'Hellboy Bprd 1953 Witch Tree',
#  'Transformers Sins of Wrecker',
#  'Inhumanity Spider-Man',
#  'Hellboy and Bprd 1953 Phantom H',
#  'Kingsman Red Diamond',
#  'Dead Rabbit',
#  'Realm of Kings Inhumans',
#  'Goners',
#  'Batwoman Rebirth',
#  'Usagi Yojimbo Senso',
#  'Gft Jungle Book Fall Wild',
#  'Archer and Armstrong (Vu)',
#  'Baltimore Infernal Train',
#  'Spider-Island Cloak and Dagge',
#  'Hex Wives',
#  'Death Vigil',
#  'Future Quest Presents',
#  'Convergence New Teen Titans',
#  'Now Mighty Thor',
#  'Batman the Red Death',
#  'It Will All Hurt',
#  'Mystery Society',
#  'My Little Pony Micro Series',
#  'Analog',
#  'Forever Evil Argus',
#  'Fear Itself Spider-Man',
#  'Superman Secret Origin',
#  'Batman the Drowned',
#  'Farscape Ongoing',
#  'Batman and Carrie Kelley',
#  'Red She-Hulk',
#  'Now Captain America Steve Rog',
#  'Convergence Adventures of Sup',
#  'Transformers Primacy',
#  'Star Trek Khan',
#  'Darkness',
#  'Now Invincible Iron Man',
#  'Infinite Dark',
#  'She Wolf',
#  'Now Avengers',
#  ...]

# %% [markdown]
# ## It's the Scraping.

# %%
# for title in sample_titles:
# #     print(title)
cs.scrape_series_covers(browser, titles_searching)
# Out:
# Scraped 0.Rick and Morty Vs Dungeons and Dr!
# Scraped 1.Goon Once Upon a Hard Time!
# Scraped 2.Black Bolt!
# Scraped 3.Conan Road of Kings!
# 4.Constantine Hellblazer City o was skipped. No title matched.
# Scraped 5.Trinity of Sin the Phantom St!
# 6.X-O Manowar (Ongoing) was skipped. No title matched.
# Scraped 7.Death of Wolverine Logan Lega!
# Scraped 8.Ballad of Sang!
# Scraped 9.Star Wars Thrawn!
# Scraped 10.Phantom Stranger!
# Scraped 11.Larfleeze!
# Scraped 12.Airboy!
# 13.Superior Spider-Man Annual was skipped. No title matched.
# Scraped 14.Ghost!
# Scraped 15.Suiciders!
# Scraped 16.Rasputin Voice of Dragon!
# Scraped 17.Spider-Man Life Story!
# Scraped 18.Godzilla Gangsters and Goliath!
# 19.Gft Robyn Hood Ongoing was skipped. No title matched.
# 20.Animal Man Annual was skipped. No title matched.
# Scraped 21.Axe Cop Bad Guy Earth!
# Scraped 22.Drumhellar!
# Scraped 23.Dark Tower Gunslinger!
# 24.Now Doctor Strange was skipped. No title matched.
# Scraped 25.Godzilla Kingdom of Monsters!
# Scraped 26.Robin Rises Alpha!
# Scraped 27.Captain Midnight!
# Scraped 28.X-O Manowar!
# 29.Ad After Death Book 02 (of 3 was skipped. No title matched.
# Scraped 30.The Squidder!
# Scraped 31.Fantastic Four Annual!
# Scraped 32.Cry Havoc!
# Scraped 33.Wasteland!
# Scraped 34.Captain Atom!
# Scraped 35.Tales From the Darkside!
# Scraped 36.Bullseye!
# 37.Captain Marvel and Carol Corp was skipped. No title matched.
# 38.Action Comics Annual was skipped. No title matched.
# Scraped 39.Five Weapons!
# Scraped 40.Spider-Geddon!
# Scraped 41.Herc!
# Scraped 42.Umbral!
# Scraped 43.Dark Tower Gunslinger Way Sta!
# Scraped 44.Mythic!
# Scraped 45.Marvelous Land of Oz!
# Scraped 46.Punk Rock Jesus!
# Scraped 47.Arkham Manor!
# Scraped 48.Bunker!
# Scraped 49.Plastic Man!
# Scraped 50.Flintstones!
# Scraped 51.Ninjak!
# 52.Gft Realm War was skipped. No title matched.
# Scraped 53.Eclipse!
# Scraped 54.Glory!
# Scraped 55.Hellraiser Dark Watch!
# 56.Wonder Woman 77 Special was skipped. No title matched.
# 57.Black Hammer 45 From World o was skipped. No title matched.
# Scraped 58.Robin War!
# Scraped 59.James Bond Hammerhead!
# Scraped 60.Chin Music!
# 61.Doctor Who 11th was skipped. No title matched.
# 62.Rose was skipped. No covers were found.
# Scraped 63.Wonder Woman Conan!
# 64.Star Wars Classified was skipped. No title matched.
# Scraped 65.Cataclysm Ultimate Spider-Ma!
# Scraped 66.Doctor Strange Sorcerers Supr!
# Scraped 67.Crosswind!
# Scraped 68.Midas Flesh!
# Scraped 69.Men of Wrath!
# Scraped 70.Savage Avengers!
# Scraped 71.Pearl!
# Scraped 72.Bitter Root!
# Scraped 73.Snowfall!
# Scraped 74.Man Without Fear!
# 75.Twilight Zone SandS was skipped. No title matched.
# Scraped 76.Stand Hardcases!
# Scraped 77.Infinity Man and the Forever!
# Scraped 78.Deadpool Vs Old Man Logan!
# Scraped 79.Vampirella!
# Scraped 80.Realm!
# Scraped 81.Sixth Gun Valley of Death!
# 82.Judge Dredd (Ongoing) was skipped. No title matched.
# Scraped 83.Rebels These Free and Independe!
# 84.Gft Oz was skipped. No title matched.
# Scraped 85.Deathbed!
# Scraped 86.Sword of Sorcery!
# 87.Harley and Ivy Meet Betty and Ver was skipped. No title matched.
# Scraped 88.I Zombie!
# Scraped 89.Original Sins!
# Scraped 90.Giant Size Little Marvel Avx!
# Scraped 91.Surface!
# 92.Swamp Thing Annual was skipped. No title matched.
# Scraped 93.Hip Hop Family Tree!
# Scraped 94.Flavor!
# Scraped 95.Superman Annual!
# Scraped 96.Jean Grey!
# Scraped 97.Visitor How and Why He Staye!
# Scraped 98.Donald Duck!
# 99.Image Giant Sized Artists Pro was skipped. No title matched.
# Scraped 100.Halo Rise of Atriox!
# Scraped 101.Ravagers!
# Scraped 102.Superior Spider-Man Team Up!
# Scraped 103.Spirit!
# Scraped 104.Ascender!
# Scraped 105.Vinegar Teeth!
# Scraped 106.Titans Hunt!
# 107.Star Trek Tng Doctor Who Assi was skipped. No title matched.
# Scraped 108.Walking Dead Michonne Specia!
# Scraped 109.Mysterious Strangers!
# Scraped 110.Conan the Slayer!
# Scraped 111.Insexts!
# Scraped 112.Rockstars!
# Scraped 113.October Faction!
# Scraped 114.Slayer Repentless!
# Scraped 115.Batman 66 Meets Green Hornet!
# Scraped 116.Captain America and Hawkeye!
# Scraped 117.Green Lantern New Gods Godhea!
# Scraped 118.Haunted Horror!
# Scraped 119.Age of X-Man Amazing Nightcra!
# Scraped 120.Lady Mechanika Tablet of Dest!
# Scraped 121.Saucer Country!
# Scraped 122.Deadpool Kills Marvel Univers!
# Scraped 123.Grimm!
# Scraped 124.Strangers!
# 125.Locke and Key Keys To the Kingd was skipped. No title matched.
# Scraped 126.Suicide Squad Rebirth!
# Scraped 127.Vault!
# Scraped 128.Rocketeer Hollywood Horror!
# Scraped 129.Stand Night Has Come!
# 130.Ad After Death Book 03 (of 3 was skipped. No title matched.
# 131.Star Trek Green Lantern VOL was skipped. No title matched.
# Scraped 132.X-O Manowar (2017)!
# Scraped 133.Near Death!
# Scraped 134.Highest House!
# Scraped 135.Punisher War Zone!
# 136.Pastaways was skipped. No title matched.
# Scraped 137.Batman Arkham Unhinged!
# Scraped 138.Joe Hill the Cape!
# Scraped 139.C.o.w.l.!
# Scraped 140.Spider-Verse Team Up!
# Scraped 141.Witchfinder Mysteries of Unla!
# Scraped 142.Contest of Champions!
# Scraped 143.Black Road!
# Scraped 144.Nighthawk!
# Scraped 145.Doctor Who Prisoners of Time!
# 146.Axe Cop President O/T World was skipped. No title matched.
# Scraped 147.Briggs Land Lone Wolves!
# 148.Hellboy and Bprd 1956 was skipped. No title matched.
# Scraped 149.Rom!
# Scraped 150.Bloodstrike!
# Scraped 151.Batman Odyssey!
# 152.Locke and Key Alpha was skipped. No title matched.
# Scraped 153.Inhumanity!
# 154.Stand No Mans Land was skipped. No title matched.
# Scraped 155.Gravediggers Union!
# Scraped 156.Star-Lord!
# Scraped 157.Squidder!
# Scraped 158.Popeye!
# Scraped 159.First Strike!
# Scraped 160.DC Nation!
# Scraped 161.Iron Man Legacy!
# 162.Doctor Who Ongoing VOL 2 was skipped. No title matched.
# 163.Garth Ennis Jennifer Blood was skipped. No title matched.
# Scraped 164.Creep!
# Scraped 165.War of Realms Uncanny X-Men!
# Scraped 166.Unnatural!
# Scraped 167.Art Ops!
# Scraped 168.Brave and the Bold Batman and Won!
# Scraped 169.Madame Xanadu!
# Scraped 170.Captain America White!
# 171.Billy Kids Oddities and Orm Loc was skipped. No title matched.
# Scraped 172.Star Wars Jedi Republic Mace!
# Scraped 173.Pigs!
# Scraped 174.Star Trek Boldly Go!
# Scraped 175.Deadpool Vs Punisher!
# Scraped 176.Freedom Fighters!
# Scraped 177.Mockingbird!
# Scraped 178.Starfire!
# 179.Vision Directors Cut was skipped. No title matched.
# Scraped 180.Beasts of Burden Wise Dogs an!
# Scraped 181.Dark Days the Casting!
# Scraped 182.Invincible Universe!
# Scraped 183.Hexed!
# Scraped 184.Baltimore Plague Ships!
# Scraped 185.Multiversity Thunderworld!
# Scraped 186.Atomic Robo Ghost of Station!
# Scraped 187.Star Wars Darth Maul!
# Scraped 188.Avengers X-Sanction!
# Scraped 189.He Man Thundercats!
# 190.Americas Got Powers was skipped. No title matched.
# Scraped 191.New Avengers Finale!
# 192.Gft Code Red was skipped. No title matched.
# Scraped 193.Batman the Return!
# Scraped 194.Debris!
# Scraped 195.Illuminati!
# Scraped 196.Aliens Defiance!
# Scraped 197.Storm!
# Scraped 198.Hoax Hunters!
# Scraped 199.Bodies!
# Scraped 200.Avx Consequences!
# Scraped 201.Starve!
# Scraped 202.Mickey Mouse!
# 203.Sidekick was skipped. No covers were found.
# Scraped 204.Inferno!
# Scraped 205.Little Nemo Return To Slumber!
# Scraped 206.Evil Empire!
# Scraped 207.Godzilla Rage Across Time!
# Scraped 208.Star Wars Old Republic!
# Scraped 209.Sword Daughter!
# Scraped 210.Sword of Ages!
# Scraped 211.Star Wars Lando Double Or Not!
# 212.Bprd Hell On Earth Long Deat was skipped. No title matched.
# Scraped 213.Movement!
# Scraped 214.Great Lakes Avengers!
# Scraped 215.Casanova Gula!
# Scraped 216.Deadpool Vs Carnage!
# Scraped 217.Dark Corridor!
# Scraped 218.Massive Ninth Wave!
# Scraped 219.Cosmic Ghost Rider Destroys M!
# Scraped 220.Scooby Doo Team Up!
# Scraped 221.Proof Endangered!
# Scraped 222.Age of X-Man Nextgen!
# Scraped 223.Sledgehammer 44!
# Scraped 224.Generation Gone!
# 225.Love and Rockets Magazine was skipped. No title matched.
# Scraped 226.Age of X-Man Marvelous X-Men!
# 227.Uncanny Avengers Annual was skipped. No title matched.
# Scraped 228.Archer and Armstrong!
# Scraped 229.Rocketeer Spirit Pulp Frictio!
# 230.Batman and the Signal was skipped. No title matched.
# Scraped 231.Hungry Ghosts!
# 232.Thor Annual was skipped. No title matched.
# Scraped 233.Red Skull!
# Scraped 234.Murder Book!
# Scraped 235.Ragnarok!
# Scraped 236.Joe Golem Occult Detective!
# Scraped 237.Runlovekill!
# Scraped 238.Batman Arkham City!
# 239.Stray Bullets the Killers was skipped. No title matched.
# Scraped 240.Invaders!
# Scraped 241.Chew Secret Agent Poyo!
# Scraped 242.Night of Living Deadpool!
# Scraped 243.Fiction!
# Scraped 244.Shadow Roads!
# Scraped 245.Bully Wars!
# Scraped 246.Star Wars Adventures!
# Scraped 247.Ducktales!
# Scraped 248.The Damned!
# Scraped 249.Jim Henson Labyrinth Coronati!
# 250.Quantum Age From World of Bla was skipped. No title matched.
# Scraped 251.Red One!
# 252.Godzilla Rulers of the Earth was skipped. No title matched.
# Scraped 253.Batman Futures End!
# Scraped 254.Capt Victory and Galactic Range!
# Scraped 255.Ruse!
# 256.Bprd Hell On Earth Gods was skipped. No title matched.
# Scraped 257.Rai!
# Scraped 258.Wolverine Max!
# Scraped 259.Naomi!
# Scraped 260.Ghostbusters!
# Scraped 261.Storm Dogs!
# Scraped 262.Cowboy Ninja Viking!
# Scraped 263.Flashpoint Project Superman!
# 264.Star Trek City O/T Edge of Fo was skipped. No title matched.
# Scraped 265.Roche Limit Clandestiny!
# Scraped 266.The Lone Ranger!
# Scraped 267.Stellar!
# Scraped 268.Dark Days the Forge!
# Scraped 269.Empty Zone!
# Scraped 270.Shadow Show!
# 271.New Avengers Annual was skipped. No title matched.
# 272.Bprd King of Fear was skipped. No title matched.
# Scraped 273.Forever Evil Arkham War!
# Scraped 274.Mouse Guard Black Axe!
# Scraped 275.Atomic Robo Savage Sword of D!
# Scraped 276.Batman Last Knight On Earth!
# Scraped 277.Master of Kung Fu!
# Scraped 278.Maxx Maxximized!
# Scraped 279.Brilliant!
# 280.Shield Infinit was skipped. No title matched.
# Scraped 281.Strange Fruit!
# Scraped 282.Bucky Barnes Winter Soldier!
# Scraped 283.Strange Talent of Luther Stro!
# Scraped 284.Batman Incorporated Leviatha!
# Scraped 285.Exodus Life After!
# 286.Ether Copper Golems was skipped. No title matched.
# Scraped 287.Silencer!
# Scraped 288.Winter Soldier Bitter March!
# Scraped 289.Teen Titans Annual!
# Scraped 290.Black!
# Scraped 291.Secret Wars 2099!
# 292.Now Unworthy Thor was skipped. No title matched.
# Scraped 293.Ame Comi Girls!
# Scraped 294.Toil and Trouble!
# Scraped 295.Tomb Raider!
# Scraped 296.Buffy the Vampire Slayer Will!
# Scraped 297.Effigy!
# Scraped 298.Infinity Wars Sleepwalker!
# Scraped 299.Catalyst Comix!
# Scraped 300.Multiversity Ultra Comics!
# 301.Peanuts VOL 2 was skipped. No title matched.
# Scraped 302.Huntress!
# Scraped 303.Strain!
# Scraped 304.Hawk and Dove!
# Scraped 305.Border Town!
# Scraped 306.Star Wars Solo Adaptation!
# Scraped 307.Go Go Power Rangers!
# Scraped 308.Masks!
# Scraped 309.Avengers Undercover!
# Scraped 310.It Girl and the Atomics!
# Scraped 311.Squadron Sinister!
# 312.Gft Hellchild was skipped. No title matched.
# Scraped 313.Undying Love!
# Scraped 314.Help Us Great Warrior!
# Scraped 315.Annihilators!
# Scraped 316.Eternity Girl!
# Scraped 317.Stumptown!
# Scraped 318.Symmetry!
# Scraped 319.Red Thorn!
# Scraped 320.Inhumans Once Future Kings!
# Scraped 321.War of Realms New Agents of A!
# Scraped 322.Flashpoint Wonder Woman and t!
# Scraped 323.Amazing Forest!
# Scraped 324.Injustice Gods Among Us!
# Scraped 325.Invisible Kingdom!
# Scraped 326.Angel Season 11!
# 327.Gft Presents Apocalypse was skipped. No title matched.
# Scraped 328.Crimson Lotus!
# Scraped 329.A Plus X!
# Scraped 330.Batman Rebirth!
# 331.Screamland Ongoing was skipped. No title matched.
# Scraped 332.Orchid!
# Scraped 333.Sledgehammer 44 Lightning Wa!
# Scraped 334.Flashpoint Abin Sur the Gree!
# 335.Rush Clockwork Angels was skipped. No title matched.
# Scraped 336.Transformers Windblade!
# Scraped 337.Age of X-Man X-Tremists!
# Scraped 338.Faith!
# Scraped 339.Hunt For Wolverine Adamantiu!
# Scraped 340.Annihilators Earthfall!
# Scraped 341.And Then Emily Was Gone!
# Scraped 342.Prophet Strikefile!
# 343.Bprd Hell On Earth Devils Eng was skipped. No title matched.
# Scraped 344.Rebel Blood!
# Scraped 345.Casanova!
# Scraped 346.Daredevil Reborn!
# 347.Gft Warlord of Oz was skipped. No title matched.
# Scraped 348.Brave and the Bold!
# Scraped 349.Nick Fury!
# 350.Godzilla Ongoing was skipped. No title matched.
# Scraped 351.Walk Through Hell!
# 352.Hillbilly Red Eyed Witchery F was skipped. No title matched.
# 353.Angela Asgards Assassin was skipped. No title matched.
# Scraped 354.Daredevil Dark Nights!
# Scraped 355.Planetoid!
# Scraped 356.Where Is Jake Ellis!
# Scraped 357.Punisher In Blood!
# Scraped 358.Stranger Things!
# Scraped 359.Horizon!
# Scraped 360.Star Wars Last Jedi Adaptatio!
# 361.Rogue and Gambit was skipped. No title matched.
# Scraped 362.Egos!
# Scraped 363.Road To Oz!
# 364.Gft Tales From Oz was skipped. No title matched.
# Scraped 365.Star Wars Legacy War!
# Scraped 366.Farscape!
# Scraped 367.Half Past Danger!
# Scraped 368.Casanova Avaritia!
# 369.Batman Jokers Daughter was skipped. No title matched.
# 370.Criminal 10th Anniversary Spe was skipped. No title matched.
# Scraped 371.Black Panther Most Dangerous!
# Scraped 372.War of Realms Punisher!
# 373.Deadpool Vs Gambit was skipped. No title matched.
# 374.Batman Lil Gotham was skipped. No title matched.
# 375.Bprd Dead Remembered was skipped. No title matched.
# Scraped 376.X-Men Schism Prelude!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-38-81df47bc598e> in <module>()
#       1 # for title in sample_titles:
#       2 # #     print(title)
# ----> 3 cs.scrape_series_covers(browser, titles_searching)
#
# ~/Dropbox/flatiron/capstone/comics_rx/lib/comic_scraper.py in scrape_series_covers(browser, titles)
#      42             # Once in cover gallery, just scrape the first image
#      43             try:
# ---> 44                 get_first_image(browser, title)
#      45                 print("Scraped {}.{}!".format(idx, title))
#      46             except NoSuchElementException:
#
# ~/Dropbox/flatiron/capstone/comics_rx/lib/comic_scraper.py in get_first_image(browser, title)
#     150
#     151     # Save the file in the file/path
# --> 152     scrape_image(first_img, filename)
#     153
#     154     return
#
# ~/Dropbox/flatiron/capstone/comics_rx/lib/comic_scraper.py in scrape_image(img, filename)
#     158     response = requests.get(img.get_attribute('src'))
#     159     img_data = response.content
# --> 160     with open(filename, 'wb') as f:
#     161         f.write(img_data)
#     162
#
# FileNotFoundError: [Errno 2] No such file or directory: './raw_data/covers/chew_/_revival.jpg'
