# %%
import pandas as pd

# %%
# !ls
# Out:
# __init__.py                      data_fcns.py
# __pycache__                      dev
# comic_recs.py                    geckodriver.log
# comic_scraper.py                 keys.py
# create_lists_for_dropdowns.ipynb webapp

# %%
path = './dev/support_data/comics.json'

# %%
comics = pd.read_json(path, lines=True)

# %%
comic_ids = comics['comic_id'].tolist()

# %%
comic_titles = comics['comic_title'].tolist()

# %%
comic_ids[:4]
# Out:
# [1, 2, 3, 4]

# %%
comic_titles[:10]
# Out:
# ['0Secret Wars (Marvel)',
#  '100 Bullets Brother Lono (DC)',
#  '100 Penny Press Locke & Key (IDW)',
#  '100 Penny Press Star Trek (IDW)',
#  '100 Penny Press Thunder Agent (IDW)',
#  '100 Penny Press Tmnt (IDW)',
#  '100th Anniversary Special (Marvel)',
#  '12 Reasons To Die (Other)',
#  '13 Coins (Other)',
#  '13th Artifact One Sho (Topcow)']

# %%
# !pwd
# Out:
# /Users/werlindo/Dropbox/flatiron/capstone/comics_rx/comrx

# %%
import pandas as pd
import requests
import random
import time
import os

# Data storage
from sqlalchemy import create_engine # SQL helper
import keys     # Custom keys lib
import psycopg2 as psql #PostgreSQL DBs

# %%
# Define path to secret
secret_path_aws = os.path.join(os.environ['HOME'], '.secret', 
                           'aws_ps_flatiron.json')
secret_path_aws
# Out:
# '/Users/werlindo/.secret/aws_ps_flatiron.json'

# %%
aws_keys = keys.get_keys(secret_path_aws)
user = aws_keys['user']
ps = aws_keys['password']
host = aws_keys['host']
db = aws_keys['db_name']

aws_ps_engine = ('postgresql://' + user + ':' + ps + '@' + host + '/' + db)

# Setup PSQL connection
conn = psql.connect(
    database=db,
    user=user,
    password=ps,
    host=host,
    port='5432'
)

# %%
# Instantiate cursor
cur = conn.cursor()

# %%
query = """SELECT * FROM comics limit 10;"""

# %%
#  Count records.
query = """
    SELECT ct.*, c.comic_id, c.img_url 
    from comic_trans ct
    inner join comics c on ct.comic_title = c.comic_title;
"""

# %%
# Execute the query
cur.execute(query)

# %%
# Check results
temp_df = pd.DataFrame(cur.fetchall())
temp_df.columns = [col.name for col in cur.description]

temp_df.head(3)
# Out:
#    index                       publisher    item_id             title_and_num  \
# 0      2  Amaze Ink Slave Labor Graphics  DCD151935           Filler Bunny #2
# 1      3  Amaze Ink Slave Labor Graphics  DCD341726              Gargoyles #6
# 2      4  Amaze Ink Slave Labor Graphics  DCD416182  Royal Historian of Oz #1
#
#    qty_sold           date_sold account_num                  comic_title  \
# 0         1 2011-08-14 18:01:03       00174           Filler Bunny (SLG)
# 1         1 2012-06-22 14:11:37       00593              Gargoyles (SLG)
# 2         1 2010-07-21 14:03:07       00226  Royal Historian of Oz (SLG)
#
#    comic_id                                            img_url
# 0      2291  https://comrx.s3-us-west-2.amazonaws.com/cover...
# 1      2445  https://comrx.s3-us-west-2.amazonaws.com/cover...
# 2      5178  https://comrx.s3-us-west-2.amazonaws.com/cover...

# %%
# Zombie Tramp is annoying.
temp_df = temp_df[~temp_df["comic_title"].str.contains('Zombie Tramp')]

# %%
qtys = (temp_df.groupby(['comic_id','comic_title','img_url'], as_index=False)
        .qty_sold.sum().sort_values(by=['qty_sold'], ascending=False).copy())

# %%
top_100 = qtys.head(100)

# %%
top_100 = (top_100.sort_values(by=['comic_title'], ascending=True).
                    loc[:,['comic_id', 'comic_title','img_url']]).copy()

# %%
pd.set_option('display.max_colwidth', -1)

# %%
top_100
# Out:
#       comic_id                          comic_title  \
# 80    81        Action Comics (DC)
# 197   198       All New X-Men (Marvel)
# 223   224       Amazing Spider-Man (Marvel)
# 277   278       Animal Man (DC)
# 318   319       Aquaman (DC)
# 387   388       Astonishing X-Men (Marvel)
# 432   433       Avengers (2010) (Marvel)
# 454   455       Avengers (Marvel)
# 551   552       Batgirl (DC)
# 609   610       Batman (DC)
# 618   619       Batman Eternal (DC)
# 647   648       Batman Superman (DC)
# 577   578       Batman and Robin (DC)
# 690   691       Batwoman (DC)
# 803   804       Black Hammer (Dark Horse)
# 828   829       Black Panther (Marvel)
# 837   838       Black Science (Image)
# 959   960       Brightest Day (DC)
# 991   992       Btvs Season 9 Freefall (Dark Horse)
# 1076  1077      Captain America (Marvel)
# 1142  1143      Catwoman (DC)
# 1213  1214      Chew (Image)
# 1344  1345      Convergence (DC)
# 1491  1492      Daredevil (Marvel)
# 1559  1560      Darth Vader (Marvel)
# 1708  1709      Deadpool (Marvel)
# 1800  1801      Descender (Image)
# 1806  1807      Detective Comics (DC)
# 1905  1906      Doctor Strange (Marvel)
# 1962  1963      Doomsday Clock (DC)
# ...    ...                      ...
# 5505  5506      Sixth Gun (Oni)
# 5599  5600      Southern Bastards (Image)
# 5658  5659      Spider-Man Deadpool (Marvel)
# 5835  5836      Star Wars (Dark Horse)
# 5881  5882      Star Wars (Marvel)
# 5991  5992      Suicide Squad (DC)
# 6018  6019      Supergirl (DC)
# 6035  6036      Superior Spider-Man (Marvel)
# 6051  6052      Superman (DC)
# 6068  6069      Superman Unchained (DC)
# 6098  6099      Swamp Thing (DC)
# 6104  6105      Sweet Tooth (Vertigo)
# 6174  6175      Teen Titans (DC)
# 6242  6243      Thief of Thieves (Image)
# 6261  6262      Thor (Marvel)
# 6259  6260      Thor God of Thunder (Marvel)
# 6666  6667      Ultimate Comics Spider-Man (Marvel)
# 6680  6681      Unbeatable Squirrel Girl (Marvel)
# 6683  6684      Uncanny Avengers (Marvel)
# 6691  6692      Uncanny X-Force (Marvel)
# 6693  6694      Uncanny X-Men (Marvel)
# 6721  6722      Unwritten (Vertigo)
# 6760  6761      Venom (Marvel)
# 6823  6824      Walking Dead (Image)
# 6936  6937      Wicked & Divine (Image)
# 6986  6987      Wolverine and X-Men (Marvel)
# 7020  7021      Wonder Woman (DC)
# 7078  7079      X-Factor (Marvel)
# 7125  7126      X-Men (Marvel)
# 7124  7125      X-Men Legacy (Marvel)
#
#                                                                              img_url
# 80    https://comrx.s3-us-west-2.amazonaws.com/covers/action_comics.jpg
# 197   https://comrx.s3-us-west-2.amazonaws.com/covers/all_new_x-men.jpg
# 223   https://comrx.s3-us-west-2.amazonaws.com/covers/amazing_spider-man.jpg
# 277   https://comrx.s3-us-west-2.amazonaws.com/covers/animal_man.jpg
# 318   https://comrx.s3-us-west-2.amazonaws.com/covers/aquaman.jpg
# 387   https://comrx.s3-us-west-2.amazonaws.com/covers/astonishing_x-men.jpg
# 432   https://comrx.s3-us-west-2.amazonaws.com/covers/avengers_(2010).jpg
# 454   https://comrx.s3-us-west-2.amazonaws.com/covers/avengers.jpg
# 551   https://comrx.s3-us-west-2.amazonaws.com/covers/batgirl.jpg
# 609   https://comrx.s3-us-west-2.amazonaws.com/covers/batman.jpg
# 618   https://comrx.s3-us-west-2.amazonaws.com/covers/batman_eternal.jpg
# 647   https://comrx.s3-us-west-2.amazonaws.com/covers/batman_superman.jpg
# 577   https://comrx.s3-us-west-2.amazonaws.com/covers/batman_and_robin.jpg
# 690   https://comrx.s3-us-west-2.amazonaws.com/covers/batwoman.jpg
# 803   https://comrx.s3-us-west-2.amazonaws.com/covers/black_hammer.jpg
# 828   https://comrx.s3-us-west-2.amazonaws.com/covers/black_panther.jpg
# 837   https://comrx.s3-us-west-2.amazonaws.com/covers/black_science.jpg
# 959   https://comrx.s3-us-west-2.amazonaws.com/covers/brightest_day.jpg
# 991   https://comrx.s3-us-west-2.amazonaws.com/covers/btvs_season_9.jpg
# 1076  https://comrx.s3-us-west-2.amazonaws.com/covers/captain_america.jpg
# 1142  https://comrx.s3-us-west-2.amazonaws.com/covers/catwoman.jpg
# 1213  https://comrx.s3-us-west-2.amazonaws.com/covers/chew.jpg
# 1344  https://comrx.s3-us-west-2.amazonaws.com/covers/convergence.jpg
# 1491  https://comrx.s3-us-west-2.amazonaws.com/covers/daredevil.jpg
# 1559  https://comrx.s3-us-west-2.amazonaws.com/covers/darth_vader.jpg
# 1708  https://comrx.s3-us-west-2.amazonaws.com/covers/deadpool.jpg
# 1800  https://comrx.s3-us-west-2.amazonaws.com/covers/descender.jpg
# 1806  https://comrx.s3-us-west-2.amazonaws.com/covers/detective_comics.jpg
# 1905  https://comrx.s3-us-west-2.amazonaws.com/covers/doctor_strange.jpg
# 1962  https://comrx.s3-us-west-2.amazonaws.com/covers/doomsday_clock.jpg
# ...                                                                  ...
# 5505  https://comrx.s3-us-west-2.amazonaws.com/covers/sixth_gun.jpg
# 5599  https://comrx.s3-us-west-2.amazonaws.com/covers/southern_bastards.jpg
# 5658  https://comrx.s3-us-west-2.amazonaws.com/covers/spider-man_deadpool.jpg
# 5835  https://comrx.s3-us-west-2.amazonaws.com/covers/star_wars_dark_horse.jpg
# 5881  https://comrx.s3-us-west-2.amazonaws.com/covers/star_wars_marvel.jpg
# 5991  https://comrx.s3-us-west-2.amazonaws.com/covers/suicide_squad.jpg
# 6018  https://comrx.s3-us-west-2.amazonaws.com/covers/supergirl.jpg
# 6035  https://comrx.s3-us-west-2.amazonaws.com/covers/superior_spider-man.jpg
# 6051  https://comrx.s3-us-west-2.amazonaws.com/covers/superman.jpg
# 6068  https://comrx.s3-us-west-2.amazonaws.com/covers/superman_unchained.jpg
# 6098  https://comrx.s3-us-west-2.amazonaws.com/covers/swamp_thing.jpg
# 6104  https://comrx.s3-us-west-2.amazonaws.com/covers/sweet_tooth.jpg
# 6174  https://comrx.s3-us-west-2.amazonaws.com/covers/teen_titans.jpg
# 6242  https://comrx.s3-us-west-2.amazonaws.com/covers/thief_of_thieves.jpg
# 6261  https://comrx.s3-us-west-2.amazonaws.com/covers/thor.jpg
# 6259  https://comrx.s3-us-west-2.amazonaws.com/covers/thor_god_of_thunder.jpg
# 6666  https://comrx.s3-us-west-2.amazonaws.com/covers/ultimate_comics_spider-man.jpg
# 6680  https://comrx.s3-us-west-2.amazonaws.com/covers/unbeatable_squirrel_girl.jpg
# 6683  https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_avengers.jpg
# 6691  https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_x-force.jpg
# 6693  https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_x-men.jpg
# 6721  https://comrx.s3-us-west-2.amazonaws.com/covers/unwritten.jpg
# 6760  https://comrx.s3-us-west-2.amazonaws.com/covers/venom.jpg
# 6823  https://comrx.s3-us-west-2.amazonaws.com/covers/walking_dead.jpg
# 6936  https://comrx.s3-us-west-2.amazonaws.com/covers/wicked_divine.jpg
# 6986  https://comrx.s3-us-west-2.amazonaws.com/covers/wolverine_and_x-men.jpg
# 7020  https://comrx.s3-us-west-2.amazonaws.com/covers/wonder_woman.jpg
# 7078  https://comrx.s3-us-west-2.amazonaws.com/covers/x-factor.jpg
# 7125  https://comrx.s3-us-west-2.amazonaws.com/covers/x-men.jpg
# 7124  https://comrx.s3-us-west-2.amazonaws.com/covers/x-men_legacy.jpg
#
# [100 rows x 3 columns]

# %%
listy = []
for i, row in top_100.iterrows():
    listy.append((row['comic_title'], row['img_url']))

# %%
listy
# Out:
# [('Action Comics (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/action_comics.jpg'),
#  ('All New X-Men (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/all_new_x-men.jpg'),
#  ('Amazing Spider-Man (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/amazing_spider-man.jpg'),
#  ('Animal Man (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/animal_man.jpg'),
#  ('Aquaman (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/aquaman.jpg'),
#  ('Astonishing X-Men (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/astonishing_x-men.jpg'),
#  ('Avengers (2010) (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg'),
#  ('Avengers (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/avengers.jpg'),
#  ('Batgirl (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batgirl.jpg'),
#  ('Batman (DC)', 'https://comrx.s3-us-west-2.amazonaws.com/covers/batman.jpg'),
#  ('Batman Eternal (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batman_eternal.jpg'),
#  ('Batman Superman (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batman_superman.jpg'),
#  ('Batman and Robin (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batman_and_robin.jpg'),
#  ('Batwoman (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batwoman.jpg'),
#  ('Black Hammer (Dark Horse)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/black_hammer.jpg'),
#  ('Black Panther (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/black_panther.jpg'),
#  ('Black Science (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/black_science.jpg'),
#  ('Brightest Day (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/brightest_day.jpg'),
#  ('Btvs Season 9 Freefall (Dark Horse)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg'),
#  ('Captain America (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/captain_america.jpg'),
#  ('Catwoman (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/catwoman.jpg'),
#  ('Chew (Image)', 'https://comrx.s3-us-west-2.amazonaws.com/covers/chew.jpg'),
#  ('Convergence (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/convergence.jpg'),
#  ('Daredevil (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/daredevil.jpg'),
#  ('Darth Vader (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/darth_vader.jpg'),
#  ('Deadpool (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/deadpool.jpg'),
#  ('Descender (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/descender.jpg'),
#  ('Detective Comics (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/detective_comics.jpg'),
#  ('Doctor Strange (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/doctor_strange.jpg'),
#  ('Doomsday Clock (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/doomsday_clock.jpg'),
#  ('East of West (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/east_of_west.jpg'),
#  ('Fables (Vertigo)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/fables.jpg'),
#  ('Fantastic Four (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/fantastic_four.jpg'),
#  ('Fatale (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/fatale.jpg'),
#  ('Ff (Marvel)', 'https://comrx.s3-us-west-2.amazonaws.com/covers/ff.jpg'),
#  ('Flash (DC)', 'https://comrx.s3-us-west-2.amazonaws.com/covers/flash.jpg'),
#  ('God Is Dead (Avatar)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/god_is_dead.jpg'),
#  ('Green Arrow (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/green_arrow.jpg'),
#  ('Green Lantern (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/green_lantern.jpg'),
#  ('Green Lantern Corps (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/green_lantern_corps.jpg'),
#  ('Guardians of Galaxy (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/guardians_of_galaxy.jpg'),
#  ('Harley Quinn (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg'),
#  ('Harrow County (Dark Horse)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/harrow_county.jpg'),
#  ('Hawkeye (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/hawkeye.jpg'),
#  ('Invader Zim (Oni)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/invader_zim.jpg'),
#  ('Invincible (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/invincible.jpg'),
#  ('Invincible Iron Man (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/invincible_iron_man.jpg'),
#  ('Journey Into Mystery (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/journey_into_mystery.jpg'),
#  ('Justice League (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/justice_league.jpg'),
#  ('Justice League of America (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/justice_league_of_america.jpg'),
#  ('Kill Or Be Killed (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/kill_or_be_killed.jpg'),
#  ('Lazarus (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/lazarus.jpg'),
#  ('Lumberjanes (Boom)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/lumberjanes.jpg'),
#  ('Manhattan Projects (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/manhattan_projects.jpg'),
#  ('Mighty Thor (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/mighty_thor.jpg'),
#  ('Moon Knight (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/moon_knight.jpg'),
#  ('Ms Marvel (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/ms_marvel.jpg'),
#  ('New Avengers (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/new_avengers.jpg'),
#  ('Nightwing (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/nightwing.jpg'),
#  ('Old Man Logan (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/old_man_logan.jpg'),
#  ('Outcast By Kirkman & Azaceta (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg'),
#  ('Paper Girls (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/paper_girls.jpg'),
#  ('Rachel Rising (Other)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/rachel_rising.jpg'),
#  ('Saga (Image)', 'https://comrx.s3-us-west-2.amazonaws.com/covers/saga.jpg'),
#  ('Sandman Overture (Vertigo)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/sandman_overture.jpg'),
#  ('Scalped (Vertigo)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/scalped.jpg'),
#  ('Secret Avengers (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/secret_avengers.jpg'),
#  ('Secret Empire (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/secret_empire.jpg'),
#  ('Secret Wars (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/secret_wars.jpg'),
#  ('Sex Criminals (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/sex_criminals.jpg'),
#  ('Sixth Gun (Oni)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/sixth_gun.jpg'),
#  ('Southern Bastards (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/southern_bastards.jpg'),
#  ('Spider-Man Deadpool (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/spider-man_deadpool.jpg'),
#  ('Star Wars (Dark Horse)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/star_wars.jpg'),
#  ('Star Wars (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/star_wars.jpg'),
#  ('Suicide Squad (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/suicide_squad.jpg'),
#  ('Supergirl (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/supergirl.jpg'),
#  ('Superior Spider-Man (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/superior_spider-man.jpg'),
#  ('Superman (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/superman.jpg'),
#  ('Superman Unchained (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/superman_unchained.jpg'),
#  ('Swamp Thing (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/swamp_thing.jpg'),
#  ('Sweet Tooth (Vertigo)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/sweet_tooth.jpg'),
#  ('Teen Titans (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/teen_titans.jpg'),
#  ('Thief of Thieves (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/thief_of_thieves.jpg'),
#  ('Thor (Marvel)', 'https://comrx.s3-us-west-2.amazonaws.com/covers/thor.jpg'),
#  ('Thor God of Thunder (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/thor_god_of_thunder.jpg'),
#  ('Ultimate Comics Spider-Man (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/ultimate_comics_spider-man.jpg'),
#  ('Unbeatable Squirrel Girl (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/unbeatable_squirrel_girl.jpg'),
#  ('Uncanny Avengers (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_avengers.jpg'),
#  ('Uncanny X-Force (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_x-force.jpg'),
#  ('Uncanny X-Men (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_x-men.jpg'),
#  ('Unwritten (Vertigo)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/unwritten.jpg'),
#  ('Venom (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/venom.jpg'),
#  ('Walking Dead (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/walking_dead.jpg'),
#  ('Wicked & Divine (Image)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg'),
#  ('Wolverine and X-Men (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/wolverine_and_x-men.jpg'),
#  ('Wonder Woman (DC)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/wonder_woman.jpg'),
#  ('X-Factor (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/x-factor.jpg'),
#  ('X-Men (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/x-men.jpg'),
#  ('X-Men Legacy (Marvel)',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/x-men_legacy.jpg')]

# %%
top_100_dict = top_100.to_dict('list')

# %%
top_100_dict
# Out:
# {'comic_id': [81,
#   198,
#   224,
#   278,
#   319,
#   388,
#   433,
#   455,
#   552,
#   610,
#   619,
#   648,
#   578,
#   691,
#   804,
#   829,
#   838,
#   960,
#   992,
#   1077,
#   1143,
#   1214,
#   1345,
#   1492,
#   1560,
#   1709,
#   1801,
#   1807,
#   1906,
#   1963,
#   2041,
#   2171,
#   2217,
#   2228,
#   2281,
#   2318,
#   2680,
#   2763,
#   2783,
#   2779,
#   2842,
#   2939,
#   2950,
#   2975,
#   3386,
#   3388,
#   3390,
#   3568,
#   3630,
#   3643,
#   3700,
#   3820,
#   3982,
#   4028,
#   4248,
#   4316,
#   4351,
#   4455,
#   4503,
#   4632,
#   4677,
#   4701,
#   4919,
#   5196,
#   5212,
#   5238,
#   5284,
#   5286,
#   5318,
#   5348,
#   5506,
#   5600,
#   5659,
#   5836,
#   5882,
#   5992,
#   6019,
#   6036,
#   6052,
#   6069,
#   6099,
#   6105,
#   6175,
#   6243,
#   6262,
#   6260,
#   6667,
#   6681,
#   6684,
#   6692,
#   6694,
#   6722,
#   6761,
#   6824,
#   6937,
#   6987,
#   7021,
#   7079,
#   7126,
#   7125],
#  'comic_title': ['Action Comics (DC)',
#   'All New X-Men (Marvel)',
#   'Amazing Spider-Man (Marvel)',
#   'Animal Man (DC)',
#   'Aquaman (DC)',
#   'Astonishing X-Men (Marvel)',
#   'Avengers (2010) (Marvel)',
#   'Avengers (Marvel)',
#   'Batgirl (DC)',
#   'Batman (DC)',
#   'Batman Eternal (DC)',
#   'Batman Superman (DC)',
#   'Batman and Robin (DC)',
#   'Batwoman (DC)',
#   'Black Hammer (Dark Horse)',
#   'Black Panther (Marvel)',
#   'Black Science (Image)',
#   'Brightest Day (DC)',
#   'Btvs Season 9 Freefall (Dark Horse)',
#   'Captain America (Marvel)',
#   'Catwoman (DC)',
#   'Chew (Image)',
#   'Convergence (DC)',
#   'Daredevil (Marvel)',
#   'Darth Vader (Marvel)',
#   'Deadpool (Marvel)',
#   'Descender (Image)',
#   'Detective Comics (DC)',
#   'Doctor Strange (Marvel)',
#   'Doomsday Clock (DC)',
#   'East of West (Image)',
#   'Fables (Vertigo)',
#   'Fantastic Four (Marvel)',
#   'Fatale (Image)',
#   'Ff (Marvel)',
#   'Flash (DC)',
#   'God Is Dead (Avatar)',
#   'Green Arrow (DC)',
#   'Green Lantern (DC)',
#   'Green Lantern Corps (DC)',
#   'Guardians of Galaxy (Marvel)',
#   'Harley Quinn (DC)',
#   'Harrow County (Dark Horse)',
#   'Hawkeye (Marvel)',
#   'Invader Zim (Oni)',
#   'Invincible (Image)',
#   'Invincible Iron Man (Marvel)',
#   'Journey Into Mystery (Marvel)',
#   'Justice League (DC)',
#   'Justice League of America (DC)',
#   'Kill Or Be Killed (Image)',
#   'Lazarus (Image)',
#   'Lumberjanes (Boom)',
#   'Manhattan Projects (Image)',
#   'Mighty Thor (Marvel)',
#   'Moon Knight (Marvel)',
#   'Ms Marvel (Marvel)',
#   'New Avengers (Marvel)',
#   'Nightwing (DC)',
#   'Old Man Logan (Marvel)',
#   'Outcast By Kirkman & Azaceta (Image)',
#   'Paper Girls (Image)',
#   'Rachel Rising (Other)',
#   'Saga (Image)',
#   'Sandman Overture (Vertigo)',
#   'Scalped (Vertigo)',
#   'Secret Avengers (Marvel)',
#   'Secret Empire (Marvel)',
#   'Secret Wars (Marvel)',
#   'Sex Criminals (Image)',
#   'Sixth Gun (Oni)',
#   'Southern Bastards (Image)',
#   'Spider-Man Deadpool (Marvel)',
#   'Star Wars (Dark Horse)',
#   'Star Wars (Marvel)',
#   'Suicide Squad (DC)',
#   'Supergirl (DC)',
#   'Superior Spider-Man (Marvel)',
#   'Superman (DC)',
#   'Superman Unchained (DC)',
#   'Swamp Thing (DC)',
#   'Sweet Tooth (Vertigo)',
#   'Teen Titans (DC)',
#   'Thief of Thieves (Image)',
#   'Thor (Marvel)',
#   'Thor God of Thunder (Marvel)',
#   'Ultimate Comics Spider-Man (Marvel)',
#   'Unbeatable Squirrel Girl (Marvel)',
#   'Uncanny Avengers (Marvel)',
#   'Uncanny X-Force (Marvel)',
#   'Uncanny X-Men (Marvel)',
#   'Unwritten (Vertigo)',
#   'Venom (Marvel)',
#   'Walking Dead (Image)',
#   'Wicked & Divine (Image)',
#   'Wolverine and X-Men (Marvel)',
#   'Wonder Woman (DC)',
#   'X-Factor (Marvel)',
#   'X-Men (Marvel)',
#   'X-Men Legacy (Marvel)'],
#  'img_url': ['https://comrx.s3-us-west-2.amazonaws.com/covers/action_comics.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/all_new_x-men.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/amazing_spider-man.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/animal_man.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/aquaman.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/astonishing_x-men.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/avengers.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batgirl.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batman.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batman_eternal.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batman_superman.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batman_and_robin.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/batwoman.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/black_hammer.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/black_panther.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/black_science.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/brightest_day.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/captain_america.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/catwoman.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/chew.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/convergence.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/daredevil.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/darth_vader.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/deadpool.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/descender.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/detective_comics.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/doctor_strange.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/doomsday_clock.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/east_of_west.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/fables.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/fantastic_four.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/fatale.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/ff.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/flash.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/god_is_dead.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/green_arrow.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/green_lantern.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/green_lantern_corps.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/guardians_of_galaxy.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/harrow_county.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/hawkeye.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/invader_zim.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/invincible.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/invincible_iron_man.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/journey_into_mystery.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/justice_league.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/justice_league_of_america.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/kill_or_be_killed.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/lazarus.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/lumberjanes.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/manhattan_projects.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/mighty_thor.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/moon_knight.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/ms_marvel.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/new_avengers.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/nightwing.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/old_man_logan.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/paper_girls.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/rachel_rising.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/saga.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/sandman_overture.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/scalped.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/secret_avengers.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/secret_empire.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/secret_wars.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/sex_criminals.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/sixth_gun.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/southern_bastards.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/spider-man_deadpool.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/star_wars.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/star_wars.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/suicide_squad.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/supergirl.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/superior_spider-man.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/superman.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/superman_unchained.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/swamp_thing.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/sweet_tooth.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/teen_titans.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/thief_of_thieves.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/thor.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/thor_god_of_thunder.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/ultimate_comics_spider-man.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/unbeatable_squirrel_girl.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_avengers.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_x-force.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_x-men.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/unwritten.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/venom.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/walking_dead.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/wolverine_and_x-men.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/wonder_woman.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/x-factor.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/x-men.jpg',
#   'https://comrx.s3-us-west-2.amazonaws.com/covers/x-men_legacy.jpg']}

# %%
zaz = pd.DataFrame(top_100_dict)

# %%
zaz
# Out:
#     comic_id                          comic_title
# 0         81                   Action Comics (DC)
# 1        198               All New X-Men (Marvel)
# 2        224          Amazing Spider-Man (Marvel)
# 3        278                      Animal Man (DC)
# 4        319                         Aquaman (DC)
# 5        388           Astonishing X-Men (Marvel)
# 6        433             Avengers (2010) (Marvel)
# 7        455                    Avengers (Marvel)
# 8        552                         Batgirl (DC)
# 9        610                          Batman (DC)
# 10       619                  Batman Eternal (DC)
# 11       648                 Batman Superman (DC)
# 12       578                Batman and Robin (DC)
# 13       691                        Batwoman (DC)
# 14       804            Black Hammer (Dark Horse)
# 15       829               Black Panther (Marvel)
# 16       838                Black Science (Image)
# 17       960                   Brightest Day (DC)
# 18       992  Btvs Season 9 Freefall (Dark Horse)
# 19      1077             Captain America (Marvel)
# 20      1143                        Catwoman (DC)
# 21      1214                         Chew (Image)
# 22      1345                     Convergence (DC)
# 23      1492                   Daredevil (Marvel)
# 24      1560                 Darth Vader (Marvel)
# 25      1709                    Deadpool (Marvel)
# 26      1801                    Descender (Image)
# 27      1807                Detective Comics (DC)
# 28      1906              Doctor Strange (Marvel)
# 29      1963                  Doomsday Clock (DC)
# ..       ...                                  ...
# 70      5506                      Sixth Gun (Oni)
# 71      5600            Southern Bastards (Image)
# 72      5659         Spider-Man Deadpool (Marvel)
# 73      5836               Star Wars (Dark Horse)
# 74      5882                   Star Wars (Marvel)
# 75      6019                       Supergirl (DC)
# 76      6036         Superior Spider-Man (Marvel)
# 77      6052                        Superman (DC)
# 78      6069              Superman Unchained (DC)
# 79      6099                     Swamp Thing (DC)
# 80      6105                Sweet Tooth (Vertigo)
# 81      6175                     Teen Titans (DC)
# 82      6243             Thief of Thieves (Image)
# 83      6262                        Thor (Marvel)
# 84      6260         Thor God of Thunder (Marvel)
# 85      6667  Ultimate Comics Spider-Man (Marvel)
# 86      6681    Unbeatable Squirrel Girl (Marvel)
# 87      6684            Uncanny Avengers (Marvel)
# 88      6692             Uncanny X-Force (Marvel)
# 89      6694               Uncanny X-Men (Marvel)
# 90      6722                  Unwritten (Vertigo)
# 91      6761                       Venom (Marvel)
# 92      6824                 Walking Dead (Image)
# 93      6937              Wicked & Divine (Image)
# 94      6987         Wolverine and X-Men (Marvel)
# 95      7021                    Wonder Woman (DC)
# 96      7079                    X-Factor (Marvel)
# 97      7126                       X-Men (Marvel)
# 98      7125                X-Men Legacy (Marvel)
# 99      7193         Zombie Tramp Ongoing (Other)
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Export back out to csv

# %%
top_100.to_csv('../webapp/templates/dev_files/top_100_comics.csv', 
               index=False)

# %%
# !head ../webapp/templates/dev_files/top_100_comics.csv
# Out:
# comic_id,comic_title,img_url
# 81,Action Comics (DC),https://comrx.s3-us-west-2.amazonaws.com/covers/action_comics.jpg
# 198,All New X-Men (Marvel),https://comrx.s3-us-west-2.amazonaws.com/covers/all_new_x-men.jpg
# 224,Amazing Spider-Man (Marvel),https://comrx.s3-us-west-2.amazonaws.com/covers/amazing_spider-man.jpg
# 278,Animal Man (DC),https://comrx.s3-us-west-2.amazonaws.com/covers/animal_man.jpg
# 319,Aquaman (DC),https://comrx.s3-us-west-2.amazonaws.com/covers/aquaman.jpg
# 388,Astonishing X-Men (Marvel),https://comrx.s3-us-west-2.amazonaws.com/covers/astonishing_x-men.jpg
# 433,Avengers (2010) (Marvel),https://comrx.s3-us-west-2.amazonaws.com/covers/avengers_(2010).jpg
# 455,Avengers (Marvel),https://comrx.s3-us-west-2.amazonaws.com/covers/avengers.jpg
# 552,Batgirl (DC),https://comrx.s3-us-west-2.amazonaws.com/covers/batgirl.jpg

# %% [markdown]
# ### Make lists

# %%
coms = pd.read_csv('./webapp/templates/dev_files/top_100_comics.csv')

# %%
coms.head()
# Out:
#    comic_id                  comic_title  \
# 0  81        Action Comics (DC)
# 1  198       All New X-Men (Marvel)
# 2  224       Amazing Spider-Man (Marvel)
# 3  278       Animal Man (DC)
# 4  319       Aquaman (DC)
#
#                                                                   img_url
# 0  https://comrx.s3-us-west-2.amazonaws.com/covers/action_comics.jpg
# 1  https://comrx.s3-us-west-2.amazonaws.com/covers/all_new_x-men.jpg
# 2  https://comrx.s3-us-west-2.amazonaws.com/covers/amazing_spider-man.jpg
# 3  https://comrx.s3-us-west-2.amazonaws.com/covers/animal_man.jpg
# 4  https://comrx.s3-us-west-2.amazonaws.com/covers/aquaman.jpg

# %%
coms2 = coms.loc[:['comic_title','img_url']].copy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-b493df554c27> in <module>()
# ----> 1 coms2 = coms.loc[:['comic_title','img_url']].copy()
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1864         if isinstance(key, slice):
#    1865             self._validate_key(key, axis)
# -> 1866             return self._get_slice_axis(key, axis=axis)
#    1867         elif com.is_bool_indexer(key):
#    1868             return self._getbool_axis(key, axis=axis)
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1509         labels = obj._get_axis(axis)
#    1510         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop,
# -> 1511                                        slice_obj.step, kind=self.name)
#    1512
#    1513         if isinstance(indexer, slice):
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4105         """
#    4106         start_slice, end_slice = self.slice_locs(start, end, step=step,
# -> 4107                                                  kind=kind)
#    4108
#    4109         # return a slice
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    4312         end_slice = None
#    4313         if end is not None:
# -> 4314             end_slice = self.get_slice_bound(end, 'right', kind)
#    4315         if end_slice is None:
#    4316             end_slice = len(self)
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4236         # we need to look up the label
#    4237         try:
# -> 4238             slc = self._get_loc_only_exact_matches(label)
#    4239         except KeyError as err:
#    4240             try:
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in _get_loc_only_exact_matches(self, key)
#    4205         get_slice_bound.
#    4206         """
# -> 4207         return self.get_loc(key)
#    4208
#    4209     def get_slice_bound(self, label, side, kind):
#
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3076                                  'backfill or nearest lookups')
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#    3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['comic_title', 'img_url']' is an invalid key

# %%
coms2
# Out:
#                             comic_title  \
# 0   Action Comics (DC)
# 1   All New X-Men (Marvel)
# 2   Amazing Spider-Man (Marvel)
# 3   Animal Man (DC)
# 4   Aquaman (DC)
# 5   Astonishing X-Men (Marvel)
# 6   Avengers (2010) (Marvel)
# 7   Avengers (Marvel)
# 8   Batgirl (DC)
# 9   Batman (DC)
# 10  Batman Eternal (DC)
# 11  Batman Superman (DC)
# 12  Batman and Robin (DC)
# 13  Batwoman (DC)
# 14  Black Hammer (Dark Horse)
# 15  Black Panther (Marvel)
# 16  Black Science (Image)
# 17  Brightest Day (DC)
# 18  Btvs Season 9 Freefall (Dark Horse)
# 19  Captain America (Marvel)
# 20  Catwoman (DC)
# 21  Chew (Image)
# 22  Convergence (DC)
# 23  Daredevil (Marvel)
# 24  Darth Vader (Marvel)
# 25  Deadpool (Marvel)
# 26  Descender (Image)
# 27  Detective Comics (DC)
# 28  Doctor Strange (Marvel)
# 29  Doomsday Clock (DC)
# ..                  ...
# 70  Sixth Gun (Oni)
# 71  Southern Bastards (Image)
# 72  Spider-Man Deadpool (Marvel)
# 73  Star Wars (Dark Horse)
# 74  Star Wars (Marvel)
# 75  Suicide Squad (DC)
# 76  Supergirl (DC)
# 77  Superior Spider-Man (Marvel)
# 78  Superman (DC)
# 79  Superman Unchained (DC)
# 80  Swamp Thing (DC)
# 81  Sweet Tooth (Vertigo)
# 82  Teen Titans (DC)
# 83  Thief of Thieves (Image)
# 84  Thor (Marvel)
# 85  Thor God of Thunder (Marvel)
# 86  Ultimate Comics Spider-Man (Marvel)
# 87  Unbeatable Squirrel Girl (Marvel)
# 88  Uncanny Avengers (Marvel)
# 89  Uncanny X-Force (Marvel)
# 90  Uncanny X-Men (Marvel)
# 91  Unwritten (Vertigo)
# 92  Venom (Marvel)
# 93  Walking Dead (Image)
# 94  Wicked & Divine (Image)
# 95  Wolverine and X-Men (Marvel)
# 96  Wonder Woman (DC)
# 97  X-Factor (Marvel)
# 98  X-Men (Marvel)
# 99  X-Men Legacy (Marvel)
#
#                                                                            img_url
# 0   https://comrx.s3-us-west-2.amazonaws.com/covers/action_comics.jpg
# 1   https://comrx.s3-us-west-2.amazonaws.com/covers/all_new_x-men.jpg
# 2   https://comrx.s3-us-west-2.amazonaws.com/covers/amazing_spider-man.jpg
# 3   https://comrx.s3-us-west-2.amazonaws.com/covers/animal_man.jpg
# 4   https://comrx.s3-us-west-2.amazonaws.com/covers/aquaman.jpg
# 5   https://comrx.s3-us-west-2.amazonaws.com/covers/astonishing_x-men.jpg
# 6   https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg
# 7   https://comrx.s3-us-west-2.amazonaws.com/covers/avengers.jpg
# 8   https://comrx.s3-us-west-2.amazonaws.com/covers/batgirl.jpg
# 9   https://comrx.s3-us-west-2.amazonaws.com/covers/batman.jpg
# 10  https://comrx.s3-us-west-2.amazonaws.com/covers/batman_eternal.jpg
# 11  https://comrx.s3-us-west-2.amazonaws.com/covers/batman_superman.jpg
# 12  https://comrx.s3-us-west-2.amazonaws.com/covers/batman_and_robin.jpg
# 13  https://comrx.s3-us-west-2.amazonaws.com/covers/batwoman.jpg
# 14  https://comrx.s3-us-west-2.amazonaws.com/covers/black_hammer.jpg
# 15  https://comrx.s3-us-west-2.amazonaws.com/covers/black_panther.jpg
# 16  https://comrx.s3-us-west-2.amazonaws.com/covers/black_science.jpg
# 17  https://comrx.s3-us-west-2.amazonaws.com/covers/brightest_day.jpg
# 18  https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg
# 19  https://comrx.s3-us-west-2.amazonaws.com/covers/captain_america.jpg
# 20  https://comrx.s3-us-west-2.amazonaws.com/covers/catwoman.jpg
# 21  https://comrx.s3-us-west-2.amazonaws.com/covers/chew.jpg
# 22  https://comrx.s3-us-west-2.amazonaws.com/covers/convergence.jpg
# 23  https://comrx.s3-us-west-2.amazonaws.com/covers/daredevil.jpg
# 24  https://comrx.s3-us-west-2.amazonaws.com/covers/darth_vader.jpg
# 25  https://comrx.s3-us-west-2.amazonaws.com/covers/deadpool.jpg
# 26  https://comrx.s3-us-west-2.amazonaws.com/covers/descender.jpg
# 27  https://comrx.s3-us-west-2.amazonaws.com/covers/detective_comics.jpg
# 28  https://comrx.s3-us-west-2.amazonaws.com/covers/doctor_strange.jpg
# 29  https://comrx.s3-us-west-2.amazonaws.com/covers/doomsday_clock.jpg
# ..                                                                 ...
# 70  https://comrx.s3-us-west-2.amazonaws.com/covers/sixth_gun.jpg
# 71  https://comrx.s3-us-west-2.amazonaws.com/covers/southern_bastards.jpg
# 72  https://comrx.s3-us-west-2.amazonaws.com/covers/spider-man_deadpool.jpg
# 73  https://comrx.s3-us-west-2.amazonaws.com/covers/star_wars.jpg
# 74  https://comrx.s3-us-west-2.amazonaws.com/covers/star_wars.jpg
# 75  https://comrx.s3-us-west-2.amazonaws.com/covers/suicide_squad.jpg
# 76  https://comrx.s3-us-west-2.amazonaws.com/covers/supergirl.jpg
# 77  https://comrx.s3-us-west-2.amazonaws.com/covers/superior_spider-man.jpg
# 78  https://comrx.s3-us-west-2.amazonaws.com/covers/superman.jpg
# 79  https://comrx.s3-us-west-2.amazonaws.com/covers/superman_unchained.jpg
# 80  https://comrx.s3-us-west-2.amazonaws.com/covers/swamp_thing.jpg
# 81  https://comrx.s3-us-west-2.amazonaws.com/covers/sweet_tooth.jpg
# 82  https://comrx.s3-us-west-2.amazonaws.com/covers/teen_titans.jpg
# 83  https://comrx.s3-us-west-2.amazonaws.com/covers/thief_of_thieves.jpg
# 84  https://comrx.s3-us-west-2.amazonaws.com/covers/thor.jpg
# 85  https://comrx.s3-us-west-2.amazonaws.com/covers/thor_god_of_thunder.jpg
# 86  https://comrx.s3-us-west-2.amazonaws.com/covers/ultimate_comics_spider-man.jpg
# 87  https://comrx.s3-us-west-2.amazonaws.com/covers/unbeatable_squirrel_girl.jpg
# 88  https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_avengers.jpg
# 89  https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_x-force.jpg
# 90  https://comrx.s3-us-west-2.amazonaws.com/covers/uncanny_x-men.jpg
# 91  https://comrx.s3-us-west-2.amazonaws.com/covers/unwritten.jpg
# 92  https://comrx.s3-us-west-2.amazonaws.com/covers/venom.jpg
# 93  https://comrx.s3-us-west-2.amazonaws.com/covers/walking_dead.jpg
# 94  https://comrx.s3-us-west-2.amazonaws.com/covers/_no_cover_.jpg
# 95  https://comrx.s3-us-west-2.amazonaws.com/covers/wolverine_and_x-men.jpg
# 96  https://comrx.s3-us-west-2.amazonaws.com/covers/wonder_woman.jpg
# 97  https://comrx.s3-us-west-2.amazonaws.com/covers/x-factor.jpg
# 98  https://comrx.s3-us-west-2.amazonaws.com/covers/x-men.jpg
# 99  https://comrx.s3-us-west-2.amazonaws.com/covers/x-men_legacy.jpg
#
# [100 rows x 2 columns]

# %%
ids = coms['comic_id'].tolist()

# %%
titles = coms['comic_title'].tolist()

# %%
ids[:10]
# Out:
# [81, 198, 224, 278, 319, 388, 433, 455, 552, 610]

# %%
titles[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c054aed9ea7c> in <module>()
# ----> 1 titles[:10]
#
# NameError: name 'titles' is not defined

# %%
ddd = ("dfdfdfd" +
        "dfdfdfdf" +
        "dfdfdfdfdf" )
ddd
# Out:
# 'dfdfdfddfdfdfdfdfdfdfdfdf'

# %%
zzz = coms.head(5)['comic_title']

# %%
zzz
# Out:
# 0             Action Comics (DC)
# 1         All New X-Men (Marvel)
# 2    Amazing Spider-Man (Marvel)
# 3                Animal Man (DC)
# 4                   Aquaman (DC)
# Name: comic_title, dtype: object

# %%
type(zzz)
# Out:
# pandas.core.series.Series

# %%
for i, row in zzz.iteritems():
    print(row)
# Out:
# Action Comics (DC)
# All New X-Men (Marvel)
# Amazing Spider-Man (Marvel)
# Animal Man (DC)
# Aquaman (DC)

# %%
import flask

# %%
from flask import Flask, request, render_template, jsonify, session, redirect, make_response

# %%
www = [{'comic_id': 81, 'comic_title': 'Action Comics (DC)'}, {'comic_id': 198, 'comic_title': 'All New X-Men (Marvel)'}, {'comic_id': 224, 'comic_title': 'Amazing Spider-Man (Marvel)'}, {'comic_id': 278, 'comic_title': 'Animal Man (DC)'}, {'comic_id': 319, 'comic_title': 'Aquaman (DC)'}]

# %%
www
# Out:
# [{'comic_id': 81, 'comic_title': 'Action Comics (DC)'},
#  {'comic_id': 198, 'comic_title': 'All New X-Men (Marvel)'},
#  {'comic_id': 224, 'comic_title': 'Amazing Spider-Man (Marvel)'},
#  {'comic_id': 278, 'comic_title': 'Animal Man (DC)'},
#  {'comic_id': 319, 'comic_title': 'Aquaman (DC)'}]

# %%
type(www)
# Out:
# list

# %%
www[0]
# Out:
# {'comic_id': 81, 'comic_title': 'Action Comics (DC)'}

# %%
www[0]['comic_id']
# Out:
# 81
