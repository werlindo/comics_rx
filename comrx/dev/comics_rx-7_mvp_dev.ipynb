# %% [markdown]
# # Comics Rx
# ## [A comic book recommendation system](https://github.com/MangrobanGit/comics_rx)
# <img src="https://images.unsplash.com/photo-1514329926535-7f6dbfbfb114?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=2850&q=80" width="400" align='left'>

# %% [markdown]
# ---

# %% [markdown]
# # Libraries

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %autoreload 1 #would be where you need to specify the files
# %aimport comic_recs

import pandas as pd # dataframes
import os
import pickle

# Data storage
from sqlalchemy import create_engine # SQL helper
#import psycopg2 as psql #PostgreSQL DBs

# import necessary libraries
import pyspark
from pyspark.sql import SparkSession
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.types import (StructType, StructField, IntegerType
                               ,FloatType, LongType, StringType)
# from pyspark.sql.types import *

import pyspark.sql.functions as F
from pyspark.sql.functions import col, explode, lit, isnan, when, count, lower
from pyspark.ml.recommendation import ALS, ALSModel
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder, TrainValidationSplit
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.sql import DataFrame

import time
import itertools
from functools import reduce
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

# %%
sys.path.append('..')

# %%
# Custom
import data_fcns as dfc
import keys  # Custom keys lib
import comic_recs as cr

# %%
# spark config
spark = SparkSession \
    .builder \
    .appName("movie recommendation") \
    .config("spark.driver.maxResultSize", "1g") \
    .config("spark.driver.memory", "1g") \
    .config("spark.executor.memory", "4g") \
    .config("spark.master", "local[*]") \
    .getOrCreate()
# get spark context
#sc = spark.sparkContext

# %% [markdown]
# ## Import Data
#
# We've previously set aside the dataset into a `json` file.

# %%
# We have previously created a version of the transactions table and filtered it down.
sold = spark.read.json('raw_data/als_input_filtered.json')

# %%
# Persist the data
sold.persist()
# Out:
# DataFrame[account_id: bigint, bought: bigint, comic_id: bigint]

# %% [markdown]
# # New Users

# %% [markdown]
# Let's develop an input process that uses titles, rather than pulling the specific person's info from the modeling data.

# %%
comics_df = spark.read.json('support_data/comics.json')
comics_df.persist()
# Out:
# DataFrame[comic_id: bigint, comic_title: string, img_url: string]

# %% [markdown]
# Get lay of land of `comics_df`

# %%
comics_df.show()
# Out:
# +--------+--------------------+--------------------+
# |comic_id|         comic_title|             img_url|
# +--------+--------------------+--------------------+
# |      15|1 For $1 Action P...|https://comrx.s3-...|
# |      17|1 For $1 Axe Cop ...|https://comrx.s3-...|
# |      20|1 For $1 Conan th...|https://comrx.s3-...|
# |      22|1 For $1 Mass Eff...|https://comrx.s3-...|
# |      24|1 For $1 Star War...|https://comrx.s3-...|
# |      27|1 For $1 Usagi Yo...|https://comrx.s3-...|
# |      18|1 For 1 Baltimore...|https://comrx.s3-...|
# |       2|100 Bullets Broth...|https://comrx.s3-...|
# |       4|100 Penny Press S...|https://comrx.s3-...|
# |       6|100 Penny Press T...|https://comrx.s3-...|
# |       8|12 Reasons To Die...|https://comrx.s3-...|
# |       9|    13 Coins (Other)|https://comrx.s3-...|
# |      11|1602 Witch Hunter...|https://comrx.s3-...|
# |      29|2021 Lost Childre...|https://comrx.s3-...|
# |      31|23 Skidoo One Sho...|https://comrx.s3-...|
# |      36|3 Floyds Alpha Ki...|https://comrx.s3-...|
# |      33|30 Days of Night ...|https://comrx.s3-...|
# |      34|32 Stories Comple...|https://comrx.s3-...|
# |      43|4001 A.d. X-O Man...|https://comrx.s3-...|
# |      40|     4001 Ad (Other)|https://comrx.s3-...|
# +--------+--------------------+--------------------+
# only showing top 20 rows

# %%
comics_pandas = comics_df.toPandas()

# %%
sample_buys = ['Spider-Man', 'Paper Girls']

# %%
sample_buys = ['Sweet Tooth', 'Paper Girls']

# %% [markdown]
# ### Get matching 'official titles'

# %%
def get_comic_ids_for_user(comics_df, read_comics_list):
    """
    Given spark DF of existing comics and list of comics to 'match'
    Return list of like comics from the DF
    """
    # Initialize
    similar_comics_list = []
    
    for comic in read_comics_list:
        # print(comic)
        # Search for comic in df
        matched_comics = (comics_df.filter(lower(comics_df['comic_title'])
                                 .contains(str.lower(comic)))
                                 .select('comic_id').rdd
                                 .flatMap(lambda x: x).collect()
                         )
        similar_comics_list.extend(matched_comics)
        
    return similar_comics_list

# %% [markdown]
# #### Testing

# %%
curr_comic_ids = get_comic_ids_for_user(comics_df, sample_buys)

# %%
curr_comic_ids
# Out:
# [6105, 3235, 4701]

# %% [markdown]
# ### Add user

# %%
def create_acct_id(model_data):
    """
    Given model data, create new account id that is just the max existing +1
    """
    # Get max account id
    max_acct_id = model_data.agg({'account_id':'max'}).collect()[0][0]

    # New Account id
    new_acct_id = max_acct_id + 1
    
    return new_acct_id

# %%
def add_new_user(model_data, new_comic_ids, new_acct_id):
    """
    Given existing model data and the comic ids for new user,
    add rows for the new user to model data
    """
#     # Get max account id
#     max_acct_id = model_data.agg({'account_id':'max'}).collect()[0][0]

#     # New Account id
#     new_acct_id = max_acct_id + 1
    
    # Create spark Df of new rows
    new_rows = spark.createDataFrame([
                (new_acct_id, 1, comic_id) for comic_id in new_comic_ids])

    # Append to existing model data
    model_data_new = model_data.union(new_rows)
    
    return model_data_new

# %% [markdown]
# #### Testing

# %%
new_id = create_acct_id(sold)

# %%
test_sold = add_new_user(sold, curr_comic_ids, new_id)

# %%
test_sold.count()
# Out:
# 61874

# %%
sold.count()
# Out:
# 61871

# %% [markdown]
# ### Train On New Data

# %%
# Create dictionary of candidate parameters
current_params = {'maxIter': 10
                  ,'rank': 5
                  ,'regParam': 0.1
                  ,'alpha': 40
                  ,'seed': 41916
                 }

# %%
def train_als(model_data, current_params):
    """
    Given training data and set of parameters
    Returns trained ALS model
    """
    # Create ALS instance for cv with our chosen parametrs
    als_train = ALS(maxIter=current_params.get('maxIter'),
              rank=current_params.get('rank'),
              userCol='account_id',
              itemCol='comic_id',
              ratingCol='bought',
              implicitPrefs=True,
              regParam=current_params.get('regParam'),
              alpha=current_params.get('alpha'),
              coldStartStrategy='nan', # we want to drop so can get through CV
              seed=41916)

    model_train = als_train.fit(model_data)
    return model_train

# %%
als_model = train_als(test_sold, current_params)

# %% [markdown]
# ### Create DF of new user's unbought comics

# %%
def get_comics_to_rate(comics_df, training_comic_ids):
    """
    Given list of comic ids, 
    returns list of ids from master list that don't match
    """
    new_comic_ids = (comics_df.select('comic_id').distinct()
                      .filter(~col('comic_id').isin(curr_comic_ids))
                      .select('comic_id').rdd.flatMap(lambda x: x).collect()
                     )
    return new_comic_ids

# %%
def recommend_n_comics(top_n, new_comics_ids, account_id, als_model, comics_df):
    """
    Given a list of new comics (to the user) and requested number N
    Return list of N comics, ordered descending by recommendation score
    """

    # Create spark Df of new rows
    comics_to_predict = (spark.createDataFrame([
                        (account_id, 1, comic_id) for comic_id in new_comics_ids])
                        .select(col('_1').alias('account_id')
                        ,col('_2').alias('bought')
                        ,col('_3').alias('comic_id'))
                        )

    # Get predictions
    test_preds = als_model.transform(comics_to_predict)
    test_preds.persist()

    # Alias
    cdf = comics_df.alias('cdf')
    tp = test_preds.alias('tp')

    # Query results
    results = (tp.join(cdf, tp.comic_id==cdf.comic_id)
                .filter(~isnan(col('prediction')))
                .orderBy('prediction', ascending=False)
                .select('comic_title', 'img_url')
                .limit(top_n)
              ).toPandas()

    return results

# %%
def make_comic_recommendations(read_comics_list, top_n, comics_df, train_data 
                               ,best_params):
    """
    Given a list of comic titles and request for N
    Return list of comics recommendations as a pandas dataframe
    """
    start_time = time.time()
    
    # Get best-matching comic IDs
    train_comic_ids = get_comic_ids_for_user(comics_df, read_comics_list)
        
    # Create new account number
    new_id = create_acct_id(train_data)
    
    # Add new account to training data
    train_data_new = add_new_user(train_data, train_comic_ids, new_id)
    train_data_new.persist()
    
    # Train new ALS model
    als_model = train_als(train_data_new, best_params)
    
    # Get list of comics to rate, exclude those already matched
    new_comics_ids = get_comics_to_rate(comics_df, train_comic_ids)

    # Get pandas df of top n recommended comics!
    top_n_comics_df = recommend_n_comics(top_n, new_comics_ids, new_id
                                        ,als_model
                                        ,comics_df
                                        )
    
    print ('Total Runtime: {:.2f} seconds'.format(time.time() - start_time))
    return top_n_comics_df

# %% [markdown]
# ## BIG TEST!

# %%
my_list = ['Transformers', 'GI Joe', 'Y The Last Man', 'Saga', 'Avengers'
           ,'Paper Girls', 'Star Wars']

# %%
df = make_comic_recommendations(my_list
                               ,5
                               ,comics_df
                               ,sold
                               ,current_params)
# Out:
# Total Runtime: 9.06 seconds

# %%
df
# Out:
#                           comic_title  \
# 0               Spider-Verse (Marvel)
# 1  Harley Quinn Valentines Day S (DC)
# 2       Convergence Harley Quinn (DC)
# 3      Harley Quinn & Power Girl (DC)
# 4              Spider-Island (Marvel)
#
#                                              img_url
# 0  https://comrx.s3-us-west-2.amazonaws.com/cover...
# 1  https://comrx.s3-us-west-2.amazonaws.com/cover...
# 2  https://comrx.s3-us-west-2.amazonaws.com/cover...
# 3  https://comrx.s3-us-west-2.amazonaws.com/cover...
# 4  https://comrx.s3-us-west-2.amazonaws.com/cover...

# %% [markdown]
# # ALTERNATIVE
#
# Use Matrices, as inspired by John Naujoks, suggested by Miles Erickson

# %% [markdown]
# 1. Get the item factors

# %%
item_factors = als_model.itemFactors.toPandas()

# %%
item_factors.head()
# Out:
#    id                                           features
# 0  10  [-0.04702767729759216, -0.13710705935955048, -...
# 1  20  [-0.06460945308208466, -0.07806924730539322, 0...
# 2  30  [-0.19240108132362366, -0.27372074127197266, 0...
# 3  40  [-0.12126117944717407, -0.01254610437899828, -...
# 4  50  [-0.012951415032148361, -0.1716042011976242, 0...

# %%
item_factors.columns = ['item_id', 'features']

# %%
item_factors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6416 entries, 0 to 6415
# Data columns (total 2 columns):
# item_id     6416 non-null int32
# features    6416 non-null object
# dtypes: int32(1), object(1)
# memory usage: 75.3+ KB

# %%
item_factors.features[0]
# Out:
# [-0.04702767729759216,
#  -0.13710705935955048,
#  -0.18831919133663177,
#  -0.23926596343517303,
#  -0.12388940155506134]

# %% [markdown]
# 2. Create a fake user

# %%
# 2171 = Fables, 2637 = Gideon Falls
fake_user = [{'id': 2171, 'rating': 1}, {'id': 2637, 'rating': 1}] 
fake_user_df = pd.DataFrame(fake_user)
fake_user_df
# Out:
#      id  rating
# 0  2171       1
# 1  2637       1

# %% [markdown]
# 3. Create item matrix

# %%
comic_ids = fake_user_df.id.tolist()
comics_mtx = np.zeros(shape=(len(comic_ids),5))

# %% [markdown]
# 3. Create rating matrix

# %%
ratings = fake_user_df.rating.tolist()

# %%
ratings_mtx = np.array((ratings,)).T

# %%
ratings_mtx
# Out:
# array([[1],
#        [1]])

# %%
for index, comic in enumerate(comic_ids):
    comics_mtx[index, :] = np.array(item_factors.loc[comic, 'features'])

# %%
comics_mtx
# Out:
# array([[ 0.3607977 ,  0.07123993,  0.23716298, -0.0791665 ,  0.50475931],
#        [-0.09457219, -0.13997468, -0.14156191, -0.08010286, -0.07182016]])

# %%
ratings_mtx.shape, comics_mtx.shape
# Out:
# ((2, 1), (2, 5))

# %%
# Least squares solution to get user features
fake_user_matrix = np.linalg.lstsq(comics_mtx, ratings_mtx, rcond=None)

# New users matrix!
fake_user_matrix = fake_user_matrix[0].reshape((5,))
fake_user_matrix.shape
# Out:
# (5,)

# %% [markdown]
# # GRAVEYARD

# %%
comics_df.show(2000)
# Out:
# +--------+--------------------+--------------------+
# |comic_id|         comic_title|             img_url|
# +--------+--------------------+--------------------+
# |      15|1 For $1 Action P...|https://comrx.s3-...|
# |      17|1 For $1 Axe Cop ...|https://comrx.s3-...|
# |      20|1 For $1 Conan th...|https://comrx.s3-...|
# |      22|1 For $1 Mass Eff...|https://comrx.s3-...|
# |      24|1 For $1 Star War...|https://comrx.s3-...|
# |      27|1 For $1 Usagi Yo...|https://comrx.s3-...|
# |      18|1 For 1 Baltimore...|https://comrx.s3-...|
# |       2|100 Bullets Broth...|https://comrx.s3-...|
# |       4|100 Penny Press S...|https://comrx.s3-...|
# |       6|100 Penny Press T...|https://comrx.s3-...|
# |       8|12 Reasons To Die...|https://comrx.s3-...|
# |       9|    13 Coins (Other)|https://comrx.s3-...|
# |      11|1602 Witch Hunter...|https://comrx.s3-...|
# |      29|2021 Lost Childre...|https://comrx.s3-...|
# |      31|23 Skidoo One Sho...|https://comrx.s3-...|
# |      36|3 Floyds Alpha Ki...|https://comrx.s3-...|
# |      33|30 Days of Night ...|https://comrx.s3-...|
# |      34|32 Stories Comple...|https://comrx.s3-...|
# |      43|4001 A.d. X-O Man...|https://comrx.s3-...|
# |      40|     4001 Ad (Other)|https://comrx.s3-...|
# |      41|4001 Ad Shadowman...|https://comrx.s3-...|
# |      44|47 Ronin (Dark Ho...|https://comrx.s3-...|
# |      47|68 Encore Ed (Mr ...|https://comrx.s3-...|
# |      49|68 Hardship One S...|https://comrx.s3-...|
# |      50|68 Homefront (Image)|https://comrx.s3-...|
# |      53|68 Jungle Jim One...|https://comrx.s3-...|
# |      54|68 Last Rights (I...|https://comrx.s3-...|
# |      56|    68 Scars (Image)|https://comrx.s3-...|
# |      60|      8house (Image)|https://comrx.s3-...|
# |      92|A Distant Soil (I...|https://comrx.s3-...|
# |      64|A-Babies Vs X-Bab...|https://comrx.s3-...|
# |      71|    Ab Irato (Other)|https://comrx.s3-...|
# |      65|  Abattoir (Radical)|https://comrx.s3-...|
# |      67|Abe Sapien Abyssa...|https://comrx.s3-...|
# |      70|Abigail and the S...|https://comrx.s3-...|
# |      73|Absolution Rubico...|https://comrx.s3-...|
# |      75|Accelerators (Other)|https://comrx.s3-...|
# |      79|Action Comics #23...|https://comrx.s3-...|
# |      81|  Action Comics (DC)|https://comrx.s3-...|
# |      83|Action Comics Spe...|https://comrx.s3-...|
# |      85|Action Man Revolu...|https://comrx.s3-...|
# |      87|Ad After Death Bo...|https://comrx.s3-...|
# |      89|Ad After Death Bo...|https://comrx.s3-...|
# |      90| Adam.3 (Dark Horse)|https://comrx.s3-...|
# |     110|Adventure Time (B...|https://comrx.s3-...|
# |     103|Adventure Time 20...|https://comrx.s3-...|
# |     105|Adventure Time 20...|https://comrx.s3-...|
# |     107|Adventure Time 20...|https://comrx.s3-...|
# |     109|Adventure Time Be...|https://comrx.s3-...|
# |     112|Adventure Time Co...|https://comrx.s3-...|
# |     114|Adventure Time Fl...|https://comrx.s3-...|
# |     117|Adventure Time Ma...|https://comrx.s3-...|
# |      96|Adventures of Aer...|https://comrx.s3-...|
# |      98|Adventures of Sup...|https://comrx.s3-...|
# |     100|Adventures of Tad...|https://comrx.s3-...|
# |     101|Adventures of the...|https://comrx.s3-...|
# |    1633|Dcd Summit 2014 O...|https://comrx.s3-...|
# |     122|Adv of Augusta Wi...|https://comrx.s3-...|
# |     119|Adventure Time Re...|https://comrx.s3-...|
# |     121|Adventure Time Su...|https://comrx.s3-...|
# |     126|After Dark (Radical)|https://comrx.s3-...|
# |     128|Afterlife With Ar...|https://comrx.s3-...|
# |     133|Age of Apocalypse...|https://comrx.s3-...|
# |     136|Age of Reptiles A...|https://comrx.s3-...|
# |     139|Age of X-Man Alph...|https://comrx.s3-...|
# |     141|Age of X-Man Apoc...|https://comrx.s3-...|
# |     142|Age of X-Man Marv...|https://comrx.s3-...|
# |     145|Age of X-Man X-Tr...|https://comrx.s3-...|
# |     131|Agents of Atlas M...|https://comrx.s3-...|
# |     132|Agents of Shield ...|https://comrx.s3-...|
# |     148|Akaneiro (Dark Ho...|https://comrx.s3-...|
# |     149|Alabaster the Goo...|https://comrx.s3-...|
# |     152|Alan Robert Killo...|https://comrx.s3-...|
# |     154|  Alex + Ada (Image)|https://comrx.s3-...|
# |     156|   Alice Cooper (DE)|https://comrx.s3-...|
# |     158|Alien Bounty Hunt...|https://comrx.s3-...|
# |     159|Aliens Dead Orbit...|https://comrx.s3-...|
# |     160|Aliens Defiance (...|https://comrx.s3-...|
# |     163|Aliens Life and D...|https://comrx.s3-...|
# |     165|Aliens Vampirella...|https://comrx.s3-...|
# |     167|Aliens Vs Predato...|https://comrx.s3-...|
# |     171|   All Crime (Other)|https://comrx.s3-...|
# |     173|All New All Diffe...|https://comrx.s3-...|
# |     175|All New Batman th...|https://comrx.s3-...|
# |     177|All New Captain A...|https://comrx.s3-...|
# |     179|All New Doop (Mar...|https://comrx.s3-...|
# |     181|All New Ghost Rid...|https://comrx.s3-...|
# |     184|All New Hawkeye (...|https://comrx.s3-...|
# |     185|All New Inhumans ...|https://comrx.s3-...|
# |     188|All New Marvel No...|https://comrx.s3-...|
# |     189|All New Miraclema...|https://comrx.s3-...|
# |     191|All New Soulfire ...|https://comrx.s3-...|
# |     194|All New Wolverine...|https://comrx.s3-...|
# |     195|All New Wolverine...|https://comrx.s3-...|
# |     198|All New X-Men (Ma...|https://comrx.s3-...|
# |     199|All New X-Men Spe...|https://comrx.s3-...|
# |     201|All Star Section ...|https://comrx.s3-...|
# |     204|All Star Western ...|https://comrx.s3-...|
# |     206|All Time Comics B...|https://comrx.s3-...|
# |     208|All Time Comics C...|https://comrx.s3-...|
# |     210|Aloha Hawaiian Di...|https://comrx.s3-...|
# |     212|Alpha Flight (Mar...|https://comrx.s3-...|
# |     214|  Alpha Girl (Image)|https://comrx.s3-...|
# |     217|      Alters (Other)|https://comrx.s3-...|
# |     219|Amazing Cerebus (...|https://comrx.s3-...|
# |     221|Amazing Spider-Gi...|https://comrx.s3-...|
# |     223|Amazing Spider-Ma...|https://comrx.s3-...|
# |     227|Amazing Spider-Ma...|https://comrx.s3-...|
# |     222|Amazing Spider-Ma...|https://comrx.s3-...|
# |     231|Amazing World of ...|https://comrx.s3-...|
# |     232|Amazing World of ...|https://comrx.s3-...|
# |     235|   Amber Blake (IDW)|https://comrx.s3-...|
# |     237|    America (Marvel)|https://comrx.s3-...|
# |     239|American Monster ...|https://comrx.s3-...|
# |     241|American Vampire ...|https://comrx.s3-...|
# |     243|American Vampire ...|https://comrx.s3-...|
# |     246|Americas Got Powe...|https://comrx.s3-...|
# |     248|Amory Wars Good A...|https://comrx.s3-...|
# |     251|      Analog (Image)|https://comrx.s3-...|
# |     260|Angel & Faith (Da...|https://comrx.s3-...|
# |     258|        Angel (Boom)|https://comrx.s3-...|
# |     257|Angel Barbary Coa...|https://comrx.s3-...|
# |     259|    Angel City (Oni)|https://comrx.s3-...|
# |     265|Angel Only Human ...|https://comrx.s3-...|
# |     267|Angel Special Lor...|https://comrx.s3-...|
# |     270|Angel Yearbook On...|https://comrx.s3-...|
# |     253|Angela Asgards As...|https://comrx.s3-...|
# |     262|     Angelic (Image)|https://comrx.s3-...|
# |     274|   Angry Birds (IDW)|https://comrx.s3-...|
# |     272|Angry Birds Comic...|https://comrx.s3-...|
# |     275|Angry Birds Super...|https://comrx.s3-...|
# |     278|     Animal Man (DC)|https://comrx.s3-...|
# |     277|Animal Man Annual...|https://comrx.s3-...|
# |     282|   Animosity (Other)|https://comrx.s3-...|
# |     284|Anita Blake Circu...|https://comrx.s3-...|
# |     286|Anita Blake Lc Ex...|https://comrx.s3-...|
# |     288|Anna Mercury 2 (A...|https://comrx.s3-...|
# |     290|Anne Rice Servant...|https://comrx.s3-...|
# |     293|Annihilators (Mar...|https://comrx.s3-...|
# |     294|Anno Dracula (Other)|https://comrx.s3-...|
# |     296| Answer (Dark Horse)|https://comrx.s3-...|
# |     304|    Ant-Man (Marvel)|https://comrx.s3-...|
# |     303|Ant-Man Last Days...|https://comrx.s3-...|
# |     299|Ant-Man and the W...|https://comrx.s3-...|
# |     297|         Antar (IDW)|https://comrx.s3-...|
# |     310|Aphrodite IX (Image)|https://comrx.s3-...|
# |     307|Aphrodite IX Ares...|https://comrx.s3-...|
# |     309|Aphrodite IX Hidd...|https://comrx.s3-...|
# |     314|Apollo IX One Sho...|https://comrx.s3-...|
# |     319|        Aquaman (DC)|https://comrx.s3-...|
# |     320|Aquaman Futures E...|https://comrx.s3-...|
# |     322|Aquaman Justice L...|https://comrx.s3-...|
# |     317|Aquaman and the O...|https://comrx.s3-...|
# |     326|Arcane Secrets (O...|https://comrx.s3-...|
# |     329|Archer & Armstron...|https://comrx.s3-...|
# |     332|Archer & Armstron...|https://comrx.s3-...|
# |     330|Archer & Armstron...|https://comrx.s3-...|
# |     336|     Archie (Archie)|https://comrx.s3-...|
# |     333|Archie 1941 (Archie)|https://comrx.s3-...|
# |     339|Archie Comics Dou...|https://comrx.s3-...|
# |     340|Archie Double Dig...|https://comrx.s3-...|
# |     344|Archie Meets Batm...|https://comrx.s3-...|
# |     350|Archie Vs Predato...|https://comrx.s3-...|
# |     335|Archie and Me Jum...|https://comrx.s3-...|
# |     346|    Archies (Archie)|https://comrx.s3-...|
# |     349|Archies Superteen...|https://comrx.s3-...|
# |     352|      Archon (Other)|https://comrx.s3-...|
# |     355|   Arkham Manor (DC)|https://comrx.s3-...|
# |    1745|   Deathmatch (Boom)|https://comrx.s3-...|
# |     360|Armor Hunters (Ot...|https://comrx.s3-...|
# |     358|Armor Hunters Blo...|https://comrx.s3-...|
# |     361| Armor Wars (Marvel)|https://comrx.s3-...|
# |     364|Army of Darkness ...|https://comrx.s3-...|
# |     367|Army of Darkness ...|https://comrx.s3-...|
# |     366|Army of Darkness/...|https://comrx.s3-...|
# |     369|          Arrow (DC)|https://comrx.s3-...|
# |     373|   Art Ops (Vertigo)|https://comrx.s3-...|
# |     374|        Arya (Other)|https://comrx.s3-...|
# |     375|    Ascender (Image)|https://comrx.s3-...|
# |     378|     Ash Vs Aod (DE)|https://comrx.s3-...|
# |     381|Assassin Nation (...|https://comrx.s3-...|
# |     380| Assassinistas (IDW)|https://comrx.s3-...|
# |     383|Assassins Creed t...|https://comrx.s3-...|
# |     386|Astonishing Thor ...|https://comrx.s3-...|
# |     387|Astonishing X-Men...|https://comrx.s3-...|
# |     390|Astonishing X-Men...|https://comrx.s3-...|
# |     392|Astounding Wolf-M...|https://comrx.s3-...|
# |     394|Astro City Silver...|https://comrx.s3-...|
# |     396|Astro Hustle (Dar...|https://comrx.s3-...|
# |     399|Athena IX One Sho...|https://comrx.s3-...|
# |     401|Athena Voltaire a...|https://comrx.s3-...|
# |     402|Atlas and Axis (O...|https://comrx.s3-...|
# |     406|Atom and Hawkman ...|https://comrx.s3-...|
# |     420|Atomic Robo & the...|https://comrx.s3-...|
# |     410|Atomic Robo Dogs ...|https://comrx.s3-...|
# |     412|Atomic Robo Ghost...|https://comrx.s3-...|
# |     414|Atomic Robo Knigh...|https://comrx.s3-...|
# |     416|Atomic Robo Reven...|https://comrx.s3-...|
# |     418|Atomic Robo Shado...|https://comrx.s3-...|
# |     407|Atomic Robo and t...|https://comrx.s3-...|
# |     423|        Auteur (Oni)|https://comrx.s3-...|
# |     424|Auteur Sister Bam...|https://comrx.s3-...|
# |     427|Authority the Los...|https://comrx.s3-...|
# |     429| Avant-Guards (Boom)|https://comrx.s3-...|
# |     431|  Avengelyne (Image)|https://comrx.s3-...|
# |     453|Avengers & Infini...|https://comrx.s3-...|
# |     433|Avengers (2010) (...|https://comrx.s3-...|
# |     436|Avengers Academy ...|https://comrx.s3-...|
# |     437|Avengers Ai (Marvel)|https://comrx.s3-...|
# |     439|Avengers Annual 2...|https://comrx.s3-...|
# |     443|Avengers Assemble...|https://comrx.s3-...|
# |     444|Avengers Black Wi...|https://comrx.s3-...|
# |     446|Avengers Children...|https://comrx.s3-...|
# |     448|Avengers Coming o...|https://comrx.s3-...|
# |     450|Avengers Edge of ...|https://comrx.s3-...|
# |     454|Avengers Initiati...|https://comrx.s3-...|
# |     456|Avengers Millenni...|https://comrx.s3-...|
# |     459|Avengers No Road ...|https://comrx.s3-...|
# |     461|Avengers Origin (...|https://comrx.s3-...|
# |     463|Avengers Origins ...|https://comrx.s3-...|
# |     465|Avengers Origins ...|https://comrx.s3-...|
# |     467|Avengers Prime (M...|https://comrx.s3-...|
# |     469|Avengers Solo (Ma...|https://comrx.s3-...|
# |     471|Avengers Standoff...|https://comrx.s3-...|
# |     473|Avengers Undercov...|https://comrx.s3-...|
# |    1764| Deathstroke (Other)|https://comrx.s3-...|
# |     484|A Voice In the Da...|https://comrx.s3-...|
# |     500|A Year of Marvels...|https://comrx.s3-...|
# |     502|A Year of Marvels...|https://comrx.s3-...|
# |     475|Avengers Vs Atlas...|https://comrx.s3-...|
# |     478|Avengers Vs X-Men...|https://comrx.s3-...|
# |     479|Avengers World (M...|https://comrx.s3-...|
# |     481|Avenging Spider-M...|https://comrx.s3-...|
# |     487|Avx Consequences ...|https://comrx.s3-...|
# |     488|     Avx Vs (Marvel)|https://comrx.s3-...|
# |     489|       Awake (Other)|https://comrx.s3-...|
# |     492|      Axcend (Image)|https://comrx.s3-...|
# |     495|Axe Cop President...|https://comrx.s3-...|
# |     496|Axis Carnage (Mar...|https://comrx.s3-...|
# |     498|Axis Revolutions ...|https://comrx.s3-...|
# |     505|   Babyteeth (Other)|https://comrx.s3-...|
# |     508|Back To Brooklyn ...|https://comrx.s3-...|
# |     510|Back To the Futur...|https://comrx.s3-...|
# |     506|  Backstagers (Boom)|https://comrx.s3-...|
# |     513|    Backways (Other)|https://comrx.s3-...|
# |     514|        Bad Ass (DE)|https://comrx.s3-...|
# |     518|Bad Luck Chuck (D...|https://comrx.s3-...|
# |     517|      Badger (Other)|https://comrx.s3-...|
# |     521|Ballad of Sang (Oni)|https://comrx.s3-...|
# |     524|Baltimore Cult of...|https://comrx.s3-...|
# |     526|Baltimore Dr Lesk...|https://comrx.s3-...|
# |     528|Baltimore Inferna...|https://comrx.s3-...|
# |     530|Baltimore Play On...|https://comrx.s3-...|
# |     534|Baltimore Witch o...|https://comrx.s3-...|
# |     531|Baltimore the Inq...|https://comrx.s3-...|
# |     536|  Bane Conquest (DC)|https://comrx.s3-...|
# |     537|Bankshot (Dark Ho...|https://comrx.s3-...|
# |     540|Barb Wire (Dark H...|https://comrx.s3-...|
# |     542|     Barrier (Image)|https://comrx.s3-...|
# |     544|Barrier Limited E...|https://comrx.s3-...|
# |     547|Bart Simpson Comi...|https://comrx.s3-...|
# |     549|Bart Simpsons Tre...|https://comrx.s3-...|
# |     552|        Batgirl (DC)|https://comrx.s3-...|
# |     551| Batgirl Annual (DC)|https://comrx.s3-...|
# |     554|Batgirl Futures E...|https://comrx.s3-...|
# |     556|Batman #23.1 Joke...|https://comrx.s3-...|
# |     559|Batman #23.4 Bane...|https://comrx.s3-...|
# |     561|Batman 66 Meets G...|https://comrx.s3-...|
# |     563|Batman 66 Meets t...|https://comrx.s3-...|
# |     566|Batman 66 the Los...|https://comrx.s3-...|
# |     568|Batman 80 Page Gi...|https://comrx.s3-...|
# |     587|Batman Arkham Cit...|https://comrx.s3-...|
# |     591|Batman Arkham Kni...|https://comrx.s3-...|
# |     592|Batman Arkham Kni...|https://comrx.s3-...|
# |     569|Batman and Aquama...|https://comrx.s3-...|
# |     572|Batman and Catwom...|https://comrx.s3-...|
# |     573|Batman and Franke...|https://comrx.s3-...|
# |     576|Batman and Robin ...|https://comrx.s3-...|
# |     581|Batman and Robin ...|https://comrx.s3-...|
# |     579|Batman and Robin ...|https://comrx.s3-...|
# |     584|Batman and Two Fa...|https://comrx.s3-...|
# |     582|Batman and the Ou...|https://comrx.s3-...|
# |     674|       Bat Mite (DC)|https://comrx.s3-...|
# |     594|Batman Arkham Unh...|https://comrx.s3-...|
# |     596|Batman Battle For...|https://comrx.s3-...|
# |     598|Batman Beyond Reb...|https://comrx.s3-...|
# |     601|Batman Beyond Unl...|https://comrx.s3-...|
# |     603|Batman Blank Comi...|https://comrx.s3-...|
# |     605|Batman Catwoman F...|https://comrx.s3-...|
# |     607|Batman Creature o...|https://comrx.s3-...|
# |     611|Batman Doc Savage...|https://comrx.s3-...|
# |     613|Batman Endgame Di...|https://comrx.s3-...|
# |     614|Batman Essentials...|https://comrx.s3-...|
# |     617|Batman Essentials...|https://comrx.s3-...|
# |     618|Batman Essentials...|https://comrx.s3-...|
# |     620|  Batman Europa (DC)|https://comrx.s3-...|
# |     622|Batman Futures En...|https://comrx.s3-...|
# |     625|Batman Hidden Tre...|https://comrx.s3-...|
# |     627|Batman Incorporat...|https://comrx.s3-...|
# |     630|Batman Incorporat...|https://comrx.s3-...|
# |     631|Batman Jokers Dau...|https://comrx.s3-...|
# |     633|Batman Last Knigh...|https://comrx.s3-...|
# |     636|    Batman Lost (DC)|https://comrx.s3-...|
# |     637| Batman Odyssey (DC)|https://comrx.s3-...|
# |     639| Batman Orphans (DC)|https://comrx.s3-...|
# |     642| Batman Rebirth (DC)|https://comrx.s3-...|
# |     645|Batman Sins of th...|https://comrx.s3-...|
# |     648|Batman Superman (DC)|https://comrx.s3-...|
# |     649|Batman Superman F...|https://comrx.s3-...|
# |     668|Batman Tmnt Adven...|https://comrx.s3-...|
# |     670|Batman Who Laughs...|https://comrx.s3-...|
# |     672|Batman Widening G...|https://comrx.s3-...|
# |     653|Batman the Dark K...|https://comrx.s3-...|
# |     652|Batman the Dark K...|https://comrx.s3-...|
# |     656|Batman the Dawnbr...|https://comrx.s3-...|
# |     658|Batman the Drowne...|https://comrx.s3-...|
# |     661|Batman the Maxx (...|https://comrx.s3-...|
# |     662|Batman the Mercil...|https://comrx.s3-...|
# |     664|Batman the Red De...|https://comrx.s3-...|
# |     666|Batman the Shadow...|https://comrx.s3-...|
# |     679|Battle Scars (Mar...|https://comrx.s3-...|
# |     677|   Battlefields (DE)|https://comrx.s3-...|
# |     682|Battlestar Galact...|https://comrx.s3-...|
# |     681|Battlestar Galact...|https://comrx.s3-...|
# |     684|Battlestar Galact...|https://comrx.s3-...|
# |     686|     Batvark (Other)|https://comrx.s3-...|
# |     689|     Batwing (Other)|https://comrx.s3-...|
# |     691|       Batwoman (DC)|https://comrx.s3-...|
# |     690|Batwoman Annual (DC)|https://comrx.s3-...|
# |     694|Batwoman Rebirth ...|https://comrx.s3-...|
# |     697|Beasts of Burden ...|https://comrx.s3-...|
# |     699|Beasts of Burden ...|https://comrx.s3-...|
# |     701|Beasts of Burden ...|https://comrx.s3-...|
# |     703|Beautiful Canvas ...|https://comrx.s3-...|
# |     705|     Beauty (Topcow)|https://comrx.s3-...|
# |     707|Bedtime Game (Dar...|https://comrx.s3-...|
# |     709|Bee and Puppyca (...|https://comrx.s3-...|
# |     711|        Beef (Image)|https://comrx.s3-...|
# |     715|Before Watchmen D...|https://comrx.s3-...|
# |     717|Before Watchmen M...|https://comrx.s3-...|
# |     719|Before Watchmen N...|https://comrx.s3-...|
# |     721|Before Watchmen O...|https://comrx.s3-...|
# |     724|Bela Lugosi Tales...|https://comrx.s3-...|
# |     726| Belladonna (Avatar)|https://comrx.s3-...|
# |     728|        Ben 10 (IDW)|https://comrx.s3-...|
# |     731|        Berlin (D&Q)|https://comrx.s3-...|
# |     732|Beronas Hundred Y...|https://comrx.s3-...|
# |     734|   Betrothed (Other)|https://comrx.s3-...|
# |     735|    Bettie Page (DE)|https://comrx.s3-...|
# |     741|Betty & Veronica ...|https://comrx.s3-...|
# |     743|Betty & Veronica ...|https://comrx.s3-...|
# |     744|Betty & Veronica ...|https://comrx.s3-...|
# |     738|     Betty Boop (DE)|https://comrx.s3-...|
# |     737|Betty and Veronic...|https://comrx.s3-...|
# |     747|Beyond Belief (Im...|https://comrx.s3-...|
# |     751|     Big Lie (Image)|https://comrx.s3-...|
# |     754|Big Thunder Mount...|https://comrx.s3-...|
# |     756|Big Trouble In Li...|https://comrx.s3-...|
# |     749|   Bigger Bang (IDW)|https://comrx.s3-...|
# |     758|Bill & Ted Go To ...|https://comrx.s3-...|
# |     760|Bill & Ted Save t...|https://comrx.s3-...|
# |     762|Billy Kids Odditi...|https://comrx.s3-...|
# |     765|     Bionic Man (DE)|https://comrx.s3-...|
# |     766|Bionic Man Vs Bio...|https://comrx.s3-...|
# |     769|  Birds of Prey (DC)|https://comrx.s3-...|
# |     771|Birds of Prey (Ot...|https://comrx.s3-...|
# |     773|Bitch Planet (Image)|https://comrx.s3-...|
# |     775| Bitter Root (Image)|https://comrx.s3-...|
# |     823|       Black (Other)|https://comrx.s3-...|
# |     779|Black Af Widows &...|https://comrx.s3-...|
# |     781|      Black Bat (DE)|https://comrx.s3-...|
# |     783|Black Beetle Nigh...|https://comrx.s3-...|
# |     786| Black Bolt (Marvel)|https://comrx.s3-...|
# |     788|  Black Cat (Marvel)|https://comrx.s3-...|
# |     792|Black Dynamite (IDW)|https://comrx.s3-...|
# |     804|Black Hammer (Dar...|https://comrx.s3-...|
# |     802|Black Hammer Age ...|https://comrx.s3-...|
# |     805|Black Hammer Gian...|https://comrx.s3-...|
# |     808|Black Hood Season...|https://comrx.s3-...|
# |     810|Black Jack Ketchu...|https://comrx.s3-...|
# |     812|Black Kiss Ii (Im...|https://comrx.s3-...|
# |     814|Black Knight (Zen...|https://comrx.s3-...|
# |     817|Black Lightning C...|https://comrx.s3-...|
# |     819|Black Magick (Image)|https://comrx.s3-...|
# |     820| Black Market (Boom)|https://comrx.s3-...|
# |     822|Black Order (Marvel)|https://comrx.s3-...|
# |     826|Black Panther Cre...|https://comrx.s3-...|
# |     828|Black Panther Man...|https://comrx.s3-...|
# |     831|Black Panther Pre...|https://comrx.s3-...|
# |     777|   Blackacre (Image)|https://comrx.s3-...|
# |     790|     Blackcross (DE)|https://comrx.s3-...|
# |     795|Blackest Night Js...|https://comrx.s3-...|
# |     798|Blackest Night Un...|https://comrx.s3-...|
# |     796|Blackest Night th...|https://comrx.s3-...|
# |     824|Blackout (Dark Ho...|https://comrx.s3-...|
# |    1637|Dce Essentials V ...|https://comrx.s3-...|
# |     835|Black Racer & Shi...|https://comrx.s3-...|
# |     836|  Black Road (Image)|https://comrx.s3-...|
# |     839|   Black Terror (DE)|https://comrx.s3-...|
# |     843|Black Widow (Marvel)|https://comrx.s3-...|
# |     841|Black Widow and M...|https://comrx.s3-...|
# |     845|Blankshot (Dark H...|https://comrx.s3-...|
# |     848|Blood Blister (Ot...|https://comrx.s3-...|
# |     850|Blood Brothers (D...|https://comrx.s3-...|
# |     855| Blood Realm (Other)|https://comrx.s3-...|
# |     853|Bloodhound Crowba...|https://comrx.s3-...|
# |     857|Bloodshot & Hard ...|https://comrx.s3-...|
# |     856|Bloodshot & Hard ...|https://comrx.s3-...|
# |     860|   Bloodshot (Other)|https://comrx.s3-...|
# |     861|Bloodshot Reborn ...|https://comrx.s3-...|
# |     864|Bloodshot Salvati...|https://comrx.s3-...|
# |     865|Bloodshots Day Of...|https://comrx.s3-...|
# |     869|Bloodthirsty (Other)|https://comrx.s3-...|
# |     871|Blubber (Fantagra...|https://comrx.s3-...|
# |     873| Blue Beetle (Other)|https://comrx.s3-...|
# |     875| Blue Estate (Image)|https://comrx.s3-...|
# |     877|   Bobs Burgers (DE)|https://comrx.s3-...|
# |     880| Bodie Troll (Red 5)|https://comrx.s3-...|
# |     881|Body Bags (One Sh...|https://comrx.s3-...|
# |     883|       Bolts (Other)|https://comrx.s3-...|
# |     886|Bomb Queen VI (Im...|https://comrx.s3-...|
# |     887|Bomb Queen VII Qu...|https://comrx.s3-...|
# |     889|Bombshells United...|https://comrx.s3-...|
# |     890|   Bonehead (Topcow)|https://comrx.s3-...|
# |     897|Book of Death (Ot...|https://comrx.s3-...|
# |     894|Book of Death Fal...|https://comrx.s3-...|
# |     895|Book of Death Fal...|https://comrx.s3-...|
# |     898|Books of Magic (V...|https://comrx.s3-...|
# |     901|Boom Box 2016 Mix...|https://comrx.s3-...|
# |     903|   Booster Gold (DC)|https://comrx.s3-...|
# |     905|Booster Gold Futu...|https://comrx.s3-...|
# |     908|Borderlands Fall ...|https://comrx.s3-...|
# |     911|      Bounce (Image)|https://comrx.s3-...|
# |     914|         Boy-1 (IDW)|https://comrx.s3-...|
# |     915|Boys #18 Blank Cv...|https://comrx.s3-...|
# |     918|  Boys Herogasm (DE)|https://comrx.s3-...|
# |     920|Bprd 1947 (Dark H...|https://comrx.s3-...|
# |     921|Bprd 1948 (Dark H...|https://comrx.s3-...|
# |     924|Bprd Devil You Kn...|https://comrx.s3-...|
# |     925|Bprd Hell On Eart...|https://comrx.s3-...|
# |     927|Bprd Hell On Eart...|https://comrx.s3-...|
# |     929|Bprd Hell On Eart...|https://comrx.s3-...|
# |     931|Bprd Hell On Eart...|https://comrx.s3-...|
# |     933|Bprd Hell On Eart...|https://comrx.s3-...|
# |     935|Bprd Hell On Eart...|https://comrx.s3-...|
# |     938|Bprd Vampire (Dar...|https://comrx.s3-...|
# |     939|Brain Boy (Dark H...|https://comrx.s3-...|
# |     941|Bram Stokers Deat...|https://comrx.s3-...|
# |     942|   Brass Sun (Other)|https://comrx.s3-...|
# |     943|Brave and the Bol...|https://comrx.s3-...|
# |     945|Bravest Warriors ...|https://comrx.s3-...|
# |     948|Bravest Warriors ...|https://comrx.s3-...|
# |     951|   Breakneck (Other)|https://comrx.s3-...|
# |    1028|B & V Friends Jum...|https://comrx.s3-...|
# |     954|   Breed Iii (Image)|https://comrx.s3-...|
# |     956|Briggs Land (Dark...|https://comrx.s3-...|
# |     960|  Brightest Day (DC)|https://comrx.s3-...|
# |     959|Brightest Day Aft...|https://comrx.s3-...|
# |     962|  Brilliant (Marvel)|https://comrx.s3-...|
# |     966|   Britannia (Other)|https://comrx.s3-...|
# |     967|Britannia We Who ...|https://comrx.s3-...|
# |     968|Broken Moon Legen...|https://comrx.s3-...|
# |     971| Broken World (Boom)|https://comrx.s3-...|
# |     973|Brother Nash (Other)|https://comrx.s3-...|
# |     975|Bruce Lee Dragon ...|https://comrx.s3-...|
# |     978|Bruce Wayne the R...|https://comrx.s3-...|
# |     980|Bruce Wayne the R...|https://comrx.s3-...|
# |     982|Bruce Wayne the R...|https://comrx.s3-...|
# |     984| Brutal Nature (IDW)|https://comrx.s3-...|
# |     986|     Bsg Vs Bsg (DE)|https://comrx.s3-...|
# |     988|Btvs Season 11 (D...|https://comrx.s3-...|
# |     990|Btvs Season 12 th...|https://comrx.s3-...|
# |     992|Btvs Season 9 Fre...|https://comrx.s3-...|
# |     994|Bubba Ho-Tep & Co...|https://comrx.s3-...|
# |     995|Bubblegun VOL 2 (...|https://comrx.s3-...|
# |     996|Buckaroo Banzai (...|https://comrx.s3-...|
# |    1000|Buddy Cops One Sh...|https://comrx.s3-...|
# |    1001|Buffy the Vampire...|https://comrx.s3-...|
# |    1003|Buffy the Vampire...|https://comrx.s3-...|
# |    1005|Buffy the Vampire...|https://comrx.s3-...|
# |    1008|Bug the Adventure...|https://comrx.s3-...|
# |    1009|Bulletproof Coffi...|https://comrx.s3-...|
# |    1013|   Bullseye (Marvel)|https://comrx.s3-...|
# |    1015|  Bully Wars (Image)|https://comrx.s3-...|
# |    1016|        Bunker (Oni)|https://comrx.s3-...|
# |    1017|Burning Fields (B...|https://comrx.s3-...|
# |    1018|    Burnouts (Image)|https://comrx.s3-...|
# |    1023|    Butterfly (Boom)|https://comrx.s3-...|
# |    1024|Buzzard (Dark Horse)|https://comrx.s3-...|
# |    1034|      Cable (Marvel)|https://comrx.s3-...|
# |    1030|Cable and Deadpoo...|https://comrx.s3-...|
# |    1032|Cable and X-Force...|https://comrx.s3-...|
# |    1036|       Cage (Marvel)|https://comrx.s3-...|
# |    1038|     Calexit (Other)|https://comrx.s3-...|
# |    1040|   Caligula (Avatar)|https://comrx.s3-...|
# |    1045|Call of Duty Zomb...|https://comrx.s3-...|
# |    1042|Calling Cthulhu C...|https://comrx.s3-...|
# |    1047|Canadian Vark (Ot...|https://comrx.s3-...|
# |    1051|Cap'n Dinosaur On...|https://comrx.s3-...|
# |    1049|     Cape 1969 (IDW)|https://comrx.s3-...|
# |    1053|Captain America 1...|https://comrx.s3-...|
# |    1066|Captain America A...|https://comrx.s3-...|
# |    1068|Captain America C...|https://comrx.s3-...|
# |    1070|Captain America F...|https://comrx.s3-...|
# |    1057|Captain America a...|https://comrx.s3-...|
# |    1059|Captain America a...|https://comrx.s3-...|
# |    1061|Captain America a...|https://comrx.s3-...|
# |    1063|Captain America a...|https://comrx.s3-...|
# |    1065|Captain America a...|https://comrx.s3-...|
# |    1762|Deathstroke Annua...|https://comrx.s3-...|
# |    1071|Captain America F...|https://comrx.s3-...|
# |    1073|Captain America H...|https://comrx.s3-...|
# |    1076|Captain America M...|https://comrx.s3-...|
# |    1078|Captain America M...|https://comrx.s3-...|
# |    1080|Captain America R...|https://comrx.s3-...|
# |    1083|Captain America S...|https://comrx.s3-...|
# |    1085|Captain America W...|https://comrx.s3-...|
# |    1087|   Captain Atom (DC)|https://comrx.s3-...|
# |    1089|Captain Britain a...|https://comrx.s3-...|
# |    1091|Captain Canuck 20...|https://comrx.s3-...|
# |    1093|Captain Ginger (O...|https://comrx.s3-...|
# |    1095|Captain Kronos (H...|https://comrx.s3-...|
# |    1099|Captain Marvel (M...|https://comrx.s3-...|
# |    1100|Captain Midnight ...|https://comrx.s3-...|
# |    1101|Captain Stone (Ot...|https://comrx.s3-...|
# |    1104|Captain Wonder 3d...|https://comrx.s3-...|
# |    1107| Carbon Grey (Image)|https://comrx.s3-...|
# |    1109|Carbon Grey VOL 3...|https://comrx.s3-...|
# |    1110|    Carnage (Marvel)|https://comrx.s3-...|
# |    1113|         Cars (Boom)|https://comrx.s3-...|
# |    1115|Cartoon Network A...|https://comrx.s3-...|
# |    1117|Cartoon Network S...|https://comrx.s3-...|
# |    1122|   Casanova (Marvel)|https://comrx.s3-...|
# |    1120|Casanova Avaritia...|https://comrx.s3-...|
# |    1123|Casper the Friend...|https://comrx.s3-...|
# |    1125|Castle a Calm Bef...|https://comrx.s3-...|
# |    1130|Cataclysm Ultimat...|https://comrx.s3-...|
# |    1129|Cataclysm Ultimat...|https://comrx.s3-...|
# |    1132|Catalyst Comix (D...|https://comrx.s3-...|
# |    1134|Catalyst Prime Ac...|https://comrx.s3-...|
# |    1136|Catalyst Prime Ki...|https://comrx.s3-...|
# |    1138|Catalyst Prime No...|https://comrx.s3-...|
# |    1140|Catalyst Prime Su...|https://comrx.s3-...|
# |    1143|       Catwoman (DC)|https://comrx.s3-...|
# |    1144|Catwoman Election...|https://comrx.s3-...|
# |    1149|Cavalry Shield 50...|https://comrx.s3-...|
# |    1148|Cavalry Shield 50...|https://comrx.s3-...|
# |    1150|Cave Carson Has a...|https://comrx.s3-...|
# |    1154|Cavewoman 2010 He...|https://comrx.s3-...|
# |    1155|Cavewoman 2010 He...|https://comrx.s3-...|
# |    1157|Cavewoman Ankhas ...|https://comrx.s3-...|
# |    1159|Cavewoman Bunny R...|https://comrx.s3-...|
# |    1161|Cavewoman Extinct...|https://comrx.s3-...|
# |    1163|Cavewoman Gangste...|https://comrx.s3-...|
# |    1165|Cavewoman Mutatio...|https://comrx.s3-...|
# |    1167|Cavewoman Night O...|https://comrx.s3-...|
# |    1169|Cavewoman Oasis (...|https://comrx.s3-...|
# |    1171|Cavewoman Snow (O...|https://comrx.s3-...|
# |    1173|Cavewoman Toy Sto...|https://comrx.s3-...|
# |    1176|Cbldf Liberty Ann...|https://comrx.s3-...|
# |    1178|Cbldf Liberty Ann...|https://comrx.s3-...|
# |    1180|Cbldf Liberty Ann...|https://comrx.s3-...|
# |    1181|Cemetery Beach (I...|https://comrx.s3-...|
# |    1184|Cerebus In Hell (...|https://comrx.s3-...|
# |    1187|  Champions (Marvel)|https://comrx.s3-...|
# |    1884|Django Unchained ...|https://comrx.s3-...|
# |    1190|Chaos Chosen One ...|https://comrx.s3-...|
# |    1192|Chaos War Alpha F...|https://comrx.s3-...|
# |    1194|Chaos War Chaos K...|https://comrx.s3-...|
# |    1196|Chaos War God Squ...|https://comrx.s3-...|
# |    1200|Chapterhouse Summ...|https://comrx.s3-...|
# |    1202|Charismagic Death...|https://comrx.s3-...|
# |    1205| Charmed (Zenescope)|https://comrx.s3-...|
# |    1206|Chasing Hitler (R...|https://comrx.s3-...|
# |    1208|       Chastity (DE)|https://comrx.s3-...|
# |    1210|Chew #2 4th Ptg (...|https://comrx.s3-...|
# |    1214|        Chew (Image)|https://comrx.s3-...|
# |    1216|Chew Script Book ...|https://comrx.s3-...|
# |    1218|Chew Warrior Chic...|https://comrx.s3-...|
# |    1212|  Chewbacca (Marvel)|https://comrx.s3-...|
# |    1221| Chimichanga (Other)|https://comrx.s3-...|
# |    1223|  Chin Music (Image)|https://comrx.s3-...|
# |    1225|        Chip (Other)|https://comrx.s3-...|
# |    1226|Chip Second Crack...|https://comrx.s3-...|
# |    1229|Chronicles of Wor...|https://comrx.s3-...|
# |    1230|Chronicles of Wor...|https://comrx.s3-...|
# |    1233|Cinderella Fables...|https://comrx.s3-...|
# |    1235|Cinderella Serial...|https://comrx.s3-...|
# |    1237|Cinema Purgatorio...|https://comrx.s3-...|
# |    1239|Cirque American G...|https://comrx.s3-...|
# |    1241|Citizen Rex (Dark...|https://comrx.s3-...|
# |    1252|  Civil War (Marvel)|https://comrx.s3-...|
# |    1248|Civil War Ii (Mar...|https://comrx.s3-...|
# |    1245|Civil War Ii Choo...|https://comrx.s3-...|
# |    1247|Civil War Ii King...|https://comrx.s3-...|
# |    1250|Civil War Ii Ulys...|https://comrx.s3-...|
# |    1253| Clandestino (Other)|https://comrx.s3-...|
# |    1255|     Clarence (Boom)|https://comrx.s3-...|
# |    1258|Clean Room (Vertigo)|https://comrx.s3-...|
# |    1261|Clive Barkers New...|https://comrx.s3-...|
# |    1262|Clive Barkers Nig...|https://comrx.s3-...|
# |    1264|       Cloaks (Boom)|https://comrx.s3-...|
# |    1266|Cloe and the Clou...|https://comrx.s3-...|
# |    1269|Clone Conspiracy ...|https://comrx.s3-...|
# |    1271|Cloudia & Rex (Ot...|https://comrx.s3-...|
# |    1274|          Clue (IDW)|https://comrx.s3-...|
# |    1275|Cluster #2 2nd Pt...|https://comrx.s3-...|
# |    1278|         Cobra (IDW)|https://comrx.s3-...|
# |    1279| Cobra Ongoing (IDW)|https://comrx.s3-...|
# |    1281| Codebreakers (Boom)|https://comrx.s3-...|
# |    1284|Codename Baboushk...|https://comrx.s3-...|
# |    1286|Coffin Hill (Vert...|https://comrx.s3-...|
# |    1288|Coil Damaged Flip...|https://comrx.s3-...|
# |    1293|   Cold Space (Boom)|https://comrx.s3-...|
# |    1295|      Cold War (IDW)|https://comrx.s3-...|
# |    1290|Colder Bad Seed (...|https://comrx.s3-...|
# |    1297|       Collider (DC)|https://comrx.s3-...|
# |    1299|     Colossi (Other)|https://comrx.s3-...|
# |    1303|Come Into Me (Other)|https://comrx.s3-...|
# |    1304|Comic Book Comics...|https://comrx.s3-...|
# |    1306|Comic Book Histor...|https://comrx.s3-...|
# |    1308|Complete Alice In...|https://comrx.s3-...|
# |    1311|Conan Legacy Fraz...|https://comrx.s3-...|
# |    1312|Conan People O/T ...|https://comrx.s3-...|
# |    1314|Conan Road of Kin...|https://comrx.s3-...|
# |    1316|Conan the Barbari...|https://comrx.s3-...|
# |    1319|Conan the Cimmeri...|https://comrx.s3-...|
# |    1320|Conan the Road of...|https://comrx.s3-...|
# |    1322|Concrete Park Res...|https://comrx.s3-...|
# |    1326|Conspiracy (Zenes...|https://comrx.s3-...|
# |    1327|    Constantine (DC)|https://comrx.s3-...|
# |    1329|Constantine Hellb...|https://comrx.s3-...|
# |    1331|Contest of Champi...|https://comrx.s3-...|
# |    1333|Convergence Actio...|https://comrx.s3-...|
# |    1335|Convergence Aquam...|https://comrx.s3-...|
# |    1337|Convergence Batgi...|https://comrx.s3-...|
# |    1339|Convergence Batma...|https://comrx.s3-...|
# |    1342|Convergence Boost...|https://comrx.s3-...|
# |    1344|Convergence Crime...|https://comrx.s3-...|
# |    1347|Convergence Flash...|https://comrx.s3-...|
# |    1350|Convergence Green...|https://comrx.s3-...|
# |    1352|Convergence Hawkm...|https://comrx.s3-...|
# |    1355|Convergence Justi...|https://comrx.s3-...|
# |    1356|Convergence Justi...|https://comrx.s3-...|
# |    1358|Convergence New T...|https://comrx.s3-...|
# |    1361|Convergence Quest...|https://comrx.s3-...|
# |    1362|Convergence Shaza...|https://comrx.s3-...|
# |    1366|Convergence Super...|https://comrx.s3-...|
# |    1367|Convergence Super...|https://comrx.s3-...|
# |    1370|Convergence Swamp...|https://comrx.s3-...|
# |    1371|Convergence Titan...|https://comrx.s3-...|
# |    1374|  Copperhead (Image)|https://comrx.s3-...|
# |    1375|Cosmic Ghost Ride...|https://comrx.s3-...|
# |    1378|Cosplayers (Fanta...|https://comrx.s3-...|
# |    1380|Country Ass Whupp...|https://comrx.s3-...|
# |    1385|Courtney Crumrin ...|https://comrx.s3-...|
# |    1386|Courtney Crumrin ...|https://comrx.s3-...|
# |    1383|Courtney Crumrin ...|https://comrx.s3-...|
# |    1389|Cowboys and Insec...|https://comrx.s3-...|
# |    1391|        Cowl (Image)|https://comrx.s3-...|
# |    1394|Crazies Part 1 Ho...|https://comrx.s3-...|
# |    1396|   Cree (Dark Horse)|https://comrx.s3-...|
# |    1398|Creepy Comics (Da...|https://comrx.s3-...|
# |    1401|    Criminal (Image)|https://comrx.s3-...|
# |    1402|Criminal Last of ...|https://comrx.s3-...|
# |    1405|Criminal Macabre ...|https://comrx.s3-...|
# |    1407|Criminal Macabre ...|https://comrx.s3-...|
# |    1409|Criminal Macabre ...|https://comrx.s3-...|
# |    1410|Criminal Savage E...|https://comrx.s3-...|
# |    1412|Criminal Special ...|https://comrx.s3-...|
# |    1414|Crisis On Infinit...|https://comrx.s3-...|
# |    1416|       Croak (Other)|https://comrx.s3-...|
# |    1418|Crossed Annual 20...|https://comrx.s3-...|
# |    1421|Crossed Badlands ...|https://comrx.s3-...|
# |    1423|Crossed Family Va...|https://comrx.s3-...|
# |    1425|Crossed Plus 100 ...|https://comrx.s3-...|
# |    1427|Crossed Psychopat...|https://comrx.s3-...|
# |    1636|Dce Essentials th...|https://comrx.s3-...|
# |    1429|Crossed Special 2...|https://comrx.s3-...|
# |    1431|Crossed Wish You ...|https://comrx.s3-...|
# |    1435|          Crow (IDW)|https://comrx.s3-...|
# |    1436|Crow Memento Mori...|https://comrx.s3-...|
# |    1434|     Crowded (Image)|https://comrx.s3-...|
# |    1439|       Crude (Image)|https://comrx.s3-...|
# |    1441|Cryptocracy (Dark...|https://comrx.s3-...|
# |    1444|   Curb Stomp (Boom)|https://comrx.s3-...|
# |    1451| Curse Words (Image)|https://comrx.s3-...|
# |    1452|Curse Words Sprin...|https://comrx.s3-...|
# |    1448|Curse of Brimston...|https://comrx.s3-...|
# |    1447|Cursed Pirate Gir...|https://comrx.s3-...|
# |    1454|      Cutter (Image)|https://comrx.s3-...|
# |    1457|         Cyborg (DC)|https://comrx.s3-...|
# |    1458| Cyborg Rebirth (DC)|https://comrx.s3-...|
# |    1460|     Cyclops (Other)|https://comrx.s3-...|
# |    1463|    D4veocracy (IDW)|https://comrx.s3-...|
# |    1465|Dads Weekend One ...|https://comrx.s3-...|
# |    1468|         Damage (DC)|https://comrx.s3-...|
# |    1469|   Damaged (Radical)|https://comrx.s3-...|
# |    1472|        Damned (Oni)|https://comrx.s3-...|
# |    1473|Damned Prodigal S...|https://comrx.s3-...|
# |    1474|      Dancer (Image)|https://comrx.s3-...|
# |    1476|Danger Girl Dange...|https://comrx.s3-...|
# |    1478|Danger Girl Mayda...|https://comrx.s3-...|
# |    1481|Danger Girl Revol...|https://comrx.s3-...|
# |    1482|Danger Girl the C...|https://comrx.s3-...|
# |    1485| Dantes Inferno (DC)|https://comrx.s3-...|
# |    1492|  Daredevil (Marvel)|https://comrx.s3-...|
# |    1489|Daredevil Black a...|https://comrx.s3-...|
# |    1493|Daredevil Mgc (Ma...|https://comrx.s3-...|
# |    1494|Daredevil Punishe...|https://comrx.s3-...|
# |    1496|Dark Ages (Dark H...|https://comrx.s3-...|
# |    1499|Dark Avengers Are...|https://comrx.s3-...|
# |    1502|Dark Days the Cas...|https://comrx.s3-...|
# |    1503|Dark Days the For...|https://comrx.s3-...|
# |    1506|   Dark Fang (Image)|https://comrx.s3-...|
# |    1509|Dark Horse Presen...|https://comrx.s3-...|
# |    1511|Dark Knight Iii (DC)|https://comrx.s3-...|
# |    1514|Dark Knight Retur...|https://comrx.s3-...|
# |    1516|Dark Matter (Dark...|https://comrx.s3-...|
# |    1521|Dark Nights Metal...|https://comrx.s3-...|
# |    1524|Dark Reign Sinist...|https://comrx.s3-...|
# |    1527|Dark Shadows Year...|https://comrx.s3-...|
# |    1530|  Dark Souls (Other)|https://comrx.s3-...|
# |    1531|Dark Souls Tales ...|https://comrx.s3-...|
# |    1535|      Dark Sun (IDW)|https://comrx.s3-...|
# |    1537|Dark Tower Battle...|https://comrx.s3-...|
# |    1539|Dark Tower Drawin...|https://comrx.s3-...|
# |    1541|Dark Tower Drawin...|https://comrx.s3-...|
# |    1543|Dark Tower Gunsli...|https://comrx.s3-...|
# |    1545|Dark Tower Gunsli...|https://comrx.s3-...|
# |    1548|Dark Tower Gunsli...|https://comrx.s3-...|
# |    1497|Dark and Bloody (...|https://comrx.s3-...|
# |    1518|   Darkness (Topcow)|https://comrx.s3-...|
# |    1520|Darkness Visible ...|https://comrx.s3-...|
# |    1533|Darkstalkers Nigh...|https://comrx.s3-...|
# |    1632|Dcd Summit 2014 A...|https://comrx.s3-...|
# |    1635|Dce Essentials Ba...|https://comrx.s3-...|
# |    1638|Dce Essentials Wo...|https://comrx.s3-...|
# |    1634|        Dceased (DC)|https://comrx.s3-...|
# |    1659|Dcu Halloween Spe...|https://comrx.s3-...|
# |    3151|Hunt For Wolverin...|https://comrx.s3-...|
# |    1574|DC Comics Bombshe...|https://comrx.s3-...|
# |    1577|DC Comics Essenti...|https://comrx.s3-...|
# |    1579|DC Comics Essenti...|https://comrx.s3-...|
# |    1580|DC Comics Present...|https://comrx.s3-...|
# |    1582|DC Comics Present...|https://comrx.s3-...|
# |    1584|DC Comics Present...|https://comrx.s3-...|
# |    1586|DC Comics Present...|https://comrx.s3-...|
# |    1589|DC Comics Present...|https://comrx.s3-...|
# |    1591|DC Comics Present...|https://comrx.s3-...|
# |    1592|DC Comics Present...|https://comrx.s3-...|
# |    1595|DC Comics Present...|https://comrx.s3-...|
# |    1597|DC Comics Present...|https://comrx.s3-...|
# |    1599|DC Comics Present...|https://comrx.s3-...|
# |    1601|DC Comics Present...|https://comrx.s3-...|
# |    1602|DC Comics Present...|https://comrx.s3-...|
# |    1607|DC Comics Present...|https://comrx.s3-...|
# |    1606|DC Comics Present...|https://comrx.s3-...|
# |    1610|DC Comics Present...|https://comrx.s3-...|
# |    1611|DC Comics Present...|https://comrx.s3-...|
# |    1613|DC Comics Present...|https://comrx.s3-...|
# |    1615|DC Comics Present...|https://comrx.s3-...|
# |    1617|DC Comics Present...|https://comrx.s3-...|
# |    1618|DC Comics Present...|https://comrx.s3-...|
# |    1621|DC Comics Present...|https://comrx.s3-...|
# |    1623|DC Comics Present...|https://comrx.s3-...|
# |    1628|DC Comics Present...|https://comrx.s3-...|
# |    1630|DC Comics Present...|https://comrx.s3-...|
# |    1625|DC Comics Present...|https://comrx.s3-...|
# |    1639|DC House of Horro...|https://comrx.s3-...|
# |    1641|DC Looney Tunes 1...|https://comrx.s3-...|
# |    1642|      DC Nation (DC)|https://comrx.s3-...|
# |    1645|DC Presents Lois ...|https://comrx.s3-...|
# |    1647|DC Retroactive Ba...|https://comrx.s3-...|
# |    1649|DC Retroactive Ba...|https://comrx.s3-...|
# |    1651|DC Retroactive Ju...|https://comrx.s3-...|
# |    1653|DC Retroactive Su...|https://comrx.s3-...|
# |    1656|DC Retroactive Wo...|https://comrx.s3-...|
# |    1661|DC Universe Holid...|https://comrx.s3-...|
# |    1551|Dark Tower Gunsli...|https://comrx.s3-...|
# |    1553|Dark Tower Sorcer...|https://comrx.s3-...|
# |    1555|Dark Tower Treach...|https://comrx.s3-...|
# |    1557|Darkwing Duck (Boom)|https://comrx.s3-...|
# |    1558| Darth Maul (Marvel)|https://comrx.s3-...|
# |    1559|Darth Vader Annua...|https://comrx.s3-...|
# |    1562|Dawn of Planet of...|https://comrx.s3-...|
# |    1565|      Day Men (Boom)|https://comrx.s3-...|
# |    1568|Days Missing (Other)|https://comrx.s3-...|
# |    1569|Days of Hate (Image)|https://comrx.s3-...|
# |    1571|    Dazzler (Marvel)|https://comrx.s3-...|
# |    1658|Dcs Year of the V...|https://comrx.s3-...|
# |    1672|Dead At 17 Witch ...|https://comrx.s3-...|
# |    1674|Dead Boy Detectiv...|https://comrx.s3-...|
# |    1676|   Dead Hand (Image)|https://comrx.s3-...|
# |    1678|  Dead Kings (Other)|https://comrx.s3-...|
# |    3488|Jenny Finn (Dark ...|https://comrx.s3-...|
# |    1664|DC Universe Prese...|https://comrx.s3-...|
# |    1666|DC Universe Rebir...|https://comrx.s3-...|
# |    1668|DC Vs Masters of ...|https://comrx.s3-...|
# |    1684| Dead Letters (Boom)|https://comrx.s3-...|
# |    1690|Dead Mans Run (As...|https://comrx.s3-...|
# |    1733|Dead Space Extrac...|https://comrx.s3-...|
# |    1691|Dead of Winter (Oni)|https://comrx.s3-...|
# |    1680|Deadlands Hopeles...|https://comrx.s3-...|
# |    1682|Deadlands One Sho...|https://comrx.s3-...|
# |    1686|Deadly Hands of K...|https://comrx.s3-...|
# |    1693|Deadpool #16 2nd ...|https://comrx.s3-...|
# |    1709|   Deadpool (Marvel)|https://comrx.s3-...|
# |    1699|Deadpool Assassin...|https://comrx.s3-...|
# |    1701|Deadpool Bi-Annua...|https://comrx.s3-...|
# |    1704|Deadpool Family (...|https://comrx.s3-...|
# |    1706|Deadpool Kills Ma...|https://comrx.s3-...|
# |    1708|Deadpool Last Day...|https://comrx.s3-...|
# |    1711|Deadpool Max 2 (M...|https://comrx.s3-...|
# |    1716|Deadpool Mgc (Mar...|https://comrx.s3-...|
# |    1717|Deadpool Pulp (Ma...|https://comrx.s3-...|
# |    1722|Deadpool Team-Up ...|https://comrx.s3-...|
# |    1726|Deadpool Vs Gambi...|https://comrx.s3-...|
# |    1728|Deadpool Vs Punis...|https://comrx.s3-...|
# |    1730|Deadpool Vs X-For...|https://comrx.s3-...|
# |    1694|Deadpool and Cabl...|https://comrx.s3-...|
# |    1696|Deadpool and Merc...|https://comrx.s3-...|
# |    1723|Deadpool the Duck...|https://comrx.s3-...|
# |    1714|Deadpoolmax X-Mas...|https://comrx.s3-...|
# |    1719|Deadpools Secret ...|https://comrx.s3-...|
# |    1735|Deadworld Restora...|https://comrx.s3-...|
# |    1737|Dean Koontz Frank...|https://comrx.s3-...|
# |    1740|Death Defying Dr ...|https://comrx.s3-...|
# |    1743|Death Head (Dark ...|https://comrx.s3-...|
# |    1758|Death Orb (Dark H...|https://comrx.s3-...|
# |    1760|Death Sentence Lo...|https://comrx.s3-...|
# |    1746|Death of Cerebus ...|https://comrx.s3-...|
# |    1748|Death of Haggard ...|https://comrx.s3-...|
# |    1751|Death of Love (Im...|https://comrx.s3-...|
# |    1752|Death of Wolverin...|https://comrx.s3-...|
# |    1754|Death of Wolverin...|https://comrx.s3-...|
# |    1757| Death of X (Marvel)|https://comrx.s3-...|
# |    1744|   Deathlok (Marvel)|https://comrx.s3-...|
# |    1763|    Deathstroke (DC)|https://comrx.s3-...|
# |    1765|Deathstroke Rebir...|https://comrx.s3-...|
# |    1768|Debbies Inferno (...|https://comrx.s3-...|
# |    1770|         Deep (Boom)|https://comrx.s3-...|
# |    1772|  Deep Roots (Other)|https://comrx.s3-...|
# |    1774|   Deep State (Boom)|https://comrx.s3-...|
# |    1776|Defenders Doctor ...|https://comrx.s3-...|
# |    1777|Defenders Immorta...|https://comrx.s3-...|
# |    1780|Defenders Namor (...|https://comrx.s3-...|
# |    1783|Defenders Tournam...|https://comrx.s3-...|
# |    1787|Dejah Thoris & Wh...|https://comrx.s3-...|
# |    1784|  Dejah of Mars (DE)|https://comrx.s3-...|
# |    1790|Delphine (Fantagr...|https://comrx.s3-...|
# |    1792|      Demi-God (IDW)|https://comrx.s3-...|
# |    1793|Demon Hell Is Ear...|https://comrx.s3-...|
# |    1796|Demon Knights (Ot...|https://comrx.s3-...|
# |    1799| Dept H (Dark Horse)|https://comrx.s3-...|
# |    1801|   Descender (Image)|https://comrx.s3-...|
# |    1803|    Desperadoes (DC)|https://comrx.s3-...|
# |    1807|Detective Comics ...|https://comrx.s3-...|
# |    1805|Detective Comics ...|https://comrx.s3-...|
# |    1808|Detective Comics ...|https://comrx.s3-...|
# |    1811|Deuce of Hearts (...|https://comrx.s3-...|
# |    1813|     Deus Ex (Other)|https://comrx.s3-...|
# |    1817|Devil Within (Other)|https://comrx.s3-...|
# |    1816|Devils Hopyard (O...|https://comrx.s3-...|
# |    1819|Dexter Down Under...|https://comrx.s3-...|
# |    1822|Df East of West (DE)|https://comrx.s3-...|
# |    1824|Df Green Lantern ...|https://comrx.s3-...|
# |    1826|Df Marvel-Ous 25-...|https://comrx.s3-...|
# |    1831|Dia De Los Muerto...|https://comrx.s3-...|
# |    1830|  Diablo House (IDW)|https://comrx.s3-...|
# |    1834|      Dial H (Other)|https://comrx.s3-...|
# |    1838|Dick Tracy Dead O...|https://comrx.s3-...|
# |    1836|      Dicks (Avatar)|https://comrx.s3-...|
# |    1843|         Die (Image)|https://comrx.s3-...|
# |    1842|Die Hard Year One...|https://comrx.s3-...|
# |    1844|Die Kitty Die Chr...|https://comrx.s3-...|
# |    1846|        Dingo (Boom)|https://comrx.s3-...|
# |    1850|Dirk Gently Salmo...|https://comrx.s3-...|
# |    1851|Dirk Gentlys Holi...|https://comrx.s3-...|
# |    1853|  Discipline (Image)|https://comrx.s3-...|
# |    1855|Disney Darkwing D...|https://comrx.s3-...|
# |    1856|Disney Frozen Ada...|https://comrx.s3-...|
# |    1859|Disney Frozen Reu...|https://comrx.s3-...|
# |    1861|Disney Gravity Fa...|https://comrx.s3-...|
# |    1863|Disney Kingdoms S...|https://comrx.s3-...|
# |    1865|Disney Muppets Pr...|https://comrx.s3-...|
# |    1867|Disney Pixar Cars...|https://comrx.s3-...|
# |    1869|Disney Pixar Incr...|https://comrx.s3-...|
# |    1870|Disney Princess a...|https://comrx.s3-...|
# |    1874|Disney Star Vs th...|https://comrx.s3-...|
# |    1875| Dissonance (Topcow)|https://comrx.s3-...|
# |    1878|    Divinica (Other)|https://comrx.s3-...|
# |    1883|    Divinity (Other)|https://comrx.s3-...|
# |    1879|Divinity Iii Aric...|https://comrx.s3-...|
# |    1881|Divinity Iii Stal...|https://comrx.s3-...|
# |    1885|   Django Zorro (DE)|https://comrx.s3-...|
# |    1887|       Dmz (Vertigo)|https://comrx.s3-...|
# |    1889|Do Androids Dream...|https://comrx.s3-...|
# |    1891|   Doc Macabre (IDW)|https://comrx.s3-...|
# |    1894|     Doc Savage (DE)|https://comrx.s3-...|
# |    1896|Doc Savage Spider...|https://comrx.s3-...|
# |    1898|    Doctor Fate (DC)|https://comrx.s3-...|
# ...
# |    3545|John Carpenters A...|https://comrx.s3-...|
# |    3546|John Carter a Pri...|https://comrx.s3-...|
# |    3549|John Carter the E...|https://comrx.s3-...|
# |    3552|      John Wick (DE)|https://comrx.s3-...|
# |    3554|Jokers Asylum Har...|https://comrx.s3-...|
# |    3556|Jokers Asylum Poi...|https://comrx.s3-...|
# |    3561|Jokers Asylum Two...|https://comrx.s3-...|
# |    3559|Jokers Asylum the...|https://comrx.s3-...|
# |    3562|      Jonah Hex (DC)|https://comrx.s3-...|
# |    5072|  Rick & Morty (Oni)|https://comrx.s3-...|
# |    3634|Justice League Go...|https://comrx.s3-...|
# |    3635|Justice League Go...|https://comrx.s3-...|
# |    3636|Justice League Go...|https://comrx.s3-...|
# |    3637|Justice League Go...|https://comrx.s3-...|
# |    3638|Justice League In...|https://comrx.s3-...|
# |    3639|Justice League In...|https://comrx.s3-...|
# |    3640|Justice League No...|https://comrx.s3-...|
# |    3641|Justice League Od...|https://comrx.s3-...|
# |    3650|Justice League Po...|https://comrx.s3-...|
# |    3651|Justice League Re...|https://comrx.s3-...|
# |    3653|Justice League Ri...|https://comrx.s3-...|
# |    3652|Justice League Ri...|https://comrx.s3-...|
# |    3654|Justice League Su...|https://comrx.s3-...|
# |    3657|Justice League Un...|https://comrx.s3-...|
# |    3656|Justice League Un...|https://comrx.s3-...|
# |    3658|Justice League Un...|https://comrx.s3-...|
# |    3643|Justice League of...|https://comrx.s3-...|
# |    3642|Justice League of...|https://comrx.s3-...|
# |    3644|Justice League of...|https://comrx.s3-...|
# |    3645|Justice League of...|https://comrx.s3-...|
# |    3648|Justice League of...|https://comrx.s3-...|
# |    3647|Justice League of...|https://comrx.s3-...|
# |    3646|Justice League of...|https://comrx.s3-...|
# |    3655|Justice League th...|https://comrx.s3-...|
# |    3659|Justice Society o...|https://comrx.s3-...|
# |    3662|Justice Society o...|https://comrx.s3-...|
# |    3660|Justice Society o...|https://comrx.s3-...|
# |    3661|Justice Society o...|https://comrx.s3-...|
# |    3663|Justice Society o...|https://comrx.s3-...|
# |    3679|     Ka-Zar (Marvel)|https://comrx.s3-...|
# |    3664|      Kaijumax (Oni)|https://comrx.s3-...|
# |    3665|Kaijumax Season 2...|https://comrx.s3-...|
# |    3666|Kaijumax Season 3...|https://comrx.s3-...|
# |    3667|Kamandi Challenge...|https://comrx.s3-...|
# |    3668|Kamandi Challenge...|https://comrx.s3-...|
# |    3670|      Kanan (Marvel)|https://comrx.s3-...|
# |    3669|Kanan Last Padawa...|https://comrx.s3-...|
# |    3671| Kane and Lynch (DC)|https://comrx.s3-...|
# |    3672|Kang & Kodos (Bongo)|https://comrx.s3-...|
# |    3673|Kapow Guinness Wo...|https://comrx.s3-...|
# |    3674|     Kaptara (Image)|https://comrx.s3-...|
# |    3675|Karma Police (Other)|https://comrx.s3-...|
# |    3676|     Karnak (Marvel)|https://comrx.s3-...|
# |    3677|         Katana (DC)|https://comrx.s3-...|
# |    3678|Kato Origins Way ...|https://comrx.s3-...|
# |    3680|Kennel Block Blue...|https://comrx.s3-...|
# |    3682|Kevin Smith Bioni...|https://comrx.s3-...|
# |    3683|Kevin Smith Green...|https://comrx.s3-...|
# |    3686|Kevin Smith Yoga ...|https://comrx.s3-...|
# |    3688|       Khaal (Other)|https://comrx.s3-...|
# |    3689| Kick-Ass 2 (Marvel)|https://comrx.s3-...|
# |    3693|   Kill Audio (Boom)|https://comrx.s3-...|
# |    3694|Killbox Chicago (...|https://comrx.s3-...|
# |    3696|Killer Instinct (DE)|https://comrx.s3-...|
# |    3698| Killmonger (Marvel)|https://comrx.s3-...|
# |    3701|Kill Shakespeare ...|https://comrx.s3-...|
# |    3704|Kill Shakespeare ...|https://comrx.s3-...|
# |    3706|Kill the Minotaur...|https://comrx.s3-...|
# |    3708| Kim and Kim (Other)|https://comrx.s3-...|
# |    3721|        King (Other)|https://comrx.s3-...|
# |    3711|   King City (Image)|https://comrx.s3-...|
# |    3713|King Conan Hour O...|https://comrx.s3-...|
# |    3715|King Conan Scarle...|https://comrx.s3-...|
# |    3718|King Flash Gordon...|https://comrx.s3-...|
# |    3720|King Mandrake Mag...|https://comrx.s3-...|
# |    3731|King Tiger (Dark ...|https://comrx.s3-...|
# |    3722|       King! (Other)|https://comrx.s3-...|
# |    3727|    Kings Quest (DE)|https://comrx.s3-...|
# |    3726|Kingsman Red Diam...|https://comrx.s3-...|
# |    3733|  Kirby Genesis (DE)|https://comrx.s3-...|
# |    3734|Kirby Genesis Dra...|https://comrx.s3-...|
# |    3737|           Kiss (DE)|https://comrx.s3-...|
# |    3736|       Kiss Aod (DE)|https://comrx.s3-...|
# |    3741|     Kiss Solo (IDW)|https://comrx.s3-...|
# |    3743|   Kitchen (Vertigo)|https://comrx.s3-...|
# |    3744|        Klarion (DC)|https://comrx.s3-...|
# |    3747|        Klaus (Boom)|https://comrx.s3-...|
# |    3749|Klaws of Panther ...|https://comrx.s3-...|
# |    3752|Knight & Squire (DC)|https://comrx.s3-...|
# |    3753|Kodiak (One Shot ...|https://comrx.s3-...|
# |    3755|Kodt Black Hands ...|https://comrx.s3-...|
# |    3759|Kong On Planet of...|https://comrx.s3-...|
# |    3758|Kong of Skull Isl...|https://comrx.s3-...|
# |    3761|Konungar War of C...|https://comrx.s3-...|
# |    3763|Korgi Short Tales...|https://comrx.s3-...|
# |    3765|Koshchei the Deat...|https://comrx.s3-...|
# |    3767|Krusty the Clown ...|https://comrx.s3-...|
# |    3769|  Kull Eternal (IDW)|https://comrx.s3-...|
# |    3771|Kull the Cat & th...|https://comrx.s3-...|
# |    3773|Kung Fu Panda (Ot...|https://comrx.s3-...|
# |    3798|La Mano Del Desti...|https://comrx.s3-...|
# |    3777|Lady Deadpool (Ma...|https://comrx.s3-...|
# |    3780|Lady Killer (Dark...|https://comrx.s3-...|
# |    3781|Lady Mechanika #0...|https://comrx.s3-...|
# |    3784|Lady Mechanika (A...|https://comrx.s3-...|
# |    3785|Lady Mechanika Cl...|https://comrx.s3-...|
# |    3787|Lady Mechanika Da...|https://comrx.s3-...|
# |    3789|Lady Mechanika La...|https://comrx.s3-...|
# |    3791|Lady Mechanika Ma...|https://comrx.s3-...|
# |    3795|Lady Robotika (Im...|https://comrx.s3-...|
# |    3776|   Ladycastle (Boom)|https://comrx.s3-...|
# |    3797|Lake of Fire (Image)|https://comrx.s3-...|
# |    3801|      Larfleeze (DC)|https://comrx.s3-...|
# |    3802|Larks Killer (Other)|https://comrx.s3-...|
# |    3805|Last Contract (Boom)|https://comrx.s3-...|
# |    3807|Last Gang In Town...|https://comrx.s3-...|
# |    3811|   Last Phantom (DE)|https://comrx.s3-...|
# |    3813|   Last Song (Other)|https://comrx.s3-...|
# |    3815|Last Space Race (...|https://comrx.s3-...|
# |    3817|  Last Unicorn (IDW)|https://comrx.s3-...|
# |    3809|Last of the Great...|https://comrx.s3-...|
# |    3819|    Lazaretto (Boom)|https://comrx.s3-...|
# |    3821|Lazarus Risen (Im...|https://comrx.s3-...|
# |    3825|Lcsd 2016 Invader...|https://comrx.s3-...|
# |    3827|Leaving Megalopol...|https://comrx.s3-...|
# |    3834|Legend of Bold Ri...|https://comrx.s3-...|
# |    3837|Legend of Wonder ...|https://comrx.s3-...|
# |    3829|Legendary Star Lo...|https://comrx.s3-...|
# |    3833|Legenderry Vampir...|https://comrx.s3-...|
# |    3838|Legends Dark Knig...|https://comrx.s3-...|
# |    3841|Legends of Tomorr...|https://comrx.s3-...|
# |    3844|     Legion (Marvel)|https://comrx.s3-...|
# |    3843| Legion Lost (Other)|https://comrx.s3-...|
# |    3848|Legion of Super H...|https://comrx.s3-...|
# |    3846|Legion of Super H...|https://comrx.s3-...|
# |    3850|Legion of Super V...|https://comrx.s3-...|
# |    3853|Let Me In Crossro...|https://comrx.s3-...|
# |    3855|     Letter 44 (Oni)|https://comrx.s3-...|
# |    3859|   Liberator (Other)|https://comrx.s3-...|
# |    3858|Liberator Earth C...|https://comrx.s3-...|
# |    3861|Liberty Comics Pr...|https://comrx.s3-...|
# |    3867|Life & Times of S...|https://comrx.s3-...|
# |    3863|    Life After (Oni)|https://comrx.s3-...|
# |    3869|Life With Archie ...|https://comrx.s3-...|
# |    3871|       Light (Image)|https://comrx.s3-...|
# |    3872|Lightstep (Dark H...|https://comrx.s3-...|
# |    3874|Lil Depressed Boy...|https://comrx.s3-...|
# |    3876|Lil Depressed Boy...|https://comrx.s3-...|
# |    3878|      Lil Sonja (DE)|https://comrx.s3-...|
# |    3880|       Limbo (Image)|https://comrx.s3-...|
# |    3882| Little Bird (Image)|https://comrx.s3-...|
# |    3885|Little Nightmares...|https://comrx.s3-...|
# |    3886|Littlest Pet Shop...|https://comrx.s3-...|
# |    3888|Littlest Zombie (...|https://comrx.s3-...|
# |    3889|    Livewire (Other)|https://comrx.s3-...|
# |    3894|Lobster Johnson C...|https://comrx.s3-...|
# |    3896|Lobster Johnson G...|https://comrx.s3-...|
# |    3898|Lobster Johnson G...|https://comrx.s3-...|
# |    3900|Lobster Johnson M...|https://comrx.s3-...|
# |    3902|Lobster Johnson P...|https://comrx.s3-...|
# |    3904|Lobster Johnson S...|https://comrx.s3-...|
# |    3893|Lobster Johnson a...|https://comrx.s3-...|
# |    3907|         Local (Oni)|https://comrx.s3-...|
# |    3908|Locke & Key Alpha...|https://comrx.s3-...|
# |    3910|Locke & Key Clock...|https://comrx.s3-...|
# |    3912|Locke & Key Grind...|https://comrx.s3-...|
# |    3914|Locke & Key Head ...|https://comrx.s3-...|
# |    3917|Locke & Key Omega...|https://comrx.s3-...|
# |    3918|Locke & Key Small...|https://comrx.s3-...|
# |    3921|Locke & Key Treas...|https://comrx.s3-...|
# |    3923|Locke & Key Welco...|https://comrx.s3-...|
# |    3926|    Lockjaw (Marvel)|https://comrx.s3-...|
# |    3927|        Lodger (IDW)|https://comrx.s3-...|
# |    3928|Loeg Tempest (Other)|https://comrx.s3-...|
# |    3931|       Loki (Marvel)|https://comrx.s3-...|
# |    3933|   Lola Xoxo (Aspen)|https://comrx.s3-...|
# |    3934|Lollipop Kids (Ot...|https://comrx.s3-...|
# |    3935|    Lone Ranger (DE)|https://comrx.s3-...|
# |    3939|Lone Wolf 2100 (D...|https://comrx.s3-...|
# |    3940|      Long Con (Oni)|https://comrx.s3-...|
# |    4747|Pierce Brown Red ...|https://comrx.s3-...|
# |    3943|Long Lost Book Tw...|https://comrx.s3-...|
# |    3947|Looking For Group...|https://comrx.s3-...|
# |    3948|Lookouts Riddle V...|https://comrx.s3-...|
# |    3950|  Loose Ends (Image)|https://comrx.s3-...|
# |    3952|Lord of Gore (Other)|https://comrx.s3-...|
# |    3955|Lorna Relic Wrang...|https://comrx.s3-...|
# |    3957|      Lost Boys (DC)|https://comrx.s3-...|
# |    3959|Lost City Explore...|https://comrx.s3-...|
# |    3961|  Lost Vegas (Image)|https://comrx.s3-...|
# |    3966|   Love Is Lov (IDW)|https://comrx.s3-...|
# |    3969|Love Stories To D...|https://comrx.s3-...|
# |    3964|Love and Capes Ev...|https://comrx.s3-...|
# |    3970|         Low (Image)|https://comrx.s3-...|
# |    3973|Low Society One S...|https://comrx.s3-...|
# |    3974|  Lucas Stand (Boom)|https://comrx.s3-...|
# |    3976|   Lucifer (Vertigo)|https://comrx.s3-...|
# |    3982|  Lumberjanes (Boom)|https://comrx.s3-...|
# |    3980|Lumberjanes 2018 ...|https://comrx.s3-...|
# |    3983|Lumberjanes Gotha...|https://comrx.s3-...|
# |    3985|Lumberjanes Speci...|https://comrx.s3-...|
# |    3987|      Lunita (Other)|https://comrx.s3-...|
# |    3989|       Machete (IDW)|https://comrx.s3-...|
# |    3997|Mad Max Fury Road...|https://comrx.s3-...|
# |    3990|Madame Frankenste...|https://comrx.s3-...|
# |    3992|      Made Men (Oni)|https://comrx.s3-...|
# |    3998|    Mae (Dark Horse)|https://comrx.s3-...|
# |    4000|   Mae VOL 2 (Other)|https://comrx.s3-...|
# |    4001|   Magdalena (Image)|https://comrx.s3-...|
# |    4004|  Magdalena (Topcow)|https://comrx.s3-...|
# |    4005|Magdalena VOL 4 (...|https://comrx.s3-...|
# |    4009| Magic Order (Image)|https://comrx.s3-...|
# |    4012|Magic the Gatheri...|https://comrx.s3-...|
# |    4014|Magic the Gatheri...|https://comrx.s3-...|
# |    4008|Magical Character...|https://comrx.s3-...|
# |    4015|    Magneto (Marvel)|https://comrx.s3-...|
# |    4018|         Magnus (DE)|https://comrx.s3-...|
# |    4019|Magnus Robot Figh...|https://comrx.s3-...|
# |    4022|     Malefic (Other)|https://comrx.s3-...|
# |    4024|        Mall (Other)|https://comrx.s3-...|
# |    4033|    Man Plus (Other)|https://comrx.s3-...|
# |    4032|   Man of Steel (DC)|https://comrx.s3-...|
# |    4034|  Man-Thing (Marvel)|https://comrx.s3-...|
# |    4028|Manhattan Project...|https://comrx.s3-...|
# |    4030|Manhunter Special...|https://comrx.s3-...|
# |    4035|      Mantle (Image)|https://comrx.s3-...|
# |    4038|        Mara (Image)|https://comrx.s3-...|
# |    4042|Mark Waid Green H...|https://comrx.s3-...|
# |    4041|    Marksmen (Image)|https://comrx.s3-...|
# |    4047|  Mars Attacks (IDW)|https://comrx.s3-...|
# |    4046|Mars Attacks Holi...|https://comrx.s3-...|
# |    4049|Mars Attacks Kiss...|https://comrx.s3-...|
# |    4051|Mars Attacks Pope...|https://comrx.s3-...|
# |    4053|Mars Attacks Tran...|https://comrx.s3-...|
# |    4055|Martian Manhunter...|https://comrx.s3-...|
# |    4057|Marvel 1602 Mgc (...|https://comrx.s3-...|
# |    4059|Marvel 75th Anniv...|https://comrx.s3-...|
# |    4060|Marvel Action Ave...|https://comrx.s3-...|
# |    4063|Marvel Adventures...|https://comrx.s3-...|
# |    4067|Marvel Boy Urania...|https://comrx.s3-...|
# |    4069|Marvel Comics Pre...|https://comrx.s3-...|
# |    4072|Marvel Holiday Sp...|https://comrx.s3-...|
# |    4073|Marvel Knights 20...|https://comrx.s3-...|
# |    4076|Marvel Knights X-...|https://comrx.s3-...|
# |    4077|Marvel Legac (Mar...|https://comrx.s3-...|
# |    4079|Marvel Legacy Bro...|https://comrx.s3-...|
# |    4081|Marvel Legacy Lan...|https://comrx.s3-...|
# |    4084|Marvel Legacy Ree...|https://comrx.s3-...|
# |    4088|Marvel Now Point ...|https://comrx.s3-...|
# |    4091|Marvel Presents (...|https://comrx.s3-...|
# |    4092|Marvel Rising Alp...|https://comrx.s3-...|
# |    4095|Marvel Rising Ome...|https://comrx.s3-...|
# |    4110|Marvel Sh Adventu...|https://comrx.s3-...|
# |    4118|Marvel Tales Aven...|https://comrx.s3-...|
# |    4119|Marvel Tales Blac...|https://comrx.s3-...|
# |    4121|Marvel Tales Iron...|https://comrx.s3-...|
# |    4123|Marvel Tales Than...|https://comrx.s3-...|
# |    4125|Marvel Tales Veno...|https://comrx.s3-...|
# |    4127|Marvel Tsum Tsum ...|https://comrx.s3-...|
# |    4139|Marvel Univers Vs...|https://comrx.s3-...|
# |    4131|Marvel Universe A...|https://comrx.s3-...|
# |    4133|Marvel Universe G...|https://comrx.s3-...|
# |    4136|Marvel Universe U...|https://comrx.s3-...|
# |    4138|Marvel Universe V...|https://comrx.s3-...|
# |    4141|Marvel Zombie (Ma...|https://comrx.s3-...|
# |    4142|Marvel Zombies 5 ...|https://comrx.s3-...|
# |    4144|Marvel Zombies Ev...|https://comrx.s3-...|
# |    4147|Marvel Zombies Mg...|https://comrx.s3-...|
# |    4149|Marvel Zombies Su...|https://comrx.s3-...|
# |    4087|Marvelman Familys...|https://comrx.s3-...|
# |    4097|Marvels Annotated...|https://comrx.s3-...|
# |    4098|Marvels Ant-Man a...|https://comrx.s3-...|
# |    4100|Marvels Avengers ...|https://comrx.s3-...|
# |    4103|Marvels Avengers ...|https://comrx.s3-...|
# |    4105|Marvels Captain A...|https://comrx.s3-...|
# |    4107|Marvels Doctor St...|https://comrx.s3-...|
# |    4109|Marvels Guardians...|https://comrx.s3-...|
# |    4112|Marvels Spider-Ma...|https://comrx.s3-...|
# |    4114|Marvels Thor Dark...|https://comrx.s3-...|
# |    4150|Mary Shelley Mons...|https://comrx.s3-...|
# |    4153|Mask Revolution (...|https://comrx.s3-...|
# |    4155|          Masks (DE)|https://comrx.s3-...|
# |    4157|Mass Effect Evolu...|https://comrx.s3-...|
# |    4159|Mass Effect Homew...|https://comrx.s3-...|
# |    4161|Mass Effect Redem...|https://comrx.s3-...|
# |    4163|Massive Ninth Wav...|https://comrx.s3-...|
# |    4165|Masterplasty Ones...|https://comrx.s3-...|
# |    4167|Masters of the Un...|https://comrx.s3-...|
# |    4169|Mata Hari (Dark H...|https://comrx.s3-...|
# |    4173|   Max Ride (Marvel)|https://comrx.s3-...|
# |    4174|Maxwells Demons (...|https://comrx.s3-...|
# |    4175|Maxx Maxximized (...|https://comrx.s3-...|
# |    4178|      Mcbain (Bongo)|https://comrx.s3-...|
# |    4180|   Meanwhile (Other)|https://comrx.s3-...|
# |    4184|Mediterranea (Other)|https://comrx.s3-...|
# |    4186|  Mega Ghost (Other)|https://comrx.s3-...|
# |    4187|   Mega Man (Archie)|https://comrx.s3-...|
# |    4190|Mega Princess (Boom)|https://comrx.s3-...|
# |    4191|      Memetic (Boom)|https://comrx.s3-...|
# |    4194|Memorial Imaginar...|https://comrx.s3-...|
# +--------+--------------------+--------------------+
# only showing top 2000 rows

# %%
from pyspark.sql.functions import lower, upper

# %%
sample_comic = 'Sweet Tooth'

# %%
sample_comic = 'Paper Girls'

# %%
test = comics_df.filter(lower(comics_df['comic_title']).contains(str.lower(sample_comic))).select('comic_title')

# %%
test.show()
# Out:
# +--------------------+
# |         comic_title|
# +--------------------+
# |Image Firsts Pape...|
# | Paper Girls (Image)|
# +--------------------+

# %%
test2 = test.withColumn('temp', col('comic_title'))

# %%
test2.show()
# Out:
# +--------------------+--------------------+
# |         comic_title|                temp|
# +--------------------+--------------------+
# |Image Firsts Pape...|Image Firsts Pape...|
# | Paper Girls (Image)| Paper Girls (Image)|
# +--------------------+--------------------+

# %%
sold.show(2)
# Out:
# +----------+------+--------+
# |account_id|bought|comic_id|
# +----------+------+--------+
# |      2247|     1|     995|
# |       487|     1|    1102|
# +----------+------+--------+
# only showing top 2 rows

# %%
# Get max account id
max_acct_id = sold.agg({'account_id':'max'}).collect()[0][0]
max_acct_id
# Out:
# 3074

# %%
new_acct_id = max_acct_id + 1

# %%
curr_comic_ids
# Out:
# [6105, 3235, 4701]

# %%
new_rows = [(new_acct_id, 1, comic_id) for comic_id in curr_comic_ids]

# %%
new_rows
# Out:
# [(3075, 1, 6105), (3075, 1, 3235), (3075, 1, 4701)]

# %%
sold_test = sold
sold_test.persist()
# Out:
# DataFrame[account_id: bigint, bought: bigint, comic_id: bigint]

# %%
sold_test.count()
# Out:
# 61871

# %%
sold_new = sold_test.union(spark.createDataFrame(new_rows))

# %%
sold_new.count()
# Out:
# 61874

# %%
newRow = spark.createDataFrame([(15,'Alk','Dhl')])
df = df.union(newRow)
df.show()

# %%
test_sold = sold

# %%
test_sold_2 = add_new_user(sold, curr_comic_ids)

# %%
print(test_sold.count())
# Out:
# 61871

# %%
print(test_sold_2.count())
# Out:
# 61874

# %%
supertest = [(3,4),(5,6)]

# %%
supertest
# Out:
# [(3, 4), (5, 6)]

# %%
superlist = dict(supertest)

# %%
superlist
# Out:
# {3: 4, 5: 6}

# %%
comm = [('Batman','www.batman'),('XMen','www.s3.commen')]

# %%
dict(comm)
# Out:
# {'Batman': 'www.batman', 'XMen': 'www.s3.commen'}
